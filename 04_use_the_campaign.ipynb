# %% [markdown]
# # Using Personalize campaigns  on synthetic cars data
# This notebook exercises campaigns that have been built in the other notebooks. The intent is to demonstrate
# that the results coming back from requests for recommendations are accurate given the dataset we provided.
#
# There are specific sections for each of the following models:
#
# 1. [Personalized Ranking](#Exercise-the-personalized-ranking-campaign)
# 2. [HRNN](#Exercise-the-hrnn-campaign)
# 3. [SIMS](#Exercise-the-SIMS-campaign)
# 4. [HRNN-Metadata]()
# 5. [Popularity Count](#Exercise-the-popularity-campaign)
#
# In addition, we have a section for experimenting with
# [Personalize Event Tracker](#Use-real-time-events).

# %% [markdown]
# ## Imports, overall settings, initialization

# %%
account_num        = '<your-account-num>'

# %%
import json
import boto3
import time
import datetime
import pandas as pd
from sklearn.utils import shuffle

region   = boto3.Session().region_name # or replace with your preferred region
print(region)

dataset_group_name = 'car-dg'

dg_arn = 'arn:aws:personalize:{}:{}:dataset-group/{}'.format(region, 
                                                             account_num, 
                                                             dataset_group_name)

cars_filename         = 'car_items.csv'
users_filename        = 'users.csv'
interactions_filename = 'interactions.csv'
int_exp_filename      = 'interactions_expanded.csv'

ranking_arn           = 'arn:aws:personalize:{}:{}:campaign/car-personalized-ranking'.format(region, account_num)
sims_arn              = 'arn:aws:personalize:{}:{}:campaign/car-sims'.format(region, account_num)
hrnn_arn              = 'arn:aws:personalize:{}:{}:campaign/car-hrnn'.format(region, account_num)
hrnn_metadata_arn     = 'arn:aws:personalize:{}:{}:campaign/car-hrnn-metadata'.format(region, account_num)
pop_arn               = 'arn:aws:personalize:{}:{}:campaign/car-popularity-count'.format(region, account_num)
# Out:
# us-east-1

# %%
personalize           = boto3.client('personalize')
personalize_runtime   = boto3.client('personalize-runtime')
personalize_events    = boto3.client('personalize-events')

# %%
def show_item_interaction_history(int_df, item_id):
    _tmp_df = int_df[int_df.ITEM_ID == item_id].sort_values('TIMESTAMP')
    print(_tmp_df.shape)
    return _tmp_df[['USER_ID','ITEM_ID','WHEN',
                    'FAV','YEAR','GENDER','SALARY']]

# %%
def show_user_interaction_history(int_df, user_id):
    _tmp_df = int_df[int_df.USER_ID == int(user_id)].sort_values('TIMESTAMP')
    print(_tmp_df.shape)
    return _tmp_df[['USER_ID','ITEM_ID','WHEN',
                    'FAV','YEAR','PRICE','MILEAGE']]

# %%
def date_to_string(ts):
    return datetime.datetime.fromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')

# %%
def is_campaign_active(c):
    _is_active = False
    
    try:
        _resp = personalize.describe_campaign(campaignArn = c)
        _campaign_status = _resp['campaign']['status']
        if _campaign_status == 'ACTIVE':
            _is_active = True
    except Exception as e:
        pass
        
    return _is_active

# %%
int_expanded_df = pd.read_csv(int_exp_filename)

int_expanded_df['WHEN'] = int_expanded_df['TIMESTAMP'].apply(date_to_string)

NUM_CLUSTERS = len(int_expanded_df.FAV_CLUSTER.value_counts())
print('{} clusters'.format(NUM_CLUSTERS))
# Out:
# 100 clusters

# %%
items_to_rank = int_expanded_df.sample(10)
items_to_rank.head(3)
# Out:
#         USER_ID  ITEM_ID   TIMESTAMP  SESSION_ID       MAKE     MODEL  YEAR  \
# 55057     22549    21220  1563207798       48831  Chevrolet  Suburban  2014
# 675905    17040    29498  1562824530       35336        GMC    Acadia  2015
# 32449      8361    21618  1562770493       16680   Chrysler  Pacifica  2014
#
#         MILEAGE  PRICE  AGE  GENDER  LOCATION  SALARY  FAV_CLUSTER  FAV_MODEL  \
# 55057     78448  33654   44    MALE     10468   26852           44         22
# 675905    63545  36952   47  FEMALE     93257   30995           22         11
# 32449     78482  34866   41  FEMALE     94544   49452           46         23
#
#                               FAV   HOURS_AGO                 WHEN
# 55057   NEWISH-Chevrolet-Suburban   43.850000  2019-07-15 16:23:18
# 675905          NEWISH-GMC-Acadia  150.313333  2019-07-11 05:55:30
# 32449    NEWISH-Chrysler-Pacifica  165.323611  2019-07-10 14:54:53

# %%
def print_item(item_id):
    tmp = int_expanded_df[int_expanded_df.ITEM_ID == item_id].iloc[0]
    print('Id: {}, Make: {}, Model: {}, Fav: {}, Year: {}'.format(item_id,
         tmp['MAKE'], tmp['MODEL'], tmp['FAV'], tmp['YEAR']))

# %% [markdown]
# Skip ahead to try out various campaigns:
#
# 1. [Personalized Ranking](#Exercise-the-personalized-ranking-campaign)
# 2. [HRNN](#Exercise-the-hrnn-campaign)
# 3. [SIMS](#Exercise-the-SIMS-campaign)
# 4. [HRNN-Metadata]()
# 5. [Popularity Count](#Exercise-the-popularity-campaign)
#
# In addition, we have a section for experimenting with
# [Personalize Event Tracker](#Use-real-time-events).

# %% [markdown]
# ## Exercise the Personalized Ranking campaign
# Here we want to see Personalize re-rank a set of search results. For our sample, we will pass
# a user that likes oldish cars and would expect oldish cars to appear closer to the top. Likewise, we will
# pass a user that likes newish cars and expect the higher ranked cars to be newish.

# %%
full_df = pd.DataFrame(columns=['USER_ID','FAV','FAV_CLUSTER'])

for i in range(NUM_CLUSTERS):
    tmp_df  = int_expanded_df[int_expanded_df.FAV_CLUSTER == i][['USER_ID','FAV','FAV_CLUSTER']].sample(1)
    full_df = pd.concat([full_df, tmp_df])
ranking_user_df = shuffle(full_df)
ranking_user_list = ranking_user_df['USER_ID'].values.astype(str).tolist()
ranking_user_df.head(NUM_CLUSTERS)
# Out:
#        USER_ID                         FAV FAV_CLUSTER
# 717562   14548   NEWISH-Chevrolet-Traverse          88
# 670482    8358    OLDISH-Volkswagen-Tiguan          83
# 722202   20635     OLDISH-Volkswagen-Jetta          91
# 748958    8768        NEWISH-Buick-Enclave           4
# 745926    8486          OLDISH-Nissan-Leaf          93
# 749953   11493        NEWISH-Dodge-Durango          98
# 739866    7909           OLDISH-Kia-Sedona           7
# 720179   14083  OLDISH-Jeep-Grand Cherokee          87
# 189199   13855        NEWISH-Ford-Explorer          52
# 272750   10893      NEWISH-Hyundai-Elantra          70
# 442968   12187          OLDISH-Buick-Regal          57
# 37295    16209    NEWISH-Chrysler-Pacifica          46
# 301679   18287            NEWISH-GMC-Yukon          24
# 521650   11594          NEWISH-Toyota-Rav4          96
# 749166   16996             OLDISH-BMW-330i           3
# 575588   12841         OLDISH-Chrysler-300          21
# 596680   14957     NEWISH-Chevrolet-Camaro          66
# 546113    9070         OLDISH-Ford-Mustang          49
# 364996   18858         OLDISH-Cadillac-XT5          69
# 132110   18720         NEWISH-Toyota-Prius          78
# 724213   14125            NEWISH-Volvo-240          26
# 704529   25123       OLDISH-Toyota-Corrola          41
# 275754   15618         NEWISH-Ford-Mustang          48
# 526541   23009         OLDISH-Chrysler-200          63
# 740523   20068         NEWISH-Chrysler-300          20
# 431231    9602  NEWISH-Jeep-Grand Cherokee          86
# 746458   15152         NEWISH-Toyota-Camry           0
# 748461   17020             NEWISH-BMW-330i           2
# 24305    15814          NEWISH-Buick-Regal          56
# 92777     3235         NEWISH-Honda-Accord          94
# ...        ...                         ...         ...
# 325677   10942          OLDISH-Honda-Pilot          37
# 476113   21900  OLDISH-Chevrolet-Silverado          35
# 736585   21994        OLDISH-Nissan-Altima          11
# 746973   14700        NEWISH-Jeep-Cherokee           8
# 137486   22532          OLDISH-Ford-Escape          33
# 624696    7569    NEWISH-Cadillac-Escalade          76
# 417056   17505            OLDISH-Ford-Edge          31
# 254423   16021    OLDISH-Cadillac-Escalade          77
# 743325   19651        NEWISH-Honda-Odyssey          12
# 614233    6262        OLDISH-Honda-Odyssey          13
# 560244   16437       OLDISH-Subaru-Outback          61
# 503642   21935            OLDISH-Volvo-240          27
# 664509   14657         NEWISH-Cadillac-XT5          68
# 48625    15551     OLDISH-Chevrolet-Camaro          67
# 250465    7515            OLDISH-Dodge-Ram          65
# 749485   18228   OLDISH-Chevrolet-Traverse          89
# 99662    20337    OLDISH-Chrysler-Pacifica          47
# 667089   13028             OLDISH-BMW-430i          51
# 314833    1879      OLDISH-Chevrolet-Tahoe          55
# 62601    12452   NEWISH-Chevrolet-Suburban          44
# 269910    6226          NEWISH-Ford-Fusion          72
# 261341    9092      OLDISH-Hyundai-Elantra          71
# 306601    7477      OLDISH-Volkswagen-Golf          29
# 381503   12397  NEWISH-Chevrolet-Silverado          34
# 738283    9480          NEWISH-Nissan-Leaf          92
# 299236   12410         NEWISH-Chrysler-200          62
# 722711   13475     NEWISH-Volkswagen-Jetta          90
# 669388   26791       NEWISH-Toyota-Corrola          40
# 709973    5013         OLDISH-Honda-Accord          95
# 397253   15931          NEWISH-Honda-Pilot          36
#
# [100 rows x 3 columns]

# %%
full_df = pd.DataFrame(columns=['ITEM_ID','FAV'])

for i in range(NUM_CLUSTERS):
    tmp_df  = int_expanded_df[int_expanded_df.FAV_CLUSTER == i][['ITEM_ID','FAV']].sample(1)
    full_df = pd.concat([full_df, tmp_df])
ranking_item_df = shuffle(full_df)
ranking_item_list = ranking_item_df['ITEM_ID'].values.astype(str).tolist()
ranking_item_df.head()
# Out:
#        ITEM_ID                        FAV
# 656811   24821            OLDISH-BMW-430i
# 749166   28108            OLDISH-BMW-330i
# 58590    20861  NEWISH-Chevrolet-Suburban
# 749383   25620        OLDISH-Toyota-Camry
# 592259   20193           NEWISH-Volvo-240

# %%
def print_ranking_target_df(user_id, input_df, target_cluster):
    print('\nRanking for user: {}'.format(user_id))
    
    _input_list = input_df['ITEM_ID'].values.astype(str).tolist()
    
    personalized_ranking_response = personalize_runtime.get_personalized_ranking(
        campaignArn = ranking_arn, userId = str(user_id), inputList = _input_list)
    
    i = 0
    _rank = len(_input_list)
    for item in personalized_ranking_response['personalizedRanking']:
        item_id = item['itemId']
        tmp = int_expanded_df[int_expanded_df.ITEM_ID == int(item_id)].iloc[0]
        _fav_cluster = tmp['FAV_CLUSTER']
        if (target_cluster == _fav_cluster) & (_rank == len(_input_list)):
            _rank = i
        print('Id: {}, Make: {}, Model: {}, Year: {}, Fav: {}'.format(item_id,
         tmp['MAKE'], tmp['MODEL'], tmp['YEAR'], tmp['FAV']))
        i += 1
    return _rank

# %%
full_df = pd.DataFrame(columns=['ITEM_ID','FAV','FAV_CLUSTER'])

random_item_df   = shuffle(int_expanded_df[['ITEM_ID','FAV', 'FAV_CLUSTER']].sample(25))
random_item_list = random_item_df['ITEM_ID'].values.astype(str).tolist()
random_item_df.head()
# Out:
#         ITEM_ID                         FAV  FAV_CLUSTER
# 258220    21042      OLDISH-Hyundai-Elantra           71
# 654781    16728            NEWISH-Ford-F150           38
# 738965    31119            OLDISH-Volvo-V60           81
# 646754    22499  OLDISH-Chevrolet-Silverado           35
# 329913    26998          OLDISH-Honda-Pilot           37

# %% [markdown]
# #### Try personalized ranking on a curated set of items with each car cluster covered
# Here we take a curated set of items, with one item for each car cluster. Personalize
# should be able to re-rank in such a way that the specific item that would best match
# the user rises to the 0th position.

# %%
if is_campaign_active(ranking_arn):
    rank_total = 0
    for i in range(NUM_CLUSTERS):
        user_fav = ranking_user_df.iloc[i]['FAV']
        user_fav_cluster = ranking_user_df.iloc[i]['FAV_CLUSTER']
        print('\nRanking for user that prefers: {}'.format(user_fav))
        rank = print_ranking_target_df(ranking_user_list[i], ranking_item_df, user_fav_cluster)
        if (random_item_df.shape[0] == rank):
            print('**desired cluster was not found in the item set')
            rank = 0 # reset to not penalize when no item was available
        else:
            print('**rank {}'.format(rank))
        rank_total += rank

    print('\nRank average: {:.2f}'.format(rank_total/len(ranking_item_list)))
else:
    print('Personalized ranking campaign not active: {}'.format(ranking_arn))
# Out:
# Ranking for user that prefers: NEWISH-Chevrolet-Traverse
#
# Ranking for user: 14548
# Id: 24271, Make: Chevrolet, Model: Traverse, Year: 2015, Fav: NEWISH-Chevrolet-Traverse
# Id: 20159, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 20902, Make: Nissan, Model: Altima, Year: 2016, Fav: NEWISH-Nissan-Altima
# Id: 27015, Make: Nissan, Model: Altima, Year: 2013, Fav: OLDISH-Nissan-Altima
# Id: 16182, Make: Dodge, Model: Caravan, Year: 2014, Fav: NEWISH-Dodge-Caravan
# Id: 28609, Make: Buick, Model: LaCrosse, Year: 2013, Fav: OLDISH-Buick-LaCrosse
# Id: 21081, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 24972, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 22501, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 28128, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 31508, Make: Chevrolet, Model: Silverado, Year: 2016, Fav: NEWISH-Chevrolet-Silverado
# Id: 33936, Make: Toyota, Model: Prius, Year: 2012, Fav: OLDISH-Toyota-Prius
# Id: 24303, Make: Buick, Model: Regal, Year: 2010, Fav: OLDISH-Buick-Regal
# Id: 20528, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 23343, Make: Dodge, Model: Caravan, Year: 2013, Fav: OLDISH-Dodge-Caravan
# Id: 20193, Make: Volvo, Model: 240, Year: 2017, Fav: NEWISH-Volvo-240
# Id: 29016, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 30730, Make: Ford, Model: Escape, Year: 2016, Fav: NEWISH-Ford-Escape
# Id: 27449, Make: BMW, Model: 330i, Year: 2015, Fav: NEWISH-BMW-330i
# Id: 17753, Make: Ford, Model: Fusion, Year: 2015, Fav: NEWISH-Ford-Fusion
# Id: 22204, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 24594, Make: Ford, Model: Expedition, Year: 2015, Fav: NEWISH-Ford-Expedition
# Id: 22151, Make: Cadillac, Model: XT5, Year: 2017, Fav: NEWISH-Cadillac-XT5
# Id: 31420, Make: GMC, Model: Yukon, Year: 2013, Fav: OLDISH-GMC-Yukon
# Id: 24714, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 22736, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 37609, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 24821, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 22766, Make: Buick, Model: Enclave, Year: 2016, Fav: NEWISH-Buick-Enclave
# Id: 23152, Make: Volkswagen, Model: Jetta, Year: 2015, Fav: NEWISH-Volkswagen-Jetta
# Id: 26379, Make: Volvo, Model: 240, Year: 2012, Fav: OLDISH-Volvo-240
# Id: 32985, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 18353, Make: Chevrolet, Model: Camaro, Year: 2015, Fav: NEWISH-Chevrolet-Camaro
# Id: 28108, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 20550, Make: GMC, Model: Acadia, Year: 2017, Fav: NEWISH-GMC-Acadia
# Id: 20041, Make: Ford, Model: F150, Year: 2011, Fav: OLDISH-Ford-F150
# Id: 28293, Make: Cadillac, Model: Escalade, Year: 2010, Fav: OLDISH-Cadillac-Escalade
# Id: 30433, Make: GMC, Model: Yukon, Year: 2015, Fav: NEWISH-GMC-Yukon
# Id: 26553, Make: Buick, Model: Enclave, Year: 2012, Fav: OLDISH-Buick-Enclave
# Id: 26657, Make: BMW, Model: 430i, Year: 2014, Fav: NEWISH-BMW-430i
# Id: 25043, Make: Buick, Model: LaCrosse, Year: 2015, Fav: NEWISH-Buick-LaCrosse
# Id: 27166, Make: Jeep, Model: Grand Cherokee, Year: 2015, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 24240, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 23740, Make: Dodge, Model: Durango, Year: 2010, Fav: OLDISH-Dodge-Durango
# Id: 19217, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 16028, Make: Jeep, Model: Cherokee, Year: 2017, Fav: NEWISH-Jeep-Cherokee
# Id: 28437, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 12211, Make: Toyota, Model: Rav4, Year: 2012, Fav: OLDISH-Toyota-Rav4
# Id: 22896, Make: Dodge, Model: Durango, Year: 2017, Fav: NEWISH-Dodge-Durango
# Id: 28345, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 19799, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 18528, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 25272, Make: Chevrolet, Model: Tahoe, Year: 2015, Fav: NEWISH-Chevrolet-Tahoe
# Id: 31391, Make: Cadillac, Model: XT5, Year: 2011, Fav: OLDISH-Cadillac-XT5
# Id: 25774, Make: Honda, Model: Civic, Year: 2015, Fav: NEWISH-Honda-Civic
# Id: 21633, Make: Volkswagen, Model: Jetta, Year: 2013, Fav: OLDISH-Volkswagen-Jetta
# Id: 32162, Make: Toyota, Model: Sienna, Year: 2015, Fav: NEWISH-Toyota-Sienna
# Id: 25620, Make: Toyota, Model: Camry, Year: 2012, Fav: OLDISH-Toyota-Camry
# Id: 27257, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 24082, Make: Toyota, Model: Camry, Year: 2014, Fav: NEWISH-Toyota-Camry
# Id: 26213, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 20728, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 24227, Make: Cadillac, Model: Escalade, Year: 2014, Fav: NEWISH-Cadillac-Escalade
# Id: 20959, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 24042, Make: Chrysler, Model: 300, Year: 2015, Fav: NEWISH-Chrysler-300
# Id: 19348, Make: Nissan, Model: Leaf, Year: 2010, Fav: OLDISH-Nissan-Leaf
# Id: 20300, Make: Ford, Model: Escape, Year: 2013, Fav: OLDISH-Ford-Escape
# Id: 27564, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 36127, Make: Ford, Model: Edge, Year: 2011, Fav: OLDISH-Ford-Edge
# Id: 35049, Make: Toyota, Model: Corrola, Year: 2013, Fav: OLDISH-Toyota-Corrola
# Id: 28956, Make: Ford, Model: F150, Year: 2016, Fav: NEWISH-Ford-F150
# Id: 25339, Make: Chevrolet, Model: Traverse, Year: 2013, Fav: OLDISH-Chevrolet-Traverse
# Id: 21895, Make: Ford, Model: Mustang, Year: 2016, Fav: NEWISH-Ford-Mustang
# Id: 27684, Make: Honda, Model: Civic, Year: 2012, Fav: OLDISH-Honda-Civic
# Id: 22019, Make: Chevrolet, Model: Silverado, Year: 2012, Fav: OLDISH-Chevrolet-Silverado
# Id: 27063, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 21042, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 28549, Make: Chrysler, Model: Pacifica, Year: 2015, Fav: NEWISH-Chrysler-Pacifica
# Id: 22739, Make: Chevrolet, Model: Suburban, Year: 2011, Fav: OLDISH-Chevrolet-Suburban
# Id: 25784, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 23032, Make: Jeep, Model: Cherokee, Year: 2013, Fav: OLDISH-Jeep-Cherokee
# Id: 23557, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 29557, Make: Toyota, Model: Sienna, Year: 2012, Fav: OLDISH-Toyota-Sienna
# Id: 23823, Make: Ford, Model: Explorer, Year: 2011, Fav: OLDISH-Ford-Explorer
# Id: 21986, Make: Honda, Model: Accord, Year: 2015, Fav: NEWISH-Honda-Accord
# Id: 26723, Make: Dodge, Model: Ram, Year: 2011, Fav: OLDISH-Dodge-Ram
# Id: 25811, Make: Honda, Model: Odyssey, Year: 2013, Fav: OLDISH-Honda-Odyssey
# Id: 20861, Make: Chevrolet, Model: Suburban, Year: 2015, Fav: NEWISH-Chevrolet-Suburban
# Id: 23066, Make: Ford, Model: Edge, Year: 2015, Fav: NEWISH-Ford-Edge
# Id: 24647, Make: Volvo, Model: V60, Year: 2010, Fav: OLDISH-Volvo-V60
# Id: 26750, Make: Toyota, Model: Prius, Year: 2018, Fav: NEWISH-Toyota-Prius
# Id: 21915, Make: Ford, Model: Expedition, Year: 2013, Fav: OLDISH-Ford-Expedition
# Id: 25337, Make: Chrysler, Model: 200, Year: 2014, Fav: NEWISH-Chrysler-200
# Id: 27979, Make: Chevrolet, Model: Camaro, Year: 2012, Fav: OLDISH-Chevrolet-Camaro
# Id: 27520, Make: Chrysler, Model: Pacifica, Year: 2013, Fav: OLDISH-Chrysler-Pacifica
# Id: 18658, Make: Chrysler, Model: 200, Year: 2012, Fav: OLDISH-Chrysler-200
# Id: 22238, Make: Hyundai, Model: Santa Fe, Year: 2010, Fav: OLDISH-Hyundai-Santa Fe
# Id: 33642, Make: Toyota, Model: Corrola, Year: 2016, Fav: NEWISH-Toyota-Corrola
# Id: 24873, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 26429, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# **rank 0
#
# Ranking for user that prefers: OLDISH-Volkswagen-Tiguan
#
# Ranking for user: 8358
# Id: 21081, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 20902, Make: Nissan, Model: Altima, Year: 2016, Fav: NEWISH-Nissan-Altima
# Id: 27449, Make: BMW, Model: 330i, Year: 2015, Fav: NEWISH-BMW-330i
# Id: 26553, Make: Buick, Model: Enclave, Year: 2012, Fav: OLDISH-Buick-Enclave
# Id: 22501, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 24271, Make: Chevrolet, Model: Traverse, Year: 2015, Fav: NEWISH-Chevrolet-Traverse
# Id: 21633, Make: Volkswagen, Model: Jetta, Year: 2013, Fav: OLDISH-Volkswagen-Jetta
# Id: 20193, Make: Volvo, Model: 240, Year: 2017, Fav: NEWISH-Volvo-240
# Id: 20159, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 26213, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 23740, Make: Dodge, Model: Durango, Year: 2010, Fav: OLDISH-Dodge-Durango
# Id: 24082, Make: Toyota, Model: Camry, Year: 2014, Fav: NEWISH-Toyota-Camry
# Id: 31420, Make: GMC, Model: Yukon, Year: 2013, Fav: OLDISH-GMC-Yukon
# Id: 28609, Make: Buick, Model: LaCrosse, Year: 2013, Fav: OLDISH-Buick-LaCrosse
# Id: 23152, Make: Volkswagen, Model: Jetta, Year: 2015, Fav: NEWISH-Volkswagen-Jetta
# Id: 27015, Make: Nissan, Model: Altima, Year: 2013, Fav: OLDISH-Nissan-Altima
# Id: 29016, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 24042, Make: Chrysler, Model: 300, Year: 2015, Fav: NEWISH-Chrysler-300
# Id: 27166, Make: Jeep, Model: Grand Cherokee, Year: 2015, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 20550, Make: GMC, Model: Acadia, Year: 2017, Fav: NEWISH-GMC-Acadia
# Id: 22766, Make: Buick, Model: Enclave, Year: 2016, Fav: NEWISH-Buick-Enclave
# Id: 19799, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 20959, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 26379, Make: Volvo, Model: 240, Year: 2012, Fav: OLDISH-Volvo-240
# Id: 22151, Make: Cadillac, Model: XT5, Year: 2017, Fav: NEWISH-Cadillac-XT5
# Id: 24240, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 28345, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 17753, Make: Ford, Model: Fusion, Year: 2015, Fav: NEWISH-Ford-Fusion
# Id: 32162, Make: Toyota, Model: Sienna, Year: 2015, Fav: NEWISH-Toyota-Sienna
# Id: 24594, Make: Ford, Model: Expedition, Year: 2015, Fav: NEWISH-Ford-Expedition
# Id: 18353, Make: Chevrolet, Model: Camaro, Year: 2015, Fav: NEWISH-Chevrolet-Camaro
# Id: 19348, Make: Nissan, Model: Leaf, Year: 2010, Fav: OLDISH-Nissan-Leaf
# Id: 25043, Make: Buick, Model: LaCrosse, Year: 2015, Fav: NEWISH-Buick-LaCrosse
# Id: 25620, Make: Toyota, Model: Camry, Year: 2012, Fav: OLDISH-Toyota-Camry
# Id: 22736, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 28549, Make: Chrysler, Model: Pacifica, Year: 2015, Fav: NEWISH-Chrysler-Pacifica
# Id: 32985, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 25339, Make: Chevrolet, Model: Traverse, Year: 2013, Fav: OLDISH-Chevrolet-Traverse
# Id: 20528, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 36127, Make: Ford, Model: Edge, Year: 2011, Fav: OLDISH-Ford-Edge
# Id: 30433, Make: GMC, Model: Yukon, Year: 2015, Fav: NEWISH-GMC-Yukon
# Id: 33936, Make: Toyota, Model: Prius, Year: 2012, Fav: OLDISH-Toyota-Prius
# Id: 16028, Make: Jeep, Model: Cherokee, Year: 2017, Fav: NEWISH-Jeep-Cherokee
# Id: 19217, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 26657, Make: BMW, Model: 430i, Year: 2014, Fav: NEWISH-BMW-430i
# Id: 27257, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 28108, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 23032, Make: Jeep, Model: Cherokee, Year: 2013, Fav: OLDISH-Jeep-Cherokee
# Id: 28293, Make: Cadillac, Model: Escalade, Year: 2010, Fav: OLDISH-Cadillac-Escalade
# Id: 29557, Make: Toyota, Model: Sienna, Year: 2012, Fav: OLDISH-Toyota-Sienna
# Id: 12211, Make: Toyota, Model: Rav4, Year: 2012, Fav: OLDISH-Toyota-Rav4
# Id: 22896, Make: Dodge, Model: Durango, Year: 2017, Fav: NEWISH-Dodge-Durango
# Id: 27520, Make: Chrysler, Model: Pacifica, Year: 2013, Fav: OLDISH-Chrysler-Pacifica
# Id: 16182, Make: Dodge, Model: Caravan, Year: 2014, Fav: NEWISH-Dodge-Caravan
# Id: 25811, Make: Honda, Model: Odyssey, Year: 2013, Fav: OLDISH-Honda-Odyssey
# Id: 20300, Make: Ford, Model: Escape, Year: 2013, Fav: OLDISH-Ford-Escape
# Id: 24227, Make: Cadillac, Model: Escalade, Year: 2014, Fav: NEWISH-Cadillac-Escalade
# Id: 31508, Make: Chevrolet, Model: Silverado, Year: 2016, Fav: NEWISH-Chevrolet-Silverado
# Id: 22019, Make: Chevrolet, Model: Silverado, Year: 2012, Fav: OLDISH-Chevrolet-Silverado
# Id: 24714, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 18528, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 25784, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 22204, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 37609, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 20041, Make: Ford, Model: F150, Year: 2011, Fav: OLDISH-Ford-F150
# Id: 24972, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 27979, Make: Chevrolet, Model: Camaro, Year: 2012, Fav: OLDISH-Chevrolet-Camaro
# Id: 30730, Make: Ford, Model: Escape, Year: 2016, Fav: NEWISH-Ford-Escape
# Id: 20728, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 18658, Make: Chrysler, Model: 200, Year: 2012, Fav: OLDISH-Chrysler-200
# Id: 35049, Make: Toyota, Model: Corrola, Year: 2013, Fav: OLDISH-Toyota-Corrola
# Id: 28128, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 23066, Make: Ford, Model: Edge, Year: 2015, Fav: NEWISH-Ford-Edge
# Id: 27564, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 25774, Make: Honda, Model: Civic, Year: 2015, Fav: NEWISH-Honda-Civic
# Id: 24303, Make: Buick, Model: Regal, Year: 2010, Fav: OLDISH-Buick-Regal
# Id: 24647, Make: Volvo, Model: V60, Year: 2010, Fav: OLDISH-Volvo-V60
# Id: 28437, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 23823, Make: Ford, Model: Explorer, Year: 2011, Fav: OLDISH-Ford-Explorer
# Id: 27684, Make: Honda, Model: Civic, Year: 2012, Fav: OLDISH-Honda-Civic
# Id: 33642, Make: Toyota, Model: Corrola, Year: 2016, Fav: NEWISH-Toyota-Corrola
# Id: 22238, Make: Hyundai, Model: Santa Fe, Year: 2010, Fav: OLDISH-Hyundai-Santa Fe
# Id: 25272, Make: Chevrolet, Model: Tahoe, Year: 2015, Fav: NEWISH-Chevrolet-Tahoe
# Id: 27063, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 21895, Make: Ford, Model: Mustang, Year: 2016, Fav: NEWISH-Ford-Mustang
# Id: 26723, Make: Dodge, Model: Ram, Year: 2011, Fav: OLDISH-Dodge-Ram
# Id: 21986, Make: Honda, Model: Accord, Year: 2015, Fav: NEWISH-Honda-Accord
# Id: 23557, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 21042, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 26750, Make: Toyota, Model: Prius, Year: 2018, Fav: NEWISH-Toyota-Prius
# Id: 22739, Make: Chevrolet, Model: Suburban, Year: 2011, Fav: OLDISH-Chevrolet-Suburban
# Id: 24821, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 28956, Make: Ford, Model: F150, Year: 2016, Fav: NEWISH-Ford-F150
# Id: 25337, Make: Chrysler, Model: 200, Year: 2014, Fav: NEWISH-Chrysler-200
# Id: 21915, Make: Ford, Model: Expedition, Year: 2013, Fav: OLDISH-Ford-Expedition
# Id: 23343, Make: Dodge, Model: Caravan, Year: 2013, Fav: OLDISH-Dodge-Caravan
# Id: 20861, Make: Chevrolet, Model: Suburban, Year: 2015, Fav: NEWISH-Chevrolet-Suburban
# Id: 31391, Make: Cadillac, Model: XT5, Year: 2011, Fav: OLDISH-Cadillac-XT5
# Id: 26429, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 24873, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# **rank 0
#
# Ranking for user that prefers: OLDISH-Volkswagen-Jetta
#
# Ranking for user: 20635
# Id: 21633, Make: Volkswagen, Model: Jetta, Year: 2013, Fav: OLDISH-Volkswagen-Jetta
# Id: 19799, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 20959, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 29557, Make: Toyota, Model: Sienna, Year: 2012, Fav: OLDISH-Toyota-Sienna
# Id: 23152, Make: Volkswagen, Model: Jetta, Year: 2015, Fav: NEWISH-Volkswagen-Jetta
# Id: 23032, Make: Jeep, Model: Cherokee, Year: 2013, Fav: OLDISH-Jeep-Cherokee
# Id: 19348, Make: Nissan, Model: Leaf, Year: 2010, Fav: OLDISH-Nissan-Leaf
# Id: 22501, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 27449, Make: BMW, Model: 330i, Year: 2015, Fav: NEWISH-BMW-330i
# Id: 22766, Make: Buick, Model: Enclave, Year: 2016, Fav: NEWISH-Buick-Enclave
# Id: 28108, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 21986, Make: Honda, Model: Accord, Year: 2015, Fav: NEWISH-Honda-Accord
# Id: 20550, Make: GMC, Model: Acadia, Year: 2017, Fav: NEWISH-GMC-Acadia
# Id: 21915, Make: Ford, Model: Expedition, Year: 2013, Fav: OLDISH-Ford-Expedition
# Id: 22204, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 30433, Make: GMC, Model: Yukon, Year: 2015, Fav: NEWISH-GMC-Yukon
# Id: 29016, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 21081, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 27166, Make: Jeep, Model: Grand Cherokee, Year: 2015, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 23740, Make: Dodge, Model: Durango, Year: 2010, Fav: OLDISH-Dodge-Durango
# Id: 24082, Make: Toyota, Model: Camry, Year: 2014, Fav: NEWISH-Toyota-Camry
# Id: 27015, Make: Nissan, Model: Altima, Year: 2013, Fav: OLDISH-Nissan-Altima
# Id: 32162, Make: Toyota, Model: Sienna, Year: 2015, Fav: NEWISH-Toyota-Sienna
# Id: 24042, Make: Chrysler, Model: 300, Year: 2015, Fav: NEWISH-Chrysler-300
# Id: 21042, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 28293, Make: Cadillac, Model: Escalade, Year: 2010, Fav: OLDISH-Cadillac-Escalade
# Id: 18528, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 18353, Make: Chevrolet, Model: Camaro, Year: 2015, Fav: NEWISH-Chevrolet-Camaro
# Id: 28956, Make: Ford, Model: F150, Year: 2016, Fav: NEWISH-Ford-F150
# Id: 24647, Make: Volvo, Model: V60, Year: 2010, Fav: OLDISH-Volvo-V60
# Id: 24594, Make: Ford, Model: Expedition, Year: 2015, Fav: NEWISH-Ford-Expedition
# Id: 25620, Make: Toyota, Model: Camry, Year: 2012, Fav: OLDISH-Toyota-Camry
# Id: 22736, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 20902, Make: Nissan, Model: Altima, Year: 2016, Fav: NEWISH-Nissan-Altima
# Id: 27564, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 20159, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 26429, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 25339, Make: Chevrolet, Model: Traverse, Year: 2013, Fav: OLDISH-Chevrolet-Traverse
# Id: 20861, Make: Chevrolet, Model: Suburban, Year: 2015, Fav: NEWISH-Chevrolet-Suburban
# Id: 26553, Make: Buick, Model: Enclave, Year: 2012, Fav: OLDISH-Buick-Enclave
# Id: 24227, Make: Cadillac, Model: Escalade, Year: 2014, Fav: NEWISH-Cadillac-Escalade
# Id: 26379, Make: Volvo, Model: 240, Year: 2012, Fav: OLDISH-Volvo-240
# Id: 24271, Make: Chevrolet, Model: Traverse, Year: 2015, Fav: NEWISH-Chevrolet-Traverse
# Id: 19217, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 24240, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 16182, Make: Dodge, Model: Caravan, Year: 2014, Fav: NEWISH-Dodge-Caravan
# Id: 31420, Make: GMC, Model: Yukon, Year: 2013, Fav: OLDISH-GMC-Yukon
# Id: 16028, Make: Jeep, Model: Cherokee, Year: 2017, Fav: NEWISH-Jeep-Cherokee
# Id: 27063, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 25774, Make: Honda, Model: Civic, Year: 2015, Fav: NEWISH-Honda-Civic
# Id: 24714, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 37609, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 12211, Make: Toyota, Model: Rav4, Year: 2012, Fav: OLDISH-Toyota-Rav4
# Id: 22896, Make: Dodge, Model: Durango, Year: 2017, Fav: NEWISH-Dodge-Durango
# Id: 20728, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 31508, Make: Chevrolet, Model: Silverado, Year: 2016, Fav: NEWISH-Chevrolet-Silverado
# Id: 20193, Make: Volvo, Model: 240, Year: 2017, Fav: NEWISH-Volvo-240
# Id: 31391, Make: Cadillac, Model: XT5, Year: 2011, Fav: OLDISH-Cadillac-XT5
# Id: 25811, Make: Honda, Model: Odyssey, Year: 2013, Fav: OLDISH-Honda-Odyssey
# Id: 27979, Make: Chevrolet, Model: Camaro, Year: 2012, Fav: OLDISH-Chevrolet-Camaro
# Id: 22019, Make: Chevrolet, Model: Silverado, Year: 2012, Fav: OLDISH-Chevrolet-Silverado
# Id: 33642, Make: Toyota, Model: Corrola, Year: 2016, Fav: NEWISH-Toyota-Corrola
# Id: 36127, Make: Ford, Model: Edge, Year: 2011, Fav: OLDISH-Ford-Edge
# Id: 25043, Make: Buick, Model: LaCrosse, Year: 2015, Fav: NEWISH-Buick-LaCrosse
# Id: 23066, Make: Ford, Model: Edge, Year: 2015, Fav: NEWISH-Ford-Edge
# Id: 28609, Make: Buick, Model: LaCrosse, Year: 2013, Fav: OLDISH-Buick-LaCrosse
# Id: 33936, Make: Toyota, Model: Prius, Year: 2012, Fav: OLDISH-Toyota-Prius
# Id: 25337, Make: Chrysler, Model: 200, Year: 2014, Fav: NEWISH-Chrysler-200
# Id: 25784, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 21895, Make: Ford, Model: Mustang, Year: 2016, Fav: NEWISH-Ford-Mustang
# Id: 27257, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 18658, Make: Chrysler, Model: 200, Year: 2012, Fav: OLDISH-Chrysler-200
# Id: 28345, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 30730, Make: Ford, Model: Escape, Year: 2016, Fav: NEWISH-Ford-Escape
# Id: 32985, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 35049, Make: Toyota, Model: Corrola, Year: 2013, Fav: OLDISH-Toyota-Corrola
# Id: 20528, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 22151, Make: Cadillac, Model: XT5, Year: 2017, Fav: NEWISH-Cadillac-XT5
# Id: 28128, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 17753, Make: Ford, Model: Fusion, Year: 2015, Fav: NEWISH-Ford-Fusion
# Id: 27520, Make: Chrysler, Model: Pacifica, Year: 2013, Fav: OLDISH-Chrysler-Pacifica
# Id: 26750, Make: Toyota, Model: Prius, Year: 2018, Fav: NEWISH-Toyota-Prius
# Id: 20041, Make: Ford, Model: F150, Year: 2011, Fav: OLDISH-Ford-F150
# Id: 23343, Make: Dodge, Model: Caravan, Year: 2013, Fav: OLDISH-Dodge-Caravan
# Id: 22238, Make: Hyundai, Model: Santa Fe, Year: 2010, Fav: OLDISH-Hyundai-Santa Fe
# Id: 24972, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 24821, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 27684, Make: Honda, Model: Civic, Year: 2012, Fav: OLDISH-Honda-Civic
# Id: 24873, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 25272, Make: Chevrolet, Model: Tahoe, Year: 2015, Fav: NEWISH-Chevrolet-Tahoe
# Id: 23557, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 28437, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 26213, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 20300, Make: Ford, Model: Escape, Year: 2013, Fav: OLDISH-Ford-Escape
# Id: 22739, Make: Chevrolet, Model: Suburban, Year: 2011, Fav: OLDISH-Chevrolet-Suburban
# Id: 26723, Make: Dodge, Model: Ram, Year: 2011, Fav: OLDISH-Dodge-Ram
# Id: 28549, Make: Chrysler, Model: Pacifica, Year: 2015, Fav: NEWISH-Chrysler-Pacifica
# Id: 24303, Make: Buick, Model: Regal, Year: 2010, Fav: OLDISH-Buick-Regal
# Id: 26657, Make: BMW, Model: 430i, Year: 2014, Fav: NEWISH-BMW-430i
# Id: 23823, Make: Ford, Model: Explorer, Year: 2011, Fav: OLDISH-Ford-Explorer
# **rank 0
#
# Ranking for user that prefers: NEWISH-Buick-Enclave
#
# Ranking for user: 8768
# Id: 22766, Make: Buick, Model: Enclave, Year: 2016, Fav: NEWISH-Buick-Enclave
# Id: 26553, Make: Buick, Model: Enclave, Year: 2012, Fav: OLDISH-Buick-Enclave
# Id: 23152, Make: Volkswagen, Model: Jetta, Year: 2015, Fav: NEWISH-Volkswagen-Jetta
# Id: 29016, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 25339, Make: Chevrolet, Model: Traverse, Year: 2013, Fav: OLDISH-Chevrolet-Traverse
# Id: 23740, Make: Dodge, Model: Durango, Year: 2010, Fav: OLDISH-Dodge-Durango
# Id: 20902, Make: Nissan, Model: Altima, Year: 2016, Fav: NEWISH-Nissan-Altima
# Id: 20959, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 24082, Make: Toyota, Model: Camry, Year: 2014, Fav: NEWISH-Toyota-Camry
# Id: 22736, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 19799, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 23032, Make: Jeep, Model: Cherokee, Year: 2013, Fav: OLDISH-Jeep-Cherokee
# Id: 25811, Make: Honda, Model: Odyssey, Year: 2013, Fav: OLDISH-Honda-Odyssey
# Id: 28108, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 19348, Make: Nissan, Model: Leaf, Year: 2010, Fav: OLDISH-Nissan-Leaf
# Id: 24042, Make: Chrysler, Model: 300, Year: 2015, Fav: NEWISH-Chrysler-300
# Id: 25620, Make: Toyota, Model: Camry, Year: 2012, Fav: OLDISH-Toyota-Camry
# Id: 27449, Make: BMW, Model: 330i, Year: 2015, Fav: NEWISH-BMW-330i
# Id: 32162, Make: Toyota, Model: Sienna, Year: 2015, Fav: NEWISH-Toyota-Sienna
# Id: 18658, Make: Chrysler, Model: 200, Year: 2012, Fav: OLDISH-Chrysler-200
# Id: 16028, Make: Jeep, Model: Cherokee, Year: 2017, Fav: NEWISH-Jeep-Cherokee
# Id: 29557, Make: Toyota, Model: Sienna, Year: 2012, Fav: OLDISH-Toyota-Sienna
# Id: 30730, Make: Ford, Model: Escape, Year: 2016, Fav: NEWISH-Ford-Escape
# Id: 21081, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 21633, Make: Volkswagen, Model: Jetta, Year: 2013, Fav: OLDISH-Volkswagen-Jetta
# Id: 19217, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 21986, Make: Honda, Model: Accord, Year: 2015, Fav: NEWISH-Honda-Accord
# Id: 22238, Make: Hyundai, Model: Santa Fe, Year: 2010, Fav: OLDISH-Hyundai-Santa Fe
# Id: 27257, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 17753, Make: Ford, Model: Fusion, Year: 2015, Fav: NEWISH-Ford-Fusion
# Id: 28609, Make: Buick, Model: LaCrosse, Year: 2013, Fav: OLDISH-Buick-LaCrosse
# Id: 27166, Make: Jeep, Model: Grand Cherokee, Year: 2015, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 20193, Make: Volvo, Model: 240, Year: 2017, Fav: NEWISH-Volvo-240
# Id: 24227, Make: Cadillac, Model: Escalade, Year: 2014, Fav: NEWISH-Cadillac-Escalade
# Id: 32985, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 18528, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 26657, Make: BMW, Model: 430i, Year: 2014, Fav: NEWISH-BMW-430i
# Id: 12211, Make: Toyota, Model: Rav4, Year: 2012, Fav: OLDISH-Toyota-Rav4
# Id: 22896, Make: Dodge, Model: Durango, Year: 2017, Fav: NEWISH-Dodge-Durango
# Id: 21042, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 22501, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 24594, Make: Ford, Model: Expedition, Year: 2015, Fav: NEWISH-Ford-Expedition
# Id: 37609, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 25774, Make: Honda, Model: Civic, Year: 2015, Fav: NEWISH-Honda-Civic
# Id: 25043, Make: Buick, Model: LaCrosse, Year: 2015, Fav: NEWISH-Buick-LaCrosse
# Id: 27684, Make: Honda, Model: Civic, Year: 2012, Fav: OLDISH-Honda-Civic
# Id: 25784, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 24714, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 20728, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 27015, Make: Nissan, Model: Altima, Year: 2013, Fav: OLDISH-Nissan-Altima
# Id: 35049, Make: Toyota, Model: Corrola, Year: 2013, Fav: OLDISH-Toyota-Corrola
# Id: 28293, Make: Cadillac, Model: Escalade, Year: 2010, Fav: OLDISH-Cadillac-Escalade
# Id: 20300, Make: Ford, Model: Escape, Year: 2013, Fav: OLDISH-Ford-Escape
# Id: 24821, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 31391, Make: Cadillac, Model: XT5, Year: 2011, Fav: OLDISH-Cadillac-XT5
# Id: 28956, Make: Ford, Model: F150, Year: 2016, Fav: NEWISH-Ford-F150
# Id: 20528, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 31420, Make: GMC, Model: Yukon, Year: 2013, Fav: OLDISH-GMC-Yukon
# Id: 33642, Make: Toyota, Model: Corrola, Year: 2016, Fav: NEWISH-Toyota-Corrola
# Id: 20550, Make: GMC, Model: Acadia, Year: 2017, Fav: NEWISH-GMC-Acadia
# Id: 22739, Make: Chevrolet, Model: Suburban, Year: 2011, Fav: OLDISH-Chevrolet-Suburban
# Id: 21915, Make: Ford, Model: Expedition, Year: 2013, Fav: OLDISH-Ford-Expedition
# Id: 24271, Make: Chevrolet, Model: Traverse, Year: 2015, Fav: NEWISH-Chevrolet-Traverse
# Id: 30433, Make: GMC, Model: Yukon, Year: 2015, Fav: NEWISH-GMC-Yukon
# Id: 16182, Make: Dodge, Model: Caravan, Year: 2014, Fav: NEWISH-Dodge-Caravan
# Id: 22151, Make: Cadillac, Model: XT5, Year: 2017, Fav: NEWISH-Cadillac-XT5
# Id: 20159, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 26213, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 28549, Make: Chrysler, Model: Pacifica, Year: 2015, Fav: NEWISH-Chrysler-Pacifica
# Id: 26429, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 28437, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 22019, Make: Chevrolet, Model: Silverado, Year: 2012, Fav: OLDISH-Chevrolet-Silverado
# Id: 23343, Make: Dodge, Model: Caravan, Year: 2013, Fav: OLDISH-Dodge-Caravan
# Id: 27979, Make: Chevrolet, Model: Camaro, Year: 2012, Fav: OLDISH-Chevrolet-Camaro
# Id: 24240, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 33936, Make: Toyota, Model: Prius, Year: 2012, Fav: OLDISH-Toyota-Prius
# Id: 28345, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 24647, Make: Volvo, Model: V60, Year: 2010, Fav: OLDISH-Volvo-V60
# Id: 24873, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 27063, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 31508, Make: Chevrolet, Model: Silverado, Year: 2016, Fav: NEWISH-Chevrolet-Silverado
# Id: 26750, Make: Toyota, Model: Prius, Year: 2018, Fav: NEWISH-Toyota-Prius
# Id: 36127, Make: Ford, Model: Edge, Year: 2011, Fav: OLDISH-Ford-Edge
# Id: 25337, Make: Chrysler, Model: 200, Year: 2014, Fav: NEWISH-Chrysler-200
# Id: 23557, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 18353, Make: Chevrolet, Model: Camaro, Year: 2015, Fav: NEWISH-Chevrolet-Camaro
# Id: 23066, Make: Ford, Model: Edge, Year: 2015, Fav: NEWISH-Ford-Edge
# Id: 27564, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 21895, Make: Ford, Model: Mustang, Year: 2016, Fav: NEWISH-Ford-Mustang
# Id: 26379, Make: Volvo, Model: 240, Year: 2012, Fav: OLDISH-Volvo-240
# Id: 20861, Make: Chevrolet, Model: Suburban, Year: 2015, Fav: NEWISH-Chevrolet-Suburban
# Id: 22204, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 24303, Make: Buick, Model: Regal, Year: 2010, Fav: OLDISH-Buick-Regal
# Id: 20041, Make: Ford, Model: F150, Year: 2011, Fav: OLDISH-Ford-F150
# Id: 27520, Make: Chrysler, Model: Pacifica, Year: 2013, Fav: OLDISH-Chrysler-Pacifica
# Id: 26723, Make: Dodge, Model: Ram, Year: 2011, Fav: OLDISH-Dodge-Ram
# Id: 25272, Make: Chevrolet, Model: Tahoe, Year: 2015, Fav: NEWISH-Chevrolet-Tahoe
# Id: 24972, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 28128, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 23823, Make: Ford, Model: Explorer, Year: 2011, Fav: OLDISH-Ford-Explorer
# **rank 0
#
# Ranking for user that prefers: OLDISH-Nissan-Leaf
#
# Ranking for user: 8486
# Id: 20959, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 22766, Make: Buick, Model: Enclave, Year: 2016, Fav: NEWISH-Buick-Enclave
# Id: 23152, Make: Volkswagen, Model: Jetta, Year: 2015, Fav: NEWISH-Volkswagen-Jetta
# Id: 19799, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 21633, Make: Volkswagen, Model: Jetta, Year: 2013, Fav: OLDISH-Volkswagen-Jetta
# Id: 19348, Make: Nissan, Model: Leaf, Year: 2010, Fav: OLDISH-Nissan-Leaf
# Id: 23032, Make: Jeep, Model: Cherokee, Year: 2013, Fav: OLDISH-Jeep-Cherokee
# Id: 24082, Make: Toyota, Model: Camry, Year: 2014, Fav: NEWISH-Toyota-Camry
# Id: 23740, Make: Dodge, Model: Durango, Year: 2010, Fav: OLDISH-Dodge-Durango
# Id: 25339, Make: Chevrolet, Model: Traverse, Year: 2013, Fav: OLDISH-Chevrolet-Traverse
# Id: 29557, Make: Toyota, Model: Sienna, Year: 2012, Fav: OLDISH-Toyota-Sienna
# Id: 21986, Make: Honda, Model: Accord, Year: 2015, Fav: NEWISH-Honda-Accord
# Id: 32162, Make: Toyota, Model: Sienna, Year: 2015, Fav: NEWISH-Toyota-Sienna
# Id: 22736, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 27449, Make: BMW, Model: 330i, Year: 2015, Fav: NEWISH-BMW-330i
# Id: 26553, Make: Buick, Model: Enclave, Year: 2012, Fav: OLDISH-Buick-Enclave
# Id: 24042, Make: Chrysler, Model: 300, Year: 2015, Fav: NEWISH-Chrysler-300
# Id: 28108, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 20902, Make: Nissan, Model: Altima, Year: 2016, Fav: NEWISH-Nissan-Altima
# Id: 25620, Make: Toyota, Model: Camry, Year: 2012, Fav: OLDISH-Toyota-Camry
# Id: 29016, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 25811, Make: Honda, Model: Odyssey, Year: 2013, Fav: OLDISH-Honda-Odyssey
# Id: 16028, Make: Jeep, Model: Cherokee, Year: 2017, Fav: NEWISH-Jeep-Cherokee
# Id: 27166, Make: Jeep, Model: Grand Cherokee, Year: 2015, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 21081, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 18658, Make: Chrysler, Model: 200, Year: 2012, Fav: OLDISH-Chrysler-200
# Id: 25774, Make: Honda, Model: Civic, Year: 2015, Fav: NEWISH-Honda-Civic
# Id: 19217, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 22501, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 21915, Make: Ford, Model: Expedition, Year: 2013, Fav: OLDISH-Ford-Expedition
# Id: 18528, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 27015, Make: Nissan, Model: Altima, Year: 2013, Fav: OLDISH-Nissan-Altima
# Id: 20550, Make: GMC, Model: Acadia, Year: 2017, Fav: NEWISH-GMC-Acadia
# Id: 20159, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 37609, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 25043, Make: Buick, Model: LaCrosse, Year: 2015, Fav: NEWISH-Buick-LaCrosse
# Id: 27257, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 20728, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 22896, Make: Dodge, Model: Durango, Year: 2017, Fav: NEWISH-Dodge-Durango
# Id: 12211, Make: Toyota, Model: Rav4, Year: 2012, Fav: OLDISH-Toyota-Rav4
# Id: 21042, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 25784, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 32985, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 20861, Make: Chevrolet, Model: Suburban, Year: 2015, Fav: NEWISH-Chevrolet-Suburban
# Id: 33642, Make: Toyota, Model: Corrola, Year: 2016, Fav: NEWISH-Toyota-Corrola
# Id: 30433, Make: GMC, Model: Yukon, Year: 2015, Fav: NEWISH-GMC-Yukon
# Id: 28609, Make: Buick, Model: LaCrosse, Year: 2013, Fav: OLDISH-Buick-LaCrosse
# Id: 24647, Make: Volvo, Model: V60, Year: 2010, Fav: OLDISH-Volvo-V60
# Id: 20300, Make: Ford, Model: Escape, Year: 2013, Fav: OLDISH-Ford-Escape
# Id: 30730, Make: Ford, Model: Escape, Year: 2016, Fav: NEWISH-Ford-Escape
# Id: 24714, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 28956, Make: Ford, Model: F150, Year: 2016, Fav: NEWISH-Ford-F150
# Id: 24594, Make: Ford, Model: Expedition, Year: 2015, Fav: NEWISH-Ford-Expedition
# Id: 22238, Make: Hyundai, Model: Santa Fe, Year: 2010, Fav: OLDISH-Hyundai-Santa Fe
# Id: 31420, Make: GMC, Model: Yukon, Year: 2013, Fav: OLDISH-GMC-Yukon
# Id: 16182, Make: Dodge, Model: Caravan, Year: 2014, Fav: NEWISH-Dodge-Caravan
# Id: 22739, Make: Chevrolet, Model: Suburban, Year: 2011, Fav: OLDISH-Chevrolet-Suburban
# Id: 31391, Make: Cadillac, Model: XT5, Year: 2011, Fav: OLDISH-Cadillac-XT5
# Id: 27564, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 22151, Make: Cadillac, Model: XT5, Year: 2017, Fav: NEWISH-Cadillac-XT5
# Id: 20193, Make: Volvo, Model: 240, Year: 2017, Fav: NEWISH-Volvo-240
# Id: 24271, Make: Chevrolet, Model: Traverse, Year: 2015, Fav: NEWISH-Chevrolet-Traverse
# Id: 25337, Make: Chrysler, Model: 200, Year: 2014, Fav: NEWISH-Chrysler-200
# Id: 23066, Make: Ford, Model: Edge, Year: 2015, Fav: NEWISH-Ford-Edge
# Id: 22019, Make: Chevrolet, Model: Silverado, Year: 2012, Fav: OLDISH-Chevrolet-Silverado
# Id: 24227, Make: Cadillac, Model: Escalade, Year: 2014, Fav: NEWISH-Cadillac-Escalade
# Id: 28293, Make: Cadillac, Model: Escalade, Year: 2010, Fav: OLDISH-Cadillac-Escalade
# Id: 28549, Make: Chrysler, Model: Pacifica, Year: 2015, Fav: NEWISH-Chrysler-Pacifica
# Id: 26213, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 33936, Make: Toyota, Model: Prius, Year: 2012, Fav: OLDISH-Toyota-Prius
# Id: 17753, Make: Ford, Model: Fusion, Year: 2015, Fav: NEWISH-Ford-Fusion
# Id: 27979, Make: Chevrolet, Model: Camaro, Year: 2012, Fav: OLDISH-Chevrolet-Camaro
# Id: 27063, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 27684, Make: Honda, Model: Civic, Year: 2012, Fav: OLDISH-Honda-Civic
# Id: 26379, Make: Volvo, Model: 240, Year: 2012, Fav: OLDISH-Volvo-240
# Id: 31508, Make: Chevrolet, Model: Silverado, Year: 2016, Fav: NEWISH-Chevrolet-Silverado
# Id: 35049, Make: Toyota, Model: Corrola, Year: 2013, Fav: OLDISH-Toyota-Corrola
# Id: 18353, Make: Chevrolet, Model: Camaro, Year: 2015, Fav: NEWISH-Chevrolet-Camaro
# Id: 24873, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 36127, Make: Ford, Model: Edge, Year: 2011, Fav: OLDISH-Ford-Edge
# Id: 26657, Make: BMW, Model: 430i, Year: 2014, Fav: NEWISH-BMW-430i
# Id: 27520, Make: Chrysler, Model: Pacifica, Year: 2013, Fav: OLDISH-Chrysler-Pacifica
# Id: 22204, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 20528, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 26429, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 23343, Make: Dodge, Model: Caravan, Year: 2013, Fav: OLDISH-Dodge-Caravan
# Id: 26750, Make: Toyota, Model: Prius, Year: 2018, Fav: NEWISH-Toyota-Prius
# Id: 21895, Make: Ford, Model: Mustang, Year: 2016, Fav: NEWISH-Ford-Mustang
# Id: 23557, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 24821, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 28437, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 28128, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 28345, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 25272, Make: Chevrolet, Model: Tahoe, Year: 2015, Fav: NEWISH-Chevrolet-Tahoe
# Id: 20041, Make: Ford, Model: F150, Year: 2011, Fav: OLDISH-Ford-F150
# Id: 24240, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 24303, Make: Buick, Model: Regal, Year: 2010, Fav: OLDISH-Buick-Regal
# Id: 26723, Make: Dodge, Model: Ram, Year: 2011, Fav: OLDISH-Dodge-Ram
# Id: 24972, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 23823, Make: Ford, Model: Explorer, Year: 2011, Fav: OLDISH-Ford-Explorer
# **rank 5
#
# Ranking for user that prefers: NEWISH-Dodge-Durango
#
# Ranking for user: 11493
# Id: 22766, Make: Buick, Model: Enclave, Year: 2016, Fav: NEWISH-Buick-Enclave
# Id: 26553, Make: Buick, Model: Enclave, Year: 2012, Fav: OLDISH-Buick-Enclave
# Id: 23740, Make: Dodge, Model: Durango, Year: 2010, Fav: OLDISH-Dodge-Durango
# Id: 25339, Make: Chevrolet, Model: Traverse, Year: 2013, Fav: OLDISH-Chevrolet-Traverse
# Id: 20959, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 24082, Make: Toyota, Model: Camry, Year: 2014, Fav: NEWISH-Toyota-Camry
# Id: 23152, Make: Volkswagen, Model: Jetta, Year: 2015, Fav: NEWISH-Volkswagen-Jetta
# Id: 20902, Make: Nissan, Model: Altima, Year: 2016, Fav: NEWISH-Nissan-Altima
# Id: 19348, Make: Nissan, Model: Leaf, Year: 2010, Fav: OLDISH-Nissan-Leaf
# Id: 25620, Make: Toyota, Model: Camry, Year: 2012, Fav: OLDISH-Toyota-Camry
# Id: 25811, Make: Honda, Model: Odyssey, Year: 2013, Fav: OLDISH-Honda-Odyssey
# Id: 22238, Make: Hyundai, Model: Santa Fe, Year: 2010, Fav: OLDISH-Hyundai-Santa Fe
# Id: 23032, Make: Jeep, Model: Cherokee, Year: 2013, Fav: OLDISH-Jeep-Cherokee
# Id: 29016, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 28108, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 18658, Make: Chrysler, Model: 200, Year: 2012, Fav: OLDISH-Chrysler-200
# Id: 21633, Make: Volkswagen, Model: Jetta, Year: 2013, Fav: OLDISH-Volkswagen-Jetta
# Id: 27449, Make: BMW, Model: 330i, Year: 2015, Fav: NEWISH-BMW-330i
# Id: 24042, Make: Chrysler, Model: 300, Year: 2015, Fav: NEWISH-Chrysler-300
# Id: 21081, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 16028, Make: Jeep, Model: Cherokee, Year: 2017, Fav: NEWISH-Jeep-Cherokee
# Id: 32162, Make: Toyota, Model: Sienna, Year: 2015, Fav: NEWISH-Toyota-Sienna
# Id: 19217, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 22736, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 19799, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 29557, Make: Toyota, Model: Sienna, Year: 2012, Fav: OLDISH-Toyota-Sienna
# Id: 17753, Make: Ford, Model: Fusion, Year: 2015, Fav: NEWISH-Ford-Fusion
# Id: 30730, Make: Ford, Model: Escape, Year: 2016, Fav: NEWISH-Ford-Escape
# Id: 35049, Make: Toyota, Model: Corrola, Year: 2013, Fav: OLDISH-Toyota-Corrola
# Id: 26657, Make: BMW, Model: 430i, Year: 2014, Fav: NEWISH-BMW-430i
# Id: 31420, Make: GMC, Model: Yukon, Year: 2013, Fav: OLDISH-GMC-Yukon
# Id: 12211, Make: Toyota, Model: Rav4, Year: 2012, Fav: OLDISH-Toyota-Rav4
# Id: 22896, Make: Dodge, Model: Durango, Year: 2017, Fav: NEWISH-Dodge-Durango
# Id: 37609, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 32985, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 20193, Make: Volvo, Model: 240, Year: 2017, Fav: NEWISH-Volvo-240
# Id: 27015, Make: Nissan, Model: Altima, Year: 2013, Fav: OLDISH-Nissan-Altima
# Id: 22019, Make: Chevrolet, Model: Silverado, Year: 2012, Fav: OLDISH-Chevrolet-Silverado
# Id: 21986, Make: Honda, Model: Accord, Year: 2015, Fav: NEWISH-Honda-Accord
# Id: 26213, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 28956, Make: Ford, Model: F150, Year: 2016, Fav: NEWISH-Ford-F150
# Id: 28437, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 22739, Make: Chevrolet, Model: Suburban, Year: 2011, Fav: OLDISH-Chevrolet-Suburban
# Id: 27684, Make: Honda, Model: Civic, Year: 2012, Fav: OLDISH-Honda-Civic
# Id: 24240, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 25043, Make: Buick, Model: LaCrosse, Year: 2015, Fav: NEWISH-Buick-LaCrosse
# Id: 20550, Make: GMC, Model: Acadia, Year: 2017, Fav: NEWISH-GMC-Acadia
# Id: 28609, Make: Buick, Model: LaCrosse, Year: 2013, Fav: OLDISH-Buick-LaCrosse
# Id: 25784, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 33642, Make: Toyota, Model: Corrola, Year: 2016, Fav: NEWISH-Toyota-Corrola
# Id: 24227, Make: Cadillac, Model: Escalade, Year: 2014, Fav: NEWISH-Cadillac-Escalade
# Id: 28549, Make: Chrysler, Model: Pacifica, Year: 2015, Fav: NEWISH-Chrysler-Pacifica
# Id: 24821, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 18528, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 20300, Make: Ford, Model: Escape, Year: 2013, Fav: OLDISH-Ford-Escape
# Id: 21042, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 24873, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 26429, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 27979, Make: Chevrolet, Model: Camaro, Year: 2012, Fav: OLDISH-Chevrolet-Camaro
# Id: 27166, Make: Jeep, Model: Grand Cherokee, Year: 2015, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 28345, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 31391, Make: Cadillac, Model: XT5, Year: 2011, Fav: OLDISH-Cadillac-XT5
# Id: 18353, Make: Chevrolet, Model: Camaro, Year: 2015, Fav: NEWISH-Chevrolet-Camaro
# Id: 27257, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 22151, Make: Cadillac, Model: XT5, Year: 2017, Fav: NEWISH-Cadillac-XT5
# Id: 20159, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 24594, Make: Ford, Model: Expedition, Year: 2015, Fav: NEWISH-Ford-Expedition
# Id: 20728, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 16182, Make: Dodge, Model: Caravan, Year: 2014, Fav: NEWISH-Dodge-Caravan
# Id: 24271, Make: Chevrolet, Model: Traverse, Year: 2015, Fav: NEWISH-Chevrolet-Traverse
# Id: 25774, Make: Honda, Model: Civic, Year: 2015, Fav: NEWISH-Honda-Civic
# Id: 27564, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 21915, Make: Ford, Model: Expedition, Year: 2013, Fav: OLDISH-Ford-Expedition
# Id: 22501, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 26379, Make: Volvo, Model: 240, Year: 2012, Fav: OLDISH-Volvo-240
# Id: 36127, Make: Ford, Model: Edge, Year: 2011, Fav: OLDISH-Ford-Edge
# Id: 30433, Make: GMC, Model: Yukon, Year: 2015, Fav: NEWISH-GMC-Yukon
# Id: 27520, Make: Chrysler, Model: Pacifica, Year: 2013, Fav: OLDISH-Chrysler-Pacifica
# Id: 23557, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 25337, Make: Chrysler, Model: 200, Year: 2014, Fav: NEWISH-Chrysler-200
# Id: 28128, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 28293, Make: Cadillac, Model: Escalade, Year: 2010, Fav: OLDISH-Cadillac-Escalade
# Id: 31508, Make: Chevrolet, Model: Silverado, Year: 2016, Fav: NEWISH-Chevrolet-Silverado
# Id: 20041, Make: Ford, Model: F150, Year: 2011, Fav: OLDISH-Ford-F150
# Id: 20861, Make: Chevrolet, Model: Suburban, Year: 2015, Fav: NEWISH-Chevrolet-Suburban
# Id: 24647, Make: Volvo, Model: V60, Year: 2010, Fav: OLDISH-Volvo-V60
# Id: 21895, Make: Ford, Model: Mustang, Year: 2016, Fav: NEWISH-Ford-Mustang
# Id: 20528, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 33936, Make: Toyota, Model: Prius, Year: 2012, Fav: OLDISH-Toyota-Prius
# Id: 26750, Make: Toyota, Model: Prius, Year: 2018, Fav: NEWISH-Toyota-Prius
# Id: 22204, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 23343, Make: Dodge, Model: Caravan, Year: 2013, Fav: OLDISH-Dodge-Caravan
# Id: 24714, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 25272, Make: Chevrolet, Model: Tahoe, Year: 2015, Fav: NEWISH-Chevrolet-Tahoe
# Id: 23066, Make: Ford, Model: Edge, Year: 2015, Fav: NEWISH-Ford-Edge
# Id: 26723, Make: Dodge, Model: Ram, Year: 2011, Fav: OLDISH-Dodge-Ram
# Id: 27063, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 24972, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 24303, Make: Buick, Model: Regal, Year: 2010, Fav: OLDISH-Buick-Regal
# Id: 23823, Make: Ford, Model: Explorer, Year: 2011, Fav: OLDISH-Ford-Explorer
# **rank 32
#
# Ranking for user that prefers: OLDISH-Kia-Sedona
#
# Ranking for user: 7909
# Id: 18528, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 27684, Make: Honda, Model: Civic, Year: 2012, Fav: OLDISH-Honda-Civic
# Id: 27166, Make: Jeep, Model: Grand Cherokee, Year: 2015, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 24647, Make: Volvo, Model: V60, Year: 2010, Fav: OLDISH-Volvo-V60
# Id: 23343, Make: Dodge, Model: Caravan, Year: 2013, Fav: OLDISH-Dodge-Caravan
# Id: 24594, Make: Ford, Model: Expedition, Year: 2015, Fav: NEWISH-Ford-Expedition
# Id: 29557, Make: Toyota, Model: Sienna, Year: 2012, Fav: OLDISH-Toyota-Sienna
# Id: 23152, Make: Volkswagen, Model: Jetta, Year: 2015, Fav: NEWISH-Volkswagen-Jetta
# Id: 21915, Make: Ford, Model: Expedition, Year: 2013, Fav: OLDISH-Ford-Expedition
# Id: 25774, Make: Honda, Model: Civic, Year: 2015, Fav: NEWISH-Honda-Civic
# ...
# Id: 27063, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 24271, Make: Chevrolet, Model: Traverse, Year: 2015, Fav: NEWISH-Chevrolet-Traverse
# Id: 28128, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# **rank 0
#
# Ranking for user that prefers: OLDISH-Honda-Accord
#
# Ranking for user: 5013
# Id: 22766, Make: Buick, Model: Enclave, Year: 2016, Fav: NEWISH-Buick-Enclave
# Id: 25339, Make: Chevrolet, Model: Traverse, Year: 2013, Fav: OLDISH-Chevrolet-Traverse
# Id: 26553, Make: Buick, Model: Enclave, Year: 2012, Fav: OLDISH-Buick-Enclave
# Id: 20959, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 25811, Make: Honda, Model: Odyssey, Year: 2013, Fav: OLDISH-Honda-Odyssey
# Id: 24082, Make: Toyota, Model: Camry, Year: 2014, Fav: NEWISH-Toyota-Camry
# Id: 23740, Make: Dodge, Model: Durango, Year: 2010, Fav: OLDISH-Dodge-Durango
# Id: 23032, Make: Jeep, Model: Cherokee, Year: 2013, Fav: OLDISH-Jeep-Cherokee
# Id: 23152, Make: Volkswagen, Model: Jetta, Year: 2015, Fav: NEWISH-Volkswagen-Jetta
# Id: 22736, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 29016, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 24042, Make: Chrysler, Model: 300, Year: 2015, Fav: NEWISH-Chrysler-300
# Id: 28108, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 19348, Make: Nissan, Model: Leaf, Year: 2010, Fav: OLDISH-Nissan-Leaf
# Id: 16028, Make: Jeep, Model: Cherokee, Year: 2017, Fav: NEWISH-Jeep-Cherokee
# Id: 25620, Make: Toyota, Model: Camry, Year: 2012, Fav: OLDISH-Toyota-Camry
# Id: 20902, Make: Nissan, Model: Altima, Year: 2016, Fav: NEWISH-Nissan-Altima
# Id: 32162, Make: Toyota, Model: Sienna, Year: 2015, Fav: NEWISH-Toyota-Sienna
# Id: 21986, Make: Honda, Model: Accord, Year: 2015, Fav: NEWISH-Honda-Accord
# Id: 25043, Make: Buick, Model: LaCrosse, Year: 2015, Fav: NEWISH-Buick-LaCrosse
# Id: 19799, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 18658, Make: Chrysler, Model: 200, Year: 2012, Fav: OLDISH-Chrysler-200
# Id: 19217, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 32985, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 21633, Make: Volkswagen, Model: Jetta, Year: 2013, Fav: OLDISH-Volkswagen-Jetta
# Id: 21081, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 26213, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 27449, Make: BMW, Model: 330i, Year: 2015, Fav: NEWISH-BMW-330i
# Id: 20300, Make: Ford, Model: Escape, Year: 2013, Fav: OLDISH-Ford-Escape
# Id: 29557, Make: Toyota, Model: Sienna, Year: 2012, Fav: OLDISH-Toyota-Sienna
# Id: 22238, Make: Hyundai, Model: Santa Fe, Year: 2010, Fav: OLDISH-Hyundai-Santa Fe
# Id: 17753, Make: Ford, Model: Fusion, Year: 2015, Fav: NEWISH-Ford-Fusion
# Id: 28609, Make: Buick, Model: LaCrosse, Year: 2013, Fav: OLDISH-Buick-LaCrosse
# Id: 28549, Make: Chrysler, Model: Pacifica, Year: 2015, Fav: NEWISH-Chrysler-Pacifica
# Id: 33642, Make: Toyota, Model: Corrola, Year: 2016, Fav: NEWISH-Toyota-Corrola
# Id: 27166, Make: Jeep, Model: Grand Cherokee, Year: 2015, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 37609, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 31420, Make: GMC, Model: Yukon, Year: 2013, Fav: OLDISH-GMC-Yukon
# Id: 12211, Make: Toyota, Model: Rav4, Year: 2012, Fav: OLDISH-Toyota-Rav4
# Id: 22896, Make: Dodge, Model: Durango, Year: 2017, Fav: NEWISH-Dodge-Durango
# Id: 30730, Make: Ford, Model: Escape, Year: 2016, Fav: NEWISH-Ford-Escape
# Id: 35049, Make: Toyota, Model: Corrola, Year: 2013, Fav: OLDISH-Toyota-Corrola
# Id: 20728, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 26657, Make: BMW, Model: 430i, Year: 2014, Fav: NEWISH-BMW-430i
# Id: 25774, Make: Honda, Model: Civic, Year: 2015, Fav: NEWISH-Honda-Civic
# Id: 27257, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 22739, Make: Chevrolet, Model: Suburban, Year: 2011, Fav: OLDISH-Chevrolet-Suburban
# Id: 21042, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 27015, Make: Nissan, Model: Altima, Year: 2013, Fav: OLDISH-Nissan-Altima
# Id: 20159, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 21915, Make: Ford, Model: Expedition, Year: 2013, Fav: OLDISH-Ford-Expedition
# Id: 25784, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 18528, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 16182, Make: Dodge, Model: Caravan, Year: 2014, Fav: NEWISH-Dodge-Caravan
# Id: 22019, Make: Chevrolet, Model: Silverado, Year: 2012, Fav: OLDISH-Chevrolet-Silverado
# Id: 22151, Make: Cadillac, Model: XT5, Year: 2017, Fav: NEWISH-Cadillac-XT5
# Id: 27684, Make: Honda, Model: Civic, Year: 2012, Fav: OLDISH-Honda-Civic
# Id: 24594, Make: Ford, Model: Expedition, Year: 2015, Fav: NEWISH-Ford-Expedition
# Id: 28437, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 31391, Make: Cadillac, Model: XT5, Year: 2011, Fav: OLDISH-Cadillac-XT5
# Id: 26429, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 28293, Make: Cadillac, Model: Escalade, Year: 2010, Fav: OLDISH-Cadillac-Escalade
# Id: 28345, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 24227, Make: Cadillac, Model: Escalade, Year: 2014, Fav: NEWISH-Cadillac-Escalade
# Id: 27520, Make: Chrysler, Model: Pacifica, Year: 2013, Fav: OLDISH-Chrysler-Pacifica
# Id: 20193, Make: Volvo, Model: 240, Year: 2017, Fav: NEWISH-Volvo-240
# Id: 24647, Make: Volvo, Model: V60, Year: 2010, Fav: OLDISH-Volvo-V60
# Id: 36127, Make: Ford, Model: Edge, Year: 2011, Fav: OLDISH-Ford-Edge
# Id: 20550, Make: GMC, Model: Acadia, Year: 2017, Fav: NEWISH-GMC-Acadia
# Id: 22501, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 24821, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 24873, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 33936, Make: Toyota, Model: Prius, Year: 2012, Fav: OLDISH-Toyota-Prius
# Id: 25337, Make: Chrysler, Model: 200, Year: 2014, Fav: NEWISH-Chrysler-200
# Id: 24271, Make: Chevrolet, Model: Traverse, Year: 2015, Fav: NEWISH-Chevrolet-Traverse
# Id: 27564, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 27979, Make: Chevrolet, Model: Camaro, Year: 2012, Fav: OLDISH-Chevrolet-Camaro
# Id: 28956, Make: Ford, Model: F150, Year: 2016, Fav: NEWISH-Ford-F150
# Id: 30433, Make: GMC, Model: Yukon, Year: 2015, Fav: NEWISH-GMC-Yukon
# Id: 26750, Make: Toyota, Model: Prius, Year: 2018, Fav: NEWISH-Toyota-Prius
# Id: 31508, Make: Chevrolet, Model: Silverado, Year: 2016, Fav: NEWISH-Chevrolet-Silverado
# Id: 23557, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 24714, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 23343, Make: Dodge, Model: Caravan, Year: 2013, Fav: OLDISH-Dodge-Caravan
# Id: 25272, Make: Chevrolet, Model: Tahoe, Year: 2015, Fav: NEWISH-Chevrolet-Tahoe
# Id: 18353, Make: Chevrolet, Model: Camaro, Year: 2015, Fav: NEWISH-Chevrolet-Camaro
# Id: 21895, Make: Ford, Model: Mustang, Year: 2016, Fav: NEWISH-Ford-Mustang
# Id: 20528, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 24240, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 27063, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 26723, Make: Dodge, Model: Ram, Year: 2011, Fav: OLDISH-Dodge-Ram
# Id: 22204, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 20041, Make: Ford, Model: F150, Year: 2011, Fav: OLDISH-Ford-F150
# Id: 24303, Make: Buick, Model: Regal, Year: 2010, Fav: OLDISH-Buick-Regal
# Id: 23066, Make: Ford, Model: Edge, Year: 2015, Fav: NEWISH-Ford-Edge
# Id: 26379, Make: Volvo, Model: 240, Year: 2012, Fav: OLDISH-Volvo-240
# Id: 28128, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 20861, Make: Chevrolet, Model: Suburban, Year: 2015, Fav: NEWISH-Chevrolet-Suburban
# Id: 23823, Make: Ford, Model: Explorer, Year: 2011, Fav: OLDISH-Ford-Explorer
# Id: 24972, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# **rank 22
#
# Ranking for user that prefers: NEWISH-Honda-Pilot
#
# Ranking for user: 15931
# Id: 28345, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 18353, Make: Chevrolet, Model: Camaro, Year: 2015, Fav: NEWISH-Chevrolet-Camaro
# Id: 22151, Make: Cadillac, Model: XT5, Year: 2017, Fav: NEWISH-Cadillac-XT5
# Id: 26213, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 22238, Make: Hyundai, Model: Santa Fe, Year: 2010, Fav: OLDISH-Hyundai-Santa Fe
# Id: 20528, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 20041, Make: Ford, Model: F150, Year: 2011, Fav: OLDISH-Ford-F150
# Id: 24821, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 28293, Make: Cadillac, Model: Escalade, Year: 2010, Fav: OLDISH-Cadillac-Escalade
# Id: 20550, Make: GMC, Model: Acadia, Year: 2017, Fav: NEWISH-GMC-Acadia
# Id: 26723, Make: Dodge, Model: Ram, Year: 2011, Fav: OLDISH-Dodge-Ram
# Id: 24227, Make: Cadillac, Model: Escalade, Year: 2014, Fav: NEWISH-Cadillac-Escalade
# Id: 28549, Make: Chrysler, Model: Pacifica, Year: 2015, Fav: NEWISH-Chrysler-Pacifica
# Id: 23557, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 29016, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 31420, Make: GMC, Model: Yukon, Year: 2013, Fav: OLDISH-GMC-Yukon
# Id: 24042, Make: Chrysler, Model: 300, Year: 2015, Fav: NEWISH-Chrysler-300
# Id: 21081, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 23823, Make: Ford, Model: Explorer, Year: 2011, Fav: OLDISH-Ford-Explorer
# Id: 27520, Make: Chrysler, Model: Pacifica, Year: 2013, Fav: OLDISH-Chrysler-Pacifica
# Id: 24240, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 17753, Make: Ford, Model: Fusion, Year: 2015, Fav: NEWISH-Ford-Fusion
# Id: 27564, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 28108, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 32985, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 28128, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 19799, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 26553, Make: Buick, Model: Enclave, Year: 2012, Fav: OLDISH-Buick-Enclave
# Id: 20959, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 33936, Make: Toyota, Model: Prius, Year: 2012, Fav: OLDISH-Toyota-Prius
# Id: 28437, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 23032, Make: Jeep, Model: Cherokee, Year: 2013, Fav: OLDISH-Jeep-Cherokee
# Id: 35049, Make: Toyota, Model: Corrola, Year: 2013, Fav: OLDISH-Toyota-Corrola
# Id: 36127, Make: Ford, Model: Edge, Year: 2011, Fav: OLDISH-Ford-Edge
# Id: 26657, Make: BMW, Model: 430i, Year: 2014, Fav: NEWISH-BMW-430i
# Id: 24271, Make: Chevrolet, Model: Traverse, Year: 2015, Fav: NEWISH-Chevrolet-Traverse
# Id: 21042, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 20193, Make: Volvo, Model: 240, Year: 2017, Fav: NEWISH-Volvo-240
# Id: 27015, Make: Nissan, Model: Altima, Year: 2013, Fav: OLDISH-Nissan-Altima
# Id: 20902, Make: Nissan, Model: Altima, Year: 2016, Fav: NEWISH-Nissan-Altima
# Id: 28609, Make: Buick, Model: LaCrosse, Year: 2013, Fav: OLDISH-Buick-LaCrosse
# Id: 21633, Make: Volkswagen, Model: Jetta, Year: 2013, Fav: OLDISH-Volkswagen-Jetta
# Id: 20728, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 22766, Make: Buick, Model: Enclave, Year: 2016, Fav: NEWISH-Buick-Enclave
# Id: 23740, Make: Dodge, Model: Durango, Year: 2010, Fav: OLDISH-Dodge-Durango
# Id: 22501, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 26379, Make: Volvo, Model: 240, Year: 2012, Fav: OLDISH-Volvo-240
# Id: 37609, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 33642, Make: Toyota, Model: Corrola, Year: 2016, Fav: NEWISH-Toyota-Corrola
# Id: 23152, Make: Volkswagen, Model: Jetta, Year: 2015, Fav: NEWISH-Volkswagen-Jetta
# Id: 30730, Make: Ford, Model: Escape, Year: 2016, Fav: NEWISH-Ford-Escape
# Id: 24594, Make: Ford, Model: Expedition, Year: 2015, Fav: NEWISH-Ford-Expedition
# Id: 19217, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 16182, Make: Dodge, Model: Caravan, Year: 2014, Fav: NEWISH-Dodge-Caravan
# Id: 24082, Make: Toyota, Model: Camry, Year: 2014, Fav: NEWISH-Toyota-Camry
# Id: 22896, Make: Dodge, Model: Durango, Year: 2017, Fav: NEWISH-Dodge-Durango
# Id: 12211, Make: Toyota, Model: Rav4, Year: 2012, Fav: OLDISH-Toyota-Rav4
# Id: 22739, Make: Chevrolet, Model: Suburban, Year: 2011, Fav: OLDISH-Chevrolet-Suburban
# Id: 26429, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 22204, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 27449, Make: BMW, Model: 330i, Year: 2015, Fav: NEWISH-BMW-330i
# Id: 22736, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 25620, Make: Toyota, Model: Camry, Year: 2012, Fav: OLDISH-Toyota-Camry
# Id: 22019, Make: Chevrolet, Model: Silverado, Year: 2012, Fav: OLDISH-Chevrolet-Silverado
# Id: 21895, Make: Ford, Model: Mustang, Year: 2016, Fav: NEWISH-Ford-Mustang
# Id: 24303, Make: Buick, Model: Regal, Year: 2010, Fav: OLDISH-Buick-Regal
# Id: 16028, Make: Jeep, Model: Cherokee, Year: 2017, Fav: NEWISH-Jeep-Cherokee
# Id: 25339, Make: Chevrolet, Model: Traverse, Year: 2013, Fav: OLDISH-Chevrolet-Traverse
# Id: 32162, Make: Toyota, Model: Sienna, Year: 2015, Fav: NEWISH-Toyota-Sienna
# Id: 23066, Make: Ford, Model: Edge, Year: 2015, Fav: NEWISH-Ford-Edge
# Id: 25043, Make: Buick, Model: LaCrosse, Year: 2015, Fav: NEWISH-Buick-LaCrosse
# Id: 27166, Make: Jeep, Model: Grand Cherokee, Year: 2015, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 25811, Make: Honda, Model: Odyssey, Year: 2013, Fav: OLDISH-Honda-Odyssey
# Id: 30433, Make: GMC, Model: Yukon, Year: 2015, Fav: NEWISH-GMC-Yukon
# Id: 21986, Make: Honda, Model: Accord, Year: 2015, Fav: NEWISH-Honda-Accord
# Id: 19348, Make: Nissan, Model: Leaf, Year: 2010, Fav: OLDISH-Nissan-Leaf
# Id: 24714, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 24972, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 27063, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 20159, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 18658, Make: Chrysler, Model: 200, Year: 2012, Fav: OLDISH-Chrysler-200
# Id: 25784, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 20861, Make: Chevrolet, Model: Suburban, Year: 2015, Fav: NEWISH-Chevrolet-Suburban
# Id: 31508, Make: Chevrolet, Model: Silverado, Year: 2016, Fav: NEWISH-Chevrolet-Silverado
# Id: 23343, Make: Dodge, Model: Caravan, Year: 2013, Fav: OLDISH-Dodge-Caravan
# Id: 29557, Make: Toyota, Model: Sienna, Year: 2012, Fav: OLDISH-Toyota-Sienna
# Id: 28956, Make: Ford, Model: F150, Year: 2016, Fav: NEWISH-Ford-F150
# Id: 24647, Make: Volvo, Model: V60, Year: 2010, Fav: OLDISH-Volvo-V60
# Id: 25337, Make: Chrysler, Model: 200, Year: 2014, Fav: NEWISH-Chrysler-200
# Id: 27979, Make: Chevrolet, Model: Camaro, Year: 2012, Fav: OLDISH-Chevrolet-Camaro
# Id: 20300, Make: Ford, Model: Escape, Year: 2013, Fav: OLDISH-Ford-Escape
# Id: 27257, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 27684, Make: Honda, Model: Civic, Year: 2012, Fav: OLDISH-Honda-Civic
# Id: 25272, Make: Chevrolet, Model: Tahoe, Year: 2015, Fav: NEWISH-Chevrolet-Tahoe
# Id: 24873, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 31391, Make: Cadillac, Model: XT5, Year: 2011, Fav: OLDISH-Cadillac-XT5
# Id: 18528, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 25774, Make: Honda, Model: Civic, Year: 2015, Fav: NEWISH-Honda-Civic
# Id: 21915, Make: Ford, Model: Expedition, Year: 2013, Fav: OLDISH-Ford-Expedition
# Id: 26750, Make: Toyota, Model: Prius, Year: 2018, Fav: NEWISH-Toyota-Prius
# **rank 0
#
# Rank average: 1.23

# %% [markdown]
# ## Exercise the hrnn campaign
# Here we try out the hrnn campaign. We ask Personalize for recommendations for a particular user. Our hope is that
# it would detect that this user likes old or new cars and would return a list accordingly.
# Best case is that the recommended list of cars entirely matches the user's preferred car
# cluster.

# %%
users_to_try = int_expanded_df.sample(5)
users_to_try[['USER_ID','FAV']].head(3)
# Out:
#         USER_ID                    FAV
# 559258     1877  OLDISH-Subaru-Outback
# 539277    14341    OLDISH-Ford-Mustang
# 657923    16068        OLDISH-BMW-430i

# %%
show_user_interaction_history(int_expanded_df, users_to_try.iloc[0]['USER_ID'])
# Out:
# (20, 18)
#         USER_ID  ITEM_ID                 WHEN                    FAV  YEAR  \
# 559255     1877    26802  2019-07-15 00:27:47  OLDISH-Subaru-Outback  2011
# 559251     1877    26247  2019-07-15 00:29:47  OLDISH-Subaru-Outback  2012
# 559260     1877    30193  2019-07-15 00:33:47  OLDISH-Subaru-Outback  2012
# 559266     1877    30058  2019-07-15 00:39:47  OLDISH-Subaru-Outback  2010
# 559263     1877    30442  2019-07-15 00:47:47  OLDISH-Subaru-Outback  2012
# 559250     1877    24479  2019-07-15 00:57:47  OLDISH-Subaru-Outback  2013
# 559259     1877    20784  2019-07-15 01:09:47  OLDISH-Subaru-Outback  2013
# 559252     1877    27320  2019-07-15 01:23:47  OLDISH-Subaru-Outback  2013
# 559264     1877    29458  2019-07-15 01:39:47  OLDISH-Subaru-Outback  2012
# 559256     1877    29252  2019-07-15 01:57:47  OLDISH-Subaru-Outback  2012
# 559254     1877    23057  2019-07-15 07:47:07  OLDISH-Subaru-Outback  2012
# 559257     1877    28576  2019-07-15 07:49:07  OLDISH-Subaru-Outback  2012
# 559261     1877    27137  2019-07-15 07:53:07  OLDISH-Subaru-Outback  2013
# 559258     1877    24697  2019-07-15 07:59:07  OLDISH-Subaru-Outback  2013
# 559269     1877    34521  2019-07-15 08:07:07  OLDISH-Subaru-Outback  2013
# 559267     1877    35747  2019-07-15 08:17:07  OLDISH-Subaru-Outback  2013
# 559268     1877    19357  2019-07-15 08:29:07  OLDISH-Subaru-Outback  2011
# 559253     1877    27320  2019-07-15 08:43:07  OLDISH-Subaru-Outback  2013
# 559265     1877    29243  2019-07-15 08:59:07  OLDISH-Subaru-Outback  2012
# 559262     1877    26539  2019-07-15 09:17:07  OLDISH-Subaru-Outback  2013
#
#         PRICE  MILEAGE
# 559255  17583   125579
# 559251  28235   111179
# 559260  27084   105120
# 559266  20205   143042
# 559263  20331   105673
# 559250  29524    91895
# 559259  23835    94644
# 559252  30890    97988
# 559264  20213   114945
# 559256  23048   106259
# 559254  26569   109880
# 559257  26653   108528
# 559261  27021    99655
# 559258  23881    91262
# 559269  22906    97810
# 559267  23261    91595
# 559268  24209   122615
# 559253  30890    97988
# 559265  28147   107560
# 559262  27391    94515

# %%
if is_campaign_active(hrnn_arn):
    for i in range(5):
        user_id     = str(users_to_try.iloc[i]['USER_ID'])
        fav         = users_to_try.iloc[i]['FAV']
        fav_cluster = users_to_try.iloc[i]['FAV_CLUSTER']

        print('Getting recommendations for user: {}, who likes: {}'.format(user_id, fav))
        response = personalize_runtime.get_recommendations(campaignArn=hrnn_arn, 
                                                           userId=user_id, 
                                                           numResults=10)
        items = response['itemList']

        match = 0
        actual_num_results = len(items)

        for item in items:
            _curr_item_id  = int(item['itemId'])
            _curr_cluster  = int_expanded_df[int_expanded_df.ITEM_ID == _curr_item_id].iloc[0]['FAV_CLUSTER']
            if fav_cluster == _curr_cluster:
                match += 1
            print_item(_curr_item_id)
        print('Matched {:.0f}% ({}/{})'.format(100 * match/actual_num_results, match, actual_num_results))
        print('')
else:
    print('HRNN campaign not active: {}'.format(hrnn_arn))
# Out:
# Getting recommendations for user: 1877, who likes: OLDISH-Subaru-Outback
# Id: 24062, Make: Subaru, Model: Outback, Fav: OLDISH-Subaru-Outback, Year: 2012
# Id: 23782, Make: Subaru, Model: Outback, Fav: OLDISH-Subaru-Outback, Year: 2011
# Id: 24753, Make: Subaru, Model: Outback, Fav: OLDISH-Subaru-Outback, Year: 2012
# Id: 24892, Make: Subaru, Model: Outback, Fav: OLDISH-Subaru-Outback, Year: 2007
# Id: 25534, Make: Subaru, Model: Outback, Fav: OLDISH-Subaru-Outback, Year: 2013
# Id: 25579, Make: Subaru, Model: Outback, Fav: OLDISH-Subaru-Outback, Year: 2013
# Id: 22404, Make: Subaru, Model: Outback, Fav: OLDISH-Subaru-Outback, Year: 2013
# Id: 23395, Make: Subaru, Model: Outback, Fav: OLDISH-Subaru-Outback, Year: 2012
# Id: 31489, Make: Subaru, Model: Outback, Fav: OLDISH-Subaru-Outback, Year: 2012
# Id: 25481, Make: Subaru, Model: Outback, Fav: OLDISH-Subaru-Outback, Year: 2011
# Matched 100% (10/10)
#
# Getting recommendations for user: 14341, who likes: OLDISH-Ford-Mustang
# Id: 29081, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2013
# Id: 24669, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2013
# Id: 26700, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2008
# Id: 26719, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2011
# Id: 22922, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2012
# Id: 26377, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2012
# Id: 24070, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2011
# Id: 28083, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2012
# Id: 25801, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2010
# Id: 27859, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2012
# Matched 100% (10/10)
#
# Getting recommendations for user: 16068, who likes: OLDISH-BMW-430i
# Id: 26974, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2011
# Id: 22484, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 23700, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2011
# Id: 23304, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2009
# Id: 27342, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 21149, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2011
# Id: 28915, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 22148, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2010
# Id: 27712, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2010
# Id: 24839, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2013
# Matched 100% (10/10)
#
# Getting recommendations for user: 280, who likes: OLDISH-Chrysler-200
# Id: 25622, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2012
# Id: 28018, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2012
# Id: 27771, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2012
# Id: 24748, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2012
# Id: 25157, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2012
# Id: 26435, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2011
# Id: 25626, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2009
# Id: 25655, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2011
# Id: 23540, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2013
# Id: 26088, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2012
# Matched 100% (10/10)
#
# Getting recommendations for user: 19186, who likes: NEWISH-Chevrolet-Tahoe
# Id: 24815, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2016
# Id: 23994, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Id: 23728, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Id: 26610, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Id: 27441, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 24587, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2016
# Id: 24421, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 27266, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Id: 25417, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Id: 24128, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Matched 100% (10/10)

# %% [markdown]
# ## Exercise the SIMS campaign
# Here we experiment with the SIMS campaign. We loop through a list of items that have at
# least some interactions historically.
# For each car, we would expect similar cars to be similar in age, make and model.
# We leverage car clusters and would like to see Personalize generate a list of similar cars
# that entirely come from the same car cluster.

# %%
items_to_try = int_expanded_df.sample(5)
items_to_try[['ITEM_ID','FAV']].head(5)
# Out:
#         ITEM_ID                       FAV
# 356080    29108       NEWISH-Ford-Mustang
# 590823    21072       OLDISH-Ford-Mustang
# 447720    24989   NEWISH-Chevrolet-Camaro
# 293836    28483       NEWISH-Chrysler-200
# 102345    29564  OLDISH-Chrysler-Pacifica

# %%
if is_campaign_active(sims_arn):
    desired_num_results = 10
    for i in range(items_to_try.shape[0]):
        item_id     = str(items_to_try.iloc[i]['ITEM_ID'])
        fav         = items_to_try.iloc[i]['FAV']
        fav_cluster = items_to_try.iloc[i]['FAV_CLUSTER']

        print('Getting items similar to: {}, which is a: {}'.format(item_id, fav))
        response = personalize_runtime.get_recommendations(campaignArn=sims_arn, 
                                                           itemId=item_id, 
                                                           numResults=desired_num_results)
        items = response['itemList']
        
        match = 0
        actual_num_results = len(items)
        
        for item in items:
            _curr_item_id  = int(item['itemId'])
            _curr_cluster  = int_expanded_df[int_expanded_df.ITEM_ID == _curr_item_id].iloc[0]['FAV_CLUSTER']
            if fav_cluster == _curr_cluster:
                match += 1
            print_item(_curr_item_id)
        print('Matched {:.0f}% ({}/{})'.format(100 * match/actual_num_results, match, actual_num_results))
        print('')
else:
    print('SIMS campaign not active: {}'.format(sims_arn))
# Out:
# Getting items similar to: 29108, which is a: NEWISH-Ford-Mustang
# Id: 25852, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2014
# Id: 21475, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 20513, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2017
# Id: 24048, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2017
# Id: 29908, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 21853, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2014
# Id: 16900, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 27087, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2016
# Id: 22862, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2014
# Id: 23408, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2014
# Matched 100% (10/10)
#
# Getting items similar to: 21072, which is a: OLDISH-Ford-Mustang
# Id: 25379, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2011
# Id: 28227, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2013
# Id: 25926, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2012
# Id: 26232, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2013
# Id: 24018, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2012
# Id: 26312, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2011
# Id: 24618, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2013
# Id: 35302, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2013
# Id: 26719, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2011
# Id: 29212, Make: Ford, Model: Mustang, Fav: OLDISH-Ford-Mustang, Year: 2010
# Matched 100% (10/10)
#
# Getting items similar to: 24989, which is a: NEWISH-Chevrolet-Camaro
# Id: 24865, Make: Chevrolet, Model: Camaro, Fav: NEWISH-Chevrolet-Camaro, Year: 2015
# Id: 26315, Make: Chevrolet, Model: Camaro, Fav: NEWISH-Chevrolet-Camaro, Year: 2014
# Id: 25804, Make: Chevrolet, Model: Camaro, Fav: NEWISH-Chevrolet-Camaro, Year: 2014
# Id: 22567, Make: Chevrolet, Model: Camaro, Fav: NEWISH-Chevrolet-Camaro, Year: 2014
# Id: 26769, Make: Chevrolet, Model: Camaro, Fav: NEWISH-Chevrolet-Camaro, Year: 2014
# Id: 25439, Make: Chevrolet, Model: Camaro, Fav: NEWISH-Chevrolet-Camaro, Year: 2014
# Id: 23046, Make: Chevrolet, Model: Camaro, Fav: NEWISH-Chevrolet-Camaro, Year: 2014
# Id: 23793, Make: Chevrolet, Model: Camaro, Fav: NEWISH-Chevrolet-Camaro, Year: 2015
# Id: 22954, Make: Chevrolet, Model: Camaro, Fav: NEWISH-Chevrolet-Camaro, Year: 2016
# Id: 27802, Make: Chevrolet, Model: Camaro, Fav: NEWISH-Chevrolet-Camaro, Year: 2016
# Matched 100% (10/10)
#
# Getting items similar to: 28483, which is a: NEWISH-Chrysler-200
# Id: 27695, Make: Chrysler, Model: 200, Fav: NEWISH-Chrysler-200, Year: 2014
# Id: 25716, Make: Chrysler, Model: 200, Fav: NEWISH-Chrysler-200, Year: 2014
# Id: 23988, Make: Chrysler, Model: 200, Fav: NEWISH-Chrysler-200, Year: 2015
# Id: 26490, Make: Chrysler, Model: 200, Fav: NEWISH-Chrysler-200, Year: 2016
# Id: 21284, Make: Chrysler, Model: 200, Fav: NEWISH-Chrysler-200, Year: 2016
# Id: 28294, Make: Chrysler, Model: 200, Fav: NEWISH-Chrysler-200, Year: 2017
# Id: 25418, Make: Chrysler, Model: 200, Fav: NEWISH-Chrysler-200, Year: 2015
# Id: 25941, Make: Chrysler, Model: 200, Fav: NEWISH-Chrysler-200, Year: 2015
# Id: 29207, Make: Chrysler, Model: 200, Fav: NEWISH-Chrysler-200, Year: 2014
# Id: 27947, Make: Chrysler, Model: 200, Fav: NEWISH-Chrysler-200, Year: 2014
# Matched 100% (10/10)
#
# Getting items similar to: 29564, which is a: OLDISH-Chrysler-Pacifica
# Id: 30957, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 25561, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2013
# Id: 26739, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2011
# Id: 25520, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 31356, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 31308, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2013
# Id: 20462, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 27506, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2013
# Id: 38469, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2013
# Id: 20182, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2013
# Matched 100% (10/10)

# %% [markdown]
# ## Exercise the hrnn-metadata campaign
# Here we try out the hrnn-metadata campaign.
# We ask Personalize for recommendations for a particular user. Our hope is that
# it would detect that this user likes old or new cars and would return a list accordingly.

# %%
users_to_try = int_expanded_df.sample(10)
users_to_try[['USER_ID','FAV']].head(3)
# Out:
#         USER_ID                   FAV
# 206482    16330      NEWISH-Ford-F150
# 18067     17005    NEWISH-Buick-Regal
# 632842    18701  NEWISH-Dodge-Caravan

# %%
show_user_interaction_history(int_expanded_df, users_to_try.iloc[0]['USER_ID'])
# Out:
# (70, 18)
#         USER_ID  ITEM_ID                 WHEN               FAV  YEAR  PRICE  \
# 206526    16330    27202  2019-07-10 20:00:04  NEWISH-Ford-F150  2014  26485
# 206509    16330    26692  2019-07-10 20:02:04  NEWISH-Ford-F150  2015  31745
# 206512    16330    26963  2019-07-10 20:06:04  NEWISH-Ford-F150  2016  34469
# 206492    16330    21428  2019-07-10 20:12:04  NEWISH-Ford-F150  2017  36431
# 206522    16330    28404  2019-07-10 20:20:04  NEWISH-Ford-F150  2016  34149
# 206543    16330    13487  2019-07-10 20:30:04  NEWISH-Ford-F150  2014  28671
# 206487    16330    25537  2019-07-10 20:42:04  NEWISH-Ford-F150  2015  32648
# 206500    16330    23574  2019-07-10 20:56:04  NEWISH-Ford-F150  2015  34683
# 206527    16330    27129  2019-07-10 21:12:04  NEWISH-Ford-F150  2014  32072
# 206530    16330    27536  2019-07-10 21:30:04  NEWISH-Ford-F150  2015  30918
# 206519    16330    18682  2019-07-11 05:58:19  NEWISH-Ford-F150  2015  30207
# 206521    16330    31816  2019-07-11 06:00:19  NEWISH-Ford-F150  2016  34599
# 206549    16330    38016  2019-07-11 06:04:19  NEWISH-Ford-F150  2014  30579
# 206528    16330    23620  2019-07-11 06:10:19  NEWISH-Ford-F150  2016  34671
# 206536    16330    27836  2019-07-11 06:18:19  NEWISH-Ford-F150  2017  43015
# 206516    16330    28285  2019-07-11 06:28:19  NEWISH-Ford-F150  2015  34831
# 206548    16330    12391  2019-07-11 06:40:19  NEWISH-Ford-F150  2016  36693
# 206514    16330    13288  2019-07-11 06:54:19  NEWISH-Ford-F150  2015  30290
# 206486    16330    31501  2019-07-11 07:10:19  NEWISH-Ford-F150  2015  28701
# 206529    16330    22488  2019-07-11 07:28:19  NEWISH-Ford-F150  2017  39528
# 206488    16330    26461  2019-07-12 07:06:38  NEWISH-Ford-F150  2017  41920
# 206540    16330    33812  2019-07-12 07:08:38  NEWISH-Ford-F150  2014  32873
# 206537    16330    29878  2019-07-12 07:12:38  NEWISH-Ford-F150  2016  32734
# 206511    16330    27471  2019-07-12 07:18:38  NEWISH-Ford-F150  2017  42098
# 206499    16330    23574  2019-07-12 07:26:38  NEWISH-Ford-F150  2015  34683
# 206481    16330    24464  2019-07-12 07:36:38  NEWISH-Ford-F150  2014  27776
# 206484    16330    23139  2019-07-12 07:48:38  NEWISH-Ford-F150  2014  28352
# 206532    16330    21903  2019-07-12 08:02:38  NEWISH-Ford-F150  2014  27681
# 206497    16330    25032  2019-07-12 08:18:38  NEWISH-Ford-F150  2015  30822
# 206485    16330    29737  2019-07-12 08:36:38  NEWISH-Ford-F150  2014  25770
# ...         ...      ...                  ...               ...   ...    ...
# 206525    16330    27202  2019-07-14 16:18:34  NEWISH-Ford-F150  2014  26485
# 206542    16330    17820  2019-07-14 16:20:34  NEWISH-Ford-F150  2017  43455
# 206544    16330    13518  2019-07-14 16:24:34  NEWISH-Ford-F150  2016  40918
# 206504    16330    17646  2019-07-14 16:30:34  NEWISH-Ford-F150  2016  40931
# 206531    16330    30596  2019-07-14 16:38:34  NEWISH-Ford-F150  2014  26802
# 206507    16330    36131  2019-07-14 16:48:34  NEWISH-Ford-F150  2015  31676
# 206535    16330    27836  2019-07-14 17:00:34  NEWISH-Ford-F150  2017  43015
# 206502    16330    26695  2019-07-14 17:14:34  NEWISH-Ford-F150  2018  46771
# 206545    16330    23094  2019-07-14 17:30:34  NEWISH-Ford-F150  2014  33206
# 206513    16330    23419  2019-07-14 17:48:34  NEWISH-Ford-F150  2017  41518
# 206482    16330    24464  2019-07-15 23:53:00  NEWISH-Ford-F150  2014  27776
# 206494    16330    24290  2019-07-15 23:55:00  NEWISH-Ford-F150  2016  39689
# 206534    16330    27148  2019-07-15 23:59:00  NEWISH-Ford-F150  2015  36593
# 206493    16330    23319  2019-07-16 00:05:00  NEWISH-Ford-F150  2016  34260
# 206520    16330    28247  2019-07-16 00:13:00  NEWISH-Ford-F150  2016  35834
# 206517    16330    31077  2019-07-16 00:23:00  NEWISH-Ford-F150  2016  40212
# 206508    16330    17865  2019-07-16 00:35:00  NEWISH-Ford-F150  2014  33907
# 206490    16330    19375  2019-07-16 00:49:00  NEWISH-Ford-F150  2015  34473
# 206539    16330    27253  2019-07-16 01:05:00  NEWISH-Ford-F150  2014  32423
# 206515    16330    24891  2019-07-16 01:23:00  NEWISH-Ford-F150  2018  41028
# 206505    16330    22755  2019-07-16 23:26:27  NEWISH-Ford-F150  2014  30428
# 206533    16330    28300  2019-07-16 23:28:27  NEWISH-Ford-F150  2015  37305
# 206498    16330    32113  2019-07-16 23:32:27  NEWISH-Ford-F150  2014  32188
# 206496    16330    33774  2019-07-16 23:38:27  NEWISH-Ford-F150  2019  49059
# 206518    16330    20078  2019-07-16 23:46:27  NEWISH-Ford-F150  2014  34095
# 206547    16330    40263  2019-07-16 23:56:27  NEWISH-Ford-F150  2016  34106
# 206538    16330    29878  2019-07-17 00:08:27  NEWISH-Ford-F150  2016  32734
# 206541    16330    23296  2019-07-17 00:22:27  NEWISH-Ford-F150  2016  39307
# 206510    16330    27456  2019-07-17 00:38:27  NEWISH-Ford-F150  2015  32976
# 206489    16330    26953  2019-07-17 00:56:27  NEWISH-Ford-F150  2014  32970
#
#         MILEAGE
# 206526    75679
# 206509    67243
# 206512    46700
# 206492    35074
# 206522    52041
# 206543    80201
# 206487    68781
# 206500    63132
# 206527    77843
# 206530    62663
# 206519    61498
# 206521    53887
# 206549    81726
# 206528    53746
# 206536    33470
# 206516    68600
# 206548    53843
# 206514    69513
# 206486    67823
# 206529    33239
# 206488    32388
# 206540    84152
# 206537    49739
# 206511    38722
# 206499    63132
# 206481    78072
# 206484    84007
# 206532    81831
# 206497    62255
# 206485    76645
# ...         ...
# 206525    75679
# 206542    39542
# 206544    51906
# 206504    53586
# 206531    84867
# 206507    65213
# 206535    33470
# 206502    23815
# 206545    84566
# 206513    30695
# 206482    78072
# 206494    52389
# 206534    65482
# 206493    51532
# 206520    54566
# 206517    45902
# 206508    76794
# 206490    61819
# 206539    77514
# 206515    22144
# 206505    75886
# 206533    65995
# 206498    83397
# 206496     4898
# 206518    84015
# 206547    45165
# 206538    49739
# 206541    46173
# 206510    63348
# 206489    80425
#
# [70 rows x 7 columns]

# %%
if is_campaign_active(hrnn_metadata_arn):
    for i in range(10):
        user_id     = str(users_to_try.iloc[i]['USER_ID'])
        fav         = users_to_try.iloc[i]['FAV']
        fav_cluster = users_to_try.iloc[i]['FAV_CLUSTER']

        print('Getting recommendations for user: {}, who likes: {}'.format(user_id, fav))
        response = personalize_runtime.get_recommendations(campaignArn=hrnn_metadata_arn, 
                                                           userId=user_id, 
                                                           numResults=10)
        match = 0
        actual_num_results = len(items)

        items = response['itemList']
        for item in items:
            _curr_item_id  = int(item['itemId'])
            _curr_cluster  = int_expanded_df[int_expanded_df.ITEM_ID == _curr_item_id].iloc[0]['FAV_CLUSTER']
            if fav_cluster == _curr_cluster:
                match += 1
            print_item(_curr_item_id)
        print('Matched {:.0f}% ({}/{})'.format(100 * match/actual_num_results, match, actual_num_results))
        print('')
else:
    print('HRNN-metadata campaign not active: {}'.format(hrnn_metadata_arn))
# Out:
# Getting recommendations for user: 16330, who likes: NEWISH-Ford-F150
# Id: 28300, Make: Ford, Model: F150, Fav: NEWISH-Ford-F150, Year: 2015
# Id: 23667, Make: Ford, Model: F150, Fav: NEWISH-Ford-F150, Year: 2014
# Id: 24603, Make: Ford, Model: F150, Fav: NEWISH-Ford-F150, Year: 2015
# Id: 26218, Make: Ford, Model: F150, Fav: NEWISH-Ford-F150, Year: 2015
# Id: 23504, Make: Ford, Model: F150, Fav: NEWISH-Ford-F150, Year: 2015
# Id: 25537, Make: Ford, Model: F150, Fav: NEWISH-Ford-F150, Year: 2015
# Id: 22832, Make: Ford, Model: F150, Fav: NEWISH-Ford-F150, Year: 2015
# Id: 29796, Make: Ford, Model: F150, Fav: NEWISH-Ford-F150, Year: 2015
# Id: 29352, Make: Ford, Model: F150, Fav: NEWISH-Ford-F150, Year: 2015
# Id: 27536, Make: Ford, Model: F150, Fav: NEWISH-Ford-F150, Year: 2015
# Matched 100% (10/10)
#
# Getting recommendations for user: 17005, who likes: NEWISH-Buick-Regal
# Id: 20047, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 28006, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 24516, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 25076, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 25324, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 21799, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 25767, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 28553, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 19061, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 27824, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Matched 100% (10/10)
#
# Getting recommendations for user: 18701, who likes: NEWISH-Dodge-Caravan
# Id: 27384, Make: Dodge, Model: Caravan, Fav: NEWISH-Dodge-Caravan, Year: 2015
# Id: 29250, Make: Dodge, Model: Caravan, Fav: NEWISH-Dodge-Caravan, Year: 2015
# Id: 18175, Make: Dodge, Model: Caravan, Fav: NEWISH-Dodge-Caravan, Year: 2015
# Id: 29593, Make: Dodge, Model: Caravan, Fav: NEWISH-Dodge-Caravan, Year: 2015
# Id: 23689, Make: Dodge, Model: Caravan, Fav: NEWISH-Dodge-Caravan, Year: 2015
# Id: 28057, Make: Dodge, Model: Caravan, Fav: NEWISH-Dodge-Caravan, Year: 2015
# Id: 33718, Make: Dodge, Model: Caravan, Fav: NEWISH-Dodge-Caravan, Year: 2015
# Id: 27633, Make: Dodge, Model: Caravan, Fav: NEWISH-Dodge-Caravan, Year: 2015
# Id: 31168, Make: Dodge, Model: Caravan, Fav: NEWISH-Dodge-Caravan, Year: 2015
# Id: 27570, Make: Dodge, Model: Caravan, Fav: NEWISH-Dodge-Caravan, Year: 2015
# Matched 100% (10/10)
#
# Getting recommendations for user: 9013, who likes: NEWISH-Honda-Pilot
# Id: 25284, Make: Honda, Model: Pilot, Fav: NEWISH-Honda-Pilot, Year: 2015
# Id: 20086, Make: Honda, Model: Pilot, Fav: NEWISH-Honda-Pilot, Year: 2015
# Id: 24419, Make: Honda, Model: Pilot, Fav: NEWISH-Honda-Pilot, Year: 2015
# Id: 16785, Make: Honda, Model: Pilot, Fav: NEWISH-Honda-Pilot, Year: 2015
# Id: 26069, Make: Honda, Model: Pilot, Fav: NEWISH-Honda-Pilot, Year: 2015
# Id: 29665, Make: Honda, Model: Pilot, Fav: NEWISH-Honda-Pilot, Year: 2015
# Id: 20384, Make: Honda, Model: Pilot, Fav: NEWISH-Honda-Pilot, Year: 2015
# Id: 24265, Make: Honda, Model: Pilot, Fav: NEWISH-Honda-Pilot, Year: 2016
# Id: 29523, Make: Honda, Model: Pilot, Fav: NEWISH-Honda-Pilot, Year: 2016
# Id: 29364, Make: Honda, Model: Pilot, Fav: NEWISH-Honda-Pilot, Year: 2015
# Matched 100% (10/10)
#
# Getting recommendations for user: 7087, who likes: OLDISH-Nissan-Rogue
# Id: 27426, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2013
# Id: 30210, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2012
# Id: 21721, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2012
# Id: 18273, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2012
# Id: 27567, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2012
# Id: 31828, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2012
# Id: 32329, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2012
# Id: 27986, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2012
# Id: 21018, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2012
# Id: 33588, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2012
# Matched 100% (10/10)
#
# Getting recommendations for user: 17668, who likes: OLDISH-BMW-430i
# Id: 25650, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 26134, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2011
# Id: 29773, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 24509, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 27839, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 23337, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 24488, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 24101, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 21128, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 23989, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Matched 100% (10/10)
#
# Getting recommendations for user: 17406, who likes: NEWISH-Chevrolet-Suburban
# Id: 24692, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 23598, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 24291, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 20727, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 20382, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 20989, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 28186, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 22603, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 25687, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 27315, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Matched 100% (10/10)
#
# Getting recommendations for user: 15719, who likes: OLDISH-Chevrolet-Tahoe
# Id: 24561, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 23185, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 27105, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 21330, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 24302, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 25338, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 20592, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 25717, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 22528, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 21423, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Matched 100% (10/10)
#
# Getting recommendations for user: 15387, who likes: OLDISH-GMC-Acadia
# Id: 26451, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Id: 29088, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2011
# Id: 26596, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Id: 24170, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2013
# Id: 26257, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Id: 23681, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Id: 26121, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Id: 19120, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Id: 26586, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Id: 19927, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Matched 100% (10/10)
#
# Getting recommendations for user: 14728, who likes: OLDISH-Chrysler-Pacifica
# Id: 29272, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 27028, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2011
# Id: 19798, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 28518, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 23127, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2011
# Id: 29743, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 25815, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2011
# Id: 24180, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 25357, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 25214, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Matched 100% (10/10)

# %% [markdown]
# ## Exercise the popularity campaign
# Personalize provides a baseline recommender which leverages simple popularity of an item.
# Here we will
# compare its results with our own definition of "popular".
#
# Our popularity is driven simply by total count of
# interactions for that item. We expect significant overlap between our list and the one from Personalize.

# %% [markdown]
# #### First let's get the results from Personalize

# %%
personalized_pop = []
pop_items = []
NUM_MOST_POPULAR = 10

if is_campaign_active(pop_arn):
    popularity_response = personalize_runtime.get_recommendations(campaignArn=pop_arn, 
                                                                  userId='0', 
                                                                  numResults=NUM_MOST_POPULAR)
    pop_items = popularity_response['itemList']
    for item in pop_items:
        print_item(int(item['itemId']))    
else:
    print('Popularity campaign not active: {}'.format(pop_arn))

for p in pop_items:
    personalized_pop.append(str(p['itemId']))
# Out:
# Id: 25714, Make: Nissan, Model: Rogue, Fav: NEWISH-Nissan-Rogue, Year: 2015
# Id: 24588, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2014
# Id: 23545, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2011
# Id: 24366, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2013
# Id: 25012, Make: Nissan, Model: Rogue, Fav: NEWISH-Nissan-Rogue, Year: 2014
# Id: 23735, Make: Nissan, Model: Rogue, Fav: NEWISH-Nissan-Rogue, Year: 2014
# Id: 23649, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 23791, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2016
# Id: 25812, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 25104, Make: Nissan, Model: Rogue, Fav: NEWISH-Nissan-Rogue, Year: 2016

# %% [markdown]
# #### Now let's get the actual popularity counts of the historical interactions

# %%
most_popular = pd.DataFrame(int_expanded_df['ITEM_ID'].value_counts().reset_index())
most_popular.drop(['ITEM_ID'], axis=1, inplace=True)
ten_most_popular = most_popular.head(10)

# %% [markdown]
# #### Now compare the two lists

# %%
if is_campaign_active(pop_arn):
    print('We asked Personalize for {} most popular.'.format(NUM_MOST_POPULAR))
    print('{}'.format(personalized_pop))
    print('We computed it ourselves also')
    print(ten_most_popular['index'])

    overlap_items     = ten_most_popular[ten_most_popular['index'].isin(personalized_pop)]
    overlap_count     = overlap_items.shape[0]
    not_overlap_items = ten_most_popular[~ten_most_popular['index'].isin(personalized_pop)]
    not_overlap_count = not_overlap_items.shape[0]
    
    print('\nOf the actual most popular, {} are selected by Personalize also.'.format(overlap_items))
    print('\nPersonalize did not think this list was truly top 10:'.format(not_overlap_count))
    print(not_overlap_items.head())
# Out:
# We asked Personalize for 10 most popular.
# ['25714', '24588', '23545', '24366', '25012', '23735', '23649', '23791', '25812', '25104']
# We computed it ourselves also
# 0    25714
# 1    26377
# 2    25104
# 3    24588
# 4    25589
# 5    23791
# 6    24366
# 7    25012
# 8    26299
# 9    23735
# Name: index, dtype: int64
#
# Of the actual most popular,    index
# 0  25714
# 2  25104
# 3  24588
# 5  23791
# 6  24366
# 7  25012
# 9  23735 are selected by Personalize also.
#
# Personalize did not think this list was truly top 10:
#    index
# 1  26377
# 4  25589
# 8  26299

# %% [markdown]
# ## Use real time events
# Here we use the event tracker mechanism of personalize to add some events on the fly after deployment of
# a campaign. We then show the impact on the recommendations.

# %%
def is_tracker_active(tracker_name):
    _is_active = False
    _event_tracker_arn = ''
    _tracking_id = ''

    resp = personalize.list_event_trackers()
    trackers = resp['eventTrackers']

    for t in trackers:
        if t['name'] == tracker_name:
            _is_active = True
            _event_tracker_arn = t['eventTrackerArn']
            d_resp = personalize.describe_event_tracker(eventTrackerArn = _event_tracker_arn)

            _tracking_id = d_resp['eventTracker']['trackingId']
    
    return _is_active, _event_tracker_arn, _tracking_id

# %%
(exists, tracker_arn, tracking_id) = is_tracker_active('CarClickTracker')
if not exists:
    response = personalize.create_event_tracker(
        name='CarClickTracker',
        datasetGroupArn=dg_arn
    )
    print(response['eventTrackerArn'])
    print(response['trackingId'])

    TRACKING_ID = response['trackingId']
else:
    TRACKING_ID = tracking_id

# %%
session_dict = {}

# %%
import uuid

def send_car_click(user_id, item_id, ts):
    """
    Simulates a click to send an event to Amazon Personalize's Event Tracker
    """
    # Configure Session
    try:
        session_ID = session_dict[user_id]
    except:
        session_dict[user_id] = str(uuid.uuid1())
        session_ID = session_dict[user_id]
        
    # Configure Properties:
    event = {
        'itemId': str(item_id)
    }
    event_json = json.dumps(event)
        
    # Make Call
    personalize_events.put_events(
        trackingId = TRACKING_ID,
        userId     = str(user_id),
        sessionId  = session_ID,
        eventList  = [{
            'sentAt': ts,
            'eventType': 'EVENT_TYPE',
            'properties': event_json
            }]
)

# %%
def send_car_clicks(user_id, items):
    # TODO: send all events in a single array instead of one call for each item
    i = 0
    for item in items:
        send_car_click(user_id, item, time.time())
        i += 1

# %%
def recommend_cars(user_id, campaign_arn):
    response = personalize_runtime.get_recommendations(campaignArn=campaign_arn, 
                                                       userId=str(user_id), 
                                                       numResults=10)
    items = response['itemList']
    for item in items:
        print_item(int(item['itemId']))
    print('')

# %%
sample_user = int_expanded_df.sample(1).iloc[0]['USER_ID']
sample_user_cluster = int_expanded_df[int_expanded_df.USER_ID == sample_user].iloc[0]['FAV_CLUSTER']
sample_user_fav = int_expanded_df[int_expanded_df.USER_ID == sample_user].iloc[0]['FAV']
print('Here is a sample user for exercising real time events:\n')
print('  user: {}, cluster: {}, fav: {}'.format(sample_user, sample_user_cluster, sample_user_fav))
# Out:
# Here is a sample user for exercising real time events:
#
#   user: 11035, cluster: 57, fav: OLDISH-Buick-Regal

# %%
new_cluster = sample_user_cluster + 1
if (new_cluster == NUM_CLUSTERS):
    new_cluster = 0
new_fav = int_expanded_df[int_expanded_df.FAV_CLUSTER == new_cluster].iloc[0]['FAV']
print('Now, we pick a new preferred set of cars that we will use when sending events:\n')
print('  new cluster: {}, new fav: {}'.format(new_cluster, new_fav))
# Out:
# Now, we pick a new preferred set of cars that we will use when sending events:
#
#   new cluster: 58, new fav: NEWISH-Hyundai-Santa Fe

# %%
print('Before any real time events, Personalize should recommend {} cars...\n'.format(sample_user_fav))

if is_campaign_active(hrnn_arn):
    print('First using {}\n'.format(hrnn_arn))
    recommend_cars(sample_user, hrnn_arn)
else:
    print('HRNN campaign not active: {}'.format(hrnn_arn))

if is_campaign_active(hrnn_metadata_arn):
    print('Next using {}\n'.format(hrnn_metadata_arn))
    recommend_cars(sample_user, hrnn_arn)
else:
    print('HRNN-metadata campaign not active: {}'.format(hrnn_metadata_arn))
# Out:
# Before any real time events, Personalize should recommend OLDISH-Buick-Regal cars...
#
# First using arn:aws:personalize:us-east-1:355151823911:campaign/car-hrnn
#
# Id: 25423, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2012
# Id: 23990, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2009
# Id: 25286, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2007
# Id: 25218, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2013
# Id: 26524, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2013
# Id: 24760, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2012
# Id: 25151, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2013
# Id: 24195, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2012
# Id: 26163, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2012
# Id: 26037, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2013
#
# Next using arn:aws:personalize:us-east-1:355151823911:campaign/car-hrnn-metadata
#
# Id: 25423, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2012
# Id: 23990, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2009
# Id: 25286, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2007
# Id: 25218, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2013
# Id: 26524, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2013
# Id: 24760, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2012
# Id: 25151, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2013
# Id: 24195, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2012
# Id: 26163, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2012
# Id: 26037, Make: Buick, Model: Regal, Fav: OLDISH-Buick-Regal, Year: 2013

# %%
new_car_cluster = int_expanded_df[int_expanded_df.FAV_CLUSTER == new_cluster].sample(100)
new_car_cluster[['FAV','ITEM_ID','YEAR','PRICE']].head(3)
# Out:
#                             FAV  ITEM_ID  YEAR  PRICE
# 600670  NEWISH-Hyundai-Santa Fe    25154  2015  33144
# 493022  NEWISH-Hyundai-Santa Fe    24548  2015  35434
# 597732  NEWISH-Hyundai-Santa Fe    22639  2015  36570

# %%
new_items_clicked = new_car_cluster['ITEM_ID'].values
new_items_clicked
# Out:
# array([25154, 24548, 22639, 24017, 34693, 26981, 28407, 24079, 29705,
#        31756, 21275, 30665, 30679, 34563, 16610, 30810, 25881, 30273,
#        28192, 21073, 24364, 23093, 14950, 12734, 22127, 25474, 16611,
#        27318, 22327, 23281, 31461, 28533, 30257, 17369, 33432, 29030,
#        22759, 28192, 23281, 23533, 28606, 23229, 26557, 21620, 33414,
#        22631, 18217, 19827, 21727, 23281, 29336, 35398, 19630, 21805,
#        29166, 24548, 17706, 25330, 20842, 22327, 23921, 23669, 23494,
#        28472, 24016, 16142, 29660, 30940, 21095, 30487, 27974, 32078,
#        24017, 25474, 32074, 22466, 26543, 19491, 24017, 19280, 33293,
#        36745, 32901, 18677, 20123, 26717, 25330, 24028, 25758, 24710,
#        23533, 23281, 15145, 22631, 22172, 17691, 29336, 23333, 20148,
#        21477])

# %%
send_car_clicks(sample_user, new_items_clicked)

# %%
int_expanded_df[int_expanded_df.USER_ID == sample_user]['FAV'].value_counts()
# Out:
# OLDISH-Buick-Regal    10
# Name: FAV, dtype: int64

# %%
print('Now this same user has started to like {} cars.'.format(new_fav))
print('Lets see if Personalize picks up on this real time change in intent...\n')

if is_campaign_active(hrnn_arn):
    print('First using {}\n'.format(hrnn_arn))
    recommend_cars(sample_user, hrnn_arn)
else:
    print('HRNN campaign not active: {}'.format(hrnn_arn))

if is_campaign_active(hrnn_metadata_arn):
    print('Next using {}\n'.format(hrnn_metadata_arn))
    recommend_cars(sample_user, hrnn_arn)
else:
    print('HRNN-metadata campaign not active: {}'.format(hrnn_metadata_arn))
# Out:
# Now this same user has started to like NEWISH-Hyundai-Santa Fe cars.
# Lets see if Personalize picks up on this real time change in intent...
#
# First using arn:aws:personalize:us-east-1:355151823911:campaign/car-hrnn
#
# Id: 25342, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2014
# Id: 25696, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2016
# Id: 28067, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 24364, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 25758, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2016
# Id: 29778, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 22816, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 23494, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 23565, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2014
# Id: 27710, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2016
#
# Next using arn:aws:personalize:us-east-1:355151823911:campaign/car-hrnn-metadata
#
# Id: 25342, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2014
# Id: 25696, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2016
# Id: 28067, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 24364, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 25758, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2016
# Id: 29778, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 22816, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 23494, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 23565, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2014
# Id: 27710, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2016
