# %% [markdown]
# # Using Personalize campaigns  on synthetic cars data
# This notebook exercises campaigns that have been built in the other notebooks. The intent is to demonstrate
# that the results coming back from requests for recommendations are accurate given the dataset we provided.
#
# There are specific sections for each of the following models:
#
# 1. [Personalized Ranking](#Exercise-the-personalized-ranking-campaign)
# 2. [HRNN](#Exercise-the-hrnn-campaign)
# 3. [SIMS](#Exercise-the-SIMS-campaign)
# 4. [HRNN-Metadata]()
# 5. [Popularity Count](#Exercise-the-popularity-campaign)
#
# In addition, we have a section for experimenting with
# [Personalize Event Tracker](#Use-real-time-events).

# %% [markdown]
# ## Imports, overall settings, initialization

# %%
account_num = '<your-account-num>'

# %%
import json
import boto3
import time
import datetime
import pandas as pd
from sklearn.utils import shuffle

region   = boto3.Session().region_name # or replace with your preferred region
print(region)

dataset_group_name = 'car-dg'

dg_arn = 'arn:aws:personalize:{}:{}:dataset-group/{}'.format(region, 
                                                             account_num, 
                                                             dataset_group_name)

cars_filename         = 'car_items.csv'
users_filename        = 'users.csv'
interactions_filename = 'interactions.csv'
int_exp_filename      = 'interactions_expanded.csv'

ranking_arn           = 'arn:aws:personalize:{}:{}:campaign/car-personalized-ranking'.format(region, account_num)
sims_arn              = 'arn:aws:personalize:{}:{}:campaign/car-sims'.format(region, account_num)
hrnn_arn              = 'arn:aws:personalize:{}:{}:campaign/car-hrnn'.format(region, account_num)
hrnn_metadata_arn     = 'arn:aws:personalize:{}:{}:campaign/car-hrnn-metadata'.format(region, account_num)
pop_arn               = 'arn:aws:personalize:{}:{}:campaign/car-popularity-count'.format(region, account_num)
# Out:
# us-east-1

# %%
personalize           = boto3.client('personalize')
personalize_runtime   = boto3.client('personalize-runtime')
personalize_events    = boto3.client('personalize-events')

# %%
def show_item_interaction_history(int_df, item_id):
    _tmp_df = int_df[int_df.ITEM_ID == item_id].sort_values('TIMESTAMP')
    print(_tmp_df.shape)
    return _tmp_df[['USER_ID','ITEM_ID','WHEN',
                    'FAV','YEAR','GENDER','SALARY']]

# %%
def show_user_interaction_history(int_df, user_id):
    _tmp_df = int_df[int_df.USER_ID == int(user_id)].sort_values('TIMESTAMP')
    print(_tmp_df.shape)
    return _tmp_df[['USER_ID','ITEM_ID','WHEN',
                    'FAV','YEAR','PRICE','MILEAGE']]

# %%
def date_to_string(ts):
    return datetime.datetime.fromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')

# %%
def is_campaign_active(c):
    _is_active = False
    
    try:
        _resp = personalize.describe_campaign(campaignArn = c)
        _campaign_status = _resp['campaign']['status']
        if _campaign_status == 'ACTIVE':
            _is_active = True
    except Exception as e:
        pass
        
    return _is_active

# %%
int_expanded_df = pd.read_csv(int_exp_filename)

int_expanded_df['WHEN'] = int_expanded_df['TIMESTAMP'].apply(date_to_string)

NUM_CLUSTERS = len(int_expanded_df.FAV_CLUSTER.value_counts())
print('{} clusters'.format(NUM_CLUSTERS))
# Out:
# 100 clusters

# %%
items_to_rank = int_expanded_df.sample(10)
items_to_rank.head(3)
# Out:
#         USER_ID  ITEM_ID   TIMESTAMP  SESSION_ID     MAKE    MODEL  YEAR  \
# 262107    28041    19781  1563005830        9739  Hyundai  Elantra  2012
# 18780     23295    26304  1563159215        3470    Buick    Regal  2016
# 726700    15499    31119  1563188328       16836    Volvo      V60  2013
#
#         MILEAGE  PRICE  AGE  GENDER  LOCATION  SALARY  FAV_CLUSTER  FAV_MODEL  \
# 262107   105945  27137   33  FEMALE     90044   22091           71         35
# 18780     52177  35670   37  FEMALE     75217   31532           56         28
# 726700    92456  30720   44  FEMALE     95076   45354           81         40
#
#                            FAV  HOURS_AGO                 WHEN
# 262107  OLDISH-Hyundai-Elantra  99.952222  2019-07-13 08:17:10
# 18780       NEWISH-Buick-Regal  57.345278  2019-07-15 02:53:35
# 726700        OLDISH-Volvo-V60  49.258333  2019-07-15 10:58:48

# %%
def print_item(item_id):
    tmp = int_expanded_df[int_expanded_df.ITEM_ID == item_id].iloc[0]
    print('Id: {}, Make: {}, Model: {}, Fav: {}, Year: {}'.format(item_id,
         tmp['MAKE'], tmp['MODEL'], tmp['FAV'], tmp['YEAR']))

# %% [markdown]
# Skip ahead to try out various campaigns:
#
# 1. [Personalized Ranking](#Exercise-the-personalized-ranking-campaign)
# 2. [HRNN](#Exercise-the-hrnn-campaign)
# 3. [SIMS](#Exercise-the-SIMS-campaign)
# 4. [HRNN-Metadata]()
# 5. [Popularity Count](#Exercise-the-popularity-campaign)
#
# In addition, we have a section for experimenting with
# [Personalize Event Tracker](#Use-real-time-events).

# %% [markdown]
# ## Exercise the Personalized Ranking campaign
# Here we want to see Personalize re-rank a set of search results. For our sample, we will pass
# a user that likes oldish cars and would expect oldish cars to appear closer to the top. Likewise, we will
# pass a user that likes newish cars and expect the higher ranked cars to be newish.

# %%
full_df = pd.DataFrame(columns=['USER_ID','FAV','FAV_CLUSTER'])

for i in range(NUM_CLUSTERS):
    tmp_df  = int_expanded_df[int_expanded_df.FAV_CLUSTER == i][['USER_ID','FAV','FAV_CLUSTER']].sample(1)
    full_df = pd.concat([full_df, tmp_df])
ranking_user_df = shuffle(full_df)
ranking_user_list = ranking_user_df['USER_ID'].values.astype(str).tolist()
ranking_user_df.head(NUM_CLUSTERS)
# Out:
#        USER_ID                         FAV FAV_CLUSTER
# 89194    28866         NEWISH-Nissan-Rogue          42
# 370228   18249      NEWISH-Volkswagen-Golf          28
# 502065   15654            OLDISH-Volvo-240          27
# 578268   17130         OLDISH-Chrysler-300          21
# 267395   15490          NEWISH-Ford-Fusion          72
# 431092   14014  NEWISH-Jeep-Grand Cherokee          86
# 747497   17899        NEWISH-Jeep-Cherokee           8
# 716625   28187       OLDISH-Toyota-Corrola          41
# 176580   12929         OLDISH-Toyota-Prius          79
# 573979   11671            OLDISH-GMC-Yukon          25
# 744171   14117        NEWISH-Honda-Odyssey          12
# 489793    8900           NEWISH-Kia-Sedona           6
# 643849   12517    NEWISH-Volkswagen-Tiguan          82
# 748992   14424        NEWISH-Buick-Enclave           4
# 628723    8994          NEWISH-Honda-Civic          18
# 76850    10634      NEWISH-Chevrolet-Tahoe          54
# 407913   15786   OLDISH-Chevrolet-Suburban          45
# 191293   16052        NEWISH-Ford-Explorer          52
# 471657   18353  OLDISH-Chevrolet-Silverado          35
# 737870   11409          OLDISH-Toyota-Rav4          97
# 360649   22780        OLDISH-Ford-Explorer          53
# 525016    5438          OLDISH-Honda-Pilot          37
# 47166    11217     OLDISH-Chevrolet-Camaro          67
# 624758   19297    NEWISH-Cadillac-Escalade          76
# 275495   15033      NEWISH-Hyundai-Elantra          70
# 457512   15535            NEWISH-Dodge-Ram          64
# 670593   17916    OLDISH-Volkswagen-Tiguan          83
# 132202    6806         NEWISH-Toyota-Prius          78
# 394688   19665          NEWISH-Honda-Pilot          36
# 664326   20210     NEWISH-Hyundai-Santa Fe          58
# ...        ...                         ...         ...
# 638736   15028            NEWISH-Ford-Edge          30
# 632501   12116        NEWISH-Dodge-Caravan          74
# 722954    7276     NEWISH-Volkswagen-Jetta          90
# 34964    14879    NEWISH-Chrysler-Pacifica          46
# 710143   13783         OLDISH-Honda-Accord          95
# 736154   13931        OLDISH-Nissan-Altima          11
# 673487   16602           NEWISH-GMC-Acadia          22
# 702733   21588       NEWISH-Buick-LaCrosse          14
# 93128    15783         NEWISH-Honda-Accord          94
# 521619   21387          NEWISH-Toyota-Rav4          96
# 731812    5836        NEWISH-Toyota-Sienna          84
# 717322   19383   NEWISH-Chevrolet-Traverse          88
# 749603   13488        OLDISH-Buick-Enclave           5
# 601450   15755          OLDISH-Ford-Fusion          73
# 3174     16781         OLDISH-Nissan-Rogue          43
# 727661    6581            OLDISH-Volvo-V60          81
# 685636   17455          OLDISH-Ford-Escape          33
# 262539   19619      OLDISH-Hyundai-Elantra          71
# 684726    4934           OLDISH-GMC-Acadia          23
# 706826   15239      NEWISH-Ford-Expedition          16
# 169338   10629          NEWISH-Ford-Escape          32
# 199192   16530        OLDISH-Dodge-Caravan          75
# 664604    2919         NEWISH-Cadillac-XT5          68
# 713803    2025            OLDISH-Dodge-Ram          65
# 660593    8102             OLDISH-BMW-430i          51
# 709497   18892        NEWISH-Nissan-Altima          10
# 746785   12107         NEWISH-Toyota-Camry           0
# 749923   11493        NEWISH-Dodge-Durango          98
# 581668   14563    OLDISH-Cadillac-Escalade          77
# 706084   25469            NEWISH-Volvo-V60          80
#
# [100 rows x 3 columns]

# %%
full_df = pd.DataFrame(columns=['ITEM_ID','FAV'])

for i in range(NUM_CLUSTERS):
    tmp_df  = int_expanded_df[int_expanded_df.FAV_CLUSTER == i][['ITEM_ID','FAV']].sample(1)
    full_df = pd.concat([full_df, tmp_df])
ranking_item_df = shuffle(full_df)
ranking_item_list = ranking_item_df['ITEM_ID'].values.astype(str).tolist()
ranking_item_df.head()
# Out:
#        ITEM_ID                        FAV
# 628195   16190         NEWISH-Honda-Civic
# 723071   23634    NEWISH-Volkswagen-Jetta
# 734270   24797      OLDISH-Buick-LaCrosse
# 686353   28972         OLDISH-Ford-Escape
# 749472   17473  OLDISH-Chevrolet-Traverse

# %%
def print_ranking_target_df(user_id, input_df, target_cluster):
    print('\nRanking for user: {}'.format(user_id))
    
    _input_list = input_df['ITEM_ID'].values.astype(str).tolist()
    
    personalized_ranking_response = personalize_runtime.get_personalized_ranking(
        campaignArn = ranking_arn, userId = str(user_id), inputList = _input_list)
    
    i = 0
    _rank = len(_input_list)
    for item in personalized_ranking_response['personalizedRanking']:
        item_id = item['itemId']
        tmp = int_expanded_df[int_expanded_df.ITEM_ID == int(item_id)].iloc[0]
        _fav_cluster = tmp['FAV_CLUSTER']
        if (target_cluster == _fav_cluster) & (_rank == len(_input_list)):
            _rank = i
        print('Id: {}, Make: {}, Model: {}, Year: {}, Fav: {}'.format(item_id,
         tmp['MAKE'], tmp['MODEL'], tmp['YEAR'], tmp['FAV']))
        i += 1
    return _rank

# %%
full_df = pd.DataFrame(columns=['ITEM_ID','FAV','FAV_CLUSTER'])

random_item_df   = shuffle(int_expanded_df[['ITEM_ID','FAV', 'FAV_CLUSTER']].sample(25))
random_item_list = random_item_df['ITEM_ID'].values.astype(str).tolist()
random_item_df.head()
# Out:
#         ITEM_ID                         FAV  FAV_CLUSTER
# 378109    21597  NEWISH-Chevrolet-Silverado           34
# 134552    19763   NEWISH-Chevrolet-Suburban           44
# 485368    24122          OLDISH-Ford-Fusion           73
# 12230     25523         OLDISH-Nissan-Rogue           43
# 133173    25899   NEWISH-Chevrolet-Suburban           44

# %% [markdown]
# #### Try personalized ranking on a curated set of items with each car cluster covered
# Here we take a curated set of items, with one item for each car cluster. Personalize
# should be able to re-rank in such a way that the specific item that would best match
# the user rises to the 0th position.

# %%
if is_campaign_active(ranking_arn):
    rank_total = 0
    for i in range(NUM_CLUSTERS):
        user_fav = ranking_user_df.iloc[i]['FAV']
        user_fav_cluster = ranking_user_df.iloc[i]['FAV_CLUSTER']
        print('\nRanking for user that prefers: {}'.format(user_fav))
        rank = print_ranking_target_df(ranking_user_list[i], ranking_item_df, user_fav_cluster)
        if (random_item_df.shape[0] == rank):
            print('**desired cluster was not found in the item set')
            rank = 0 # reset to not penalize when no item was available
        else:
            print('**rank {}'.format(rank))
        rank_total += rank

    print('\nRank average: {:.2f}'.format(rank_total/len(ranking_item_list)))
else:
    print('Personalized ranking campaign not active: {}'.format(ranking_arn))
# Out:
# Ranking for user that prefers: NEWISH-Nissan-Rogue
#
# Ranking for user: 28866
# Id: 20256, Make: Ford, Model: Edge, Year: 2009, Fav: OLDISH-Ford-Edge
# Id: 27047, Make: Toyota, Model: Corrola, Year: 2015, Fav: NEWISH-Toyota-Corrola
# Id: 18210, Make: Jeep, Model: Grand Cherokee, Year: 2014, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 22385, Make: Chrysler, Model: Pacifica, Year: 2014, Fav: NEWISH-Chrysler-Pacifica
# Id: 23268, Make: Chevrolet, Model: Suburban, Year: 2012, Fav: OLDISH-Chevrolet-Suburban
# Id: 24364, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 29286, Make: Toyota, Model: Corrola, Year: 2010, Fav: OLDISH-Toyota-Corrola
# Id: 23768, Make: Ford, Model: Mustang, Year: 2014, Fav: NEWISH-Ford-Mustang
# Id: 18592, Make: Toyota, Model: Sienna, Year: 2016, Fav: NEWISH-Toyota-Sienna
# Id: 26112, Make: Chrysler, Model: Pacifica, Year: 2009, Fav: OLDISH-Chrysler-Pacifica
# Id: 29351, Make: Ford, Model: Explorer, Year: 2012, Fav: OLDISH-Ford-Explorer
# Id: 24211, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 37961, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 15726, Make: Buick, Model: Regal, Year: 2012, Fav: OLDISH-Buick-Regal
# Id: 26796, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 27595, Make: Cadillac, Model: Escalade, Year: 2008, Fav: OLDISH-Cadillac-Escalade
# Id: 24126, Make: Buick, Model: Enclave, Year: 2017, Fav: NEWISH-Buick-Enclave
# Id: 30388, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 28523, Make: Ford, Model: Edge, Year: 2014, Fav: NEWISH-Ford-Edge
# Id: 33634, Make: Honda, Model: Civic, Year: 2013, Fav: OLDISH-Honda-Civic
# Id: 20185, Make: Volkswagen, Model: Jetta, Year: 2011, Fav: OLDISH-Volkswagen-Jetta
# Id: 26612, Make: Hyundai, Model: Santa Fe, Year: 2011, Fav: OLDISH-Hyundai-Santa Fe
# Id: 18514, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 32504, Make: Nissan, Model: Altima, Year: 2012, Fav: OLDISH-Nissan-Altima
# Id: 27300, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 29318, Make: Ford, Model: Expedition, Year: 2016, Fav: NEWISH-Ford-Expedition
# Id: 26539, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 22801, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 28429, Make: Chevrolet, Model: Suburban, Year: 2014, Fav: NEWISH-Chevrolet-Suburban
# Id: 23634, Make: Volkswagen, Model: Jetta, Year: 2017, Fav: NEWISH-Volkswagen-Jetta
# Id: 29315, Make: Volvo, Model: V60, Year: 2013, Fav: OLDISH-Volvo-V60
# Id: 30781, Make: Volvo, Model: 240, Year: 2015, Fav: NEWISH-Volvo-240
# Id: 23560, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 28620, Make: Toyota, Model: Camry, Year: 2013, Fav: OLDISH-Toyota-Camry
# Id: 25146, Make: Toyota, Model: Prius, Year: 2014, Fav: NEWISH-Toyota-Prius
# Id: 16650, Make: Honda, Model: Accord, Year: 2014, Fav: NEWISH-Honda-Accord
# Id: 41302, Make: Chevrolet, Model: Silverado, Year: 2010, Fav: OLDISH-Chevrolet-Silverado
# Id: 16902, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 21564, Make: Volvo, Model: 240, Year: 2013, Fav: OLDISH-Volvo-240
# Id: 21480, Make: Jeep, Model: Cherokee, Year: 2011, Fav: OLDISH-Jeep-Cherokee
# Id: 28278, Make: Chevrolet, Model: Traverse, Year: 2018, Fav: NEWISH-Chevrolet-Traverse
# Id: 26664, Make: Dodge, Model: Durango, Year: 2014, Fav: NEWISH-Dodge-Durango
# Id: 10115, Make: GMC, Model: Acadia, Year: 2015, Fav: NEWISH-GMC-Acadia
# Id: 28972, Make: Ford, Model: Escape, Year: 2012, Fav: OLDISH-Ford-Escape
# Id: 38505, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 33149, Make: Dodge, Model: Durango, Year: 2009, Fav: OLDISH-Dodge-Durango
# Id: 12022, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 21689, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 26280, Make: Toyota, Model: Camry, Year: 2017, Fav: NEWISH-Toyota-Camry
# Id: 21758, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 32765, Make: Buick, Model: Enclave, Year: 2010, Fav: OLDISH-Buick-Enclave
# Id: 23524, Make: Cadillac, Model: XT5, Year: 2015, Fav: NEWISH-Cadillac-XT5
# Id: 30200, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 29112, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 18848, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 24026, Make: Chevrolet, Model: Camaro, Year: 2010, Fav: OLDISH-Chevrolet-Camaro
# Id: 23367, Make: Ford, Model: Expedition, Year: 2012, Fav: OLDISH-Ford-Expedition
# Id: 20174, Make: BMW, Model: 330i, Year: 2018, Fav: NEWISH-BMW-330i
# Id: 30515, Make: Ford, Model: F150, Year: 2014, Fav: NEWISH-Ford-F150
# Id: 26526, Make: Buick, Model: LaCrosse, Year: 2016, Fav: NEWISH-Buick-LaCrosse
# Id: 17132, Make: Cadillac, Model: XT5, Year: 2012, Fav: OLDISH-Cadillac-XT5
# Id: 20280, Make: Nissan, Model: Altima, Year: 2015, Fav: NEWISH-Nissan-Altima
# Id: 27157, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 22564, Make: Chrysler, Model: 200, Year: 2010, Fav: OLDISH-Chrysler-200
# Id: 16190, Make: Honda, Model: Civic, Year: 2014, Fav: NEWISH-Honda-Civic
# Id: 26836, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 17473, Make: Chevrolet, Model: Traverse, Year: 2010, Fav: OLDISH-Chevrolet-Traverse
# Id: 22167, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 29975, Make: BMW, Model: 430i, Year: 2015, Fav: NEWISH-BMW-430i
# Id: 23067, Make: Toyota, Model: Rav4, Year: 2013, Fav: OLDISH-Toyota-Rav4
# Id: 28854, Make: GMC, Model: Yukon, Year: 2014, Fav: NEWISH-GMC-Yukon
# Id: 19096, Make: Dodge, Model: Ram, Year: 2012, Fav: OLDISH-Dodge-Ram
# Id: 23184, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 24543, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 25625, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 28795, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 31823, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 24787, Make: Ford, Model: Escape, Year: 2014, Fav: NEWISH-Ford-Escape
# Id: 27298, Make: Ford, Model: Fusion, Year: 2017, Fav: NEWISH-Ford-Fusion
# Id: 25913, Make: Chrysler, Model: 300, Year: 2018, Fav: NEWISH-Chrysler-300
# Id: 28721, Make: Cadillac, Model: Escalade, Year: 2015, Fav: NEWISH-Cadillac-Escalade
# Id: 18759, Make: Chevrolet, Model: Camaro, Year: 2014, Fav: NEWISH-Chevrolet-Camaro
# Id: 30082, Make: Nissan, Model: Leaf, Year: 2012, Fav: OLDISH-Nissan-Leaf
# Id: 28581, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 27599, Make: Toyota, Model: Sienna, Year: 2013, Fav: OLDISH-Toyota-Sienna
# Id: 29091, Make: Chevrolet, Model: Silverado, Year: 2018, Fav: NEWISH-Chevrolet-Silverado
# Id: 19715, Make: Honda, Model: Odyssey, Year: 2010, Fav: OLDISH-Honda-Odyssey
# Id: 24797, Make: Buick, Model: LaCrosse, Year: 2012, Fav: OLDISH-Buick-LaCrosse
# Id: 19394, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 24809, Make: Dodge, Model: Caravan, Year: 2016, Fav: NEWISH-Dodge-Caravan
# Id: 23899, Make: Chevrolet, Model: Tahoe, Year: 2016, Fav: NEWISH-Chevrolet-Tahoe
# Id: 23029, Make: GMC, Model: Yukon, Year: 2008, Fav: OLDISH-GMC-Yukon
# Id: 28245, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 19054, Make: Jeep, Model: Cherokee, Year: 2014, Fav: NEWISH-Jeep-Cherokee
# Id: 20265, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 24730, Make: Ford, Model: F150, Year: 2010, Fav: OLDISH-Ford-F150
# Id: 25219, Make: Toyota, Model: Prius, Year: 2013, Fav: OLDISH-Toyota-Prius
# Id: 27785, Make: Dodge, Model: Caravan, Year: 2011, Fav: OLDISH-Dodge-Caravan
# Id: 24315, Make: Chrysler, Model: 200, Year: 2015, Fav: NEWISH-Chrysler-200
# Id: 20606, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# **rank 12
#
# Ranking for user that prefers: NEWISH-Volkswagen-Golf
#
# Ranking for user: 18249
# Id: 38505, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 28245, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 19054, Make: Jeep, Model: Cherokee, Year: 2014, Fav: NEWISH-Jeep-Cherokee
# Id: 21758, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 24809, Make: Dodge, Model: Caravan, Year: 2016, Fav: NEWISH-Dodge-Caravan
# Id: 29315, Make: Volvo, Model: V60, Year: 2013, Fav: OLDISH-Volvo-V60
# Id: 22167, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 27157, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 16190, Make: Honda, Model: Civic, Year: 2014, Fav: NEWISH-Honda-Civic
# Id: 26539, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 26526, Make: Buick, Model: LaCrosse, Year: 2016, Fav: NEWISH-Buick-LaCrosse
# Id: 25146, Make: Toyota, Model: Prius, Year: 2014, Fav: NEWISH-Toyota-Prius
# Id: 29112, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 21480, Make: Jeep, Model: Cherokee, Year: 2011, Fav: OLDISH-Jeep-Cherokee
# Id: 29091, Make: Chevrolet, Model: Silverado, Year: 2018, Fav: NEWISH-Chevrolet-Silverado
# Id: 27599, Make: Toyota, Model: Sienna, Year: 2013, Fav: OLDISH-Toyota-Sienna
# Id: 29318, Make: Ford, Model: Expedition, Year: 2016, Fav: NEWISH-Ford-Expedition
# Id: 22385, Make: Chrysler, Model: Pacifica, Year: 2014, Fav: NEWISH-Chrysler-Pacifica
# Id: 23184, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 23067, Make: Toyota, Model: Rav4, Year: 2013, Fav: OLDISH-Toyota-Rav4
# Id: 21689, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 32765, Make: Buick, Model: Enclave, Year: 2010, Fav: OLDISH-Buick-Enclave
# Id: 25913, Make: Chrysler, Model: 300, Year: 2018, Fav: NEWISH-Chrysler-300
# Id: 28854, Make: GMC, Model: Yukon, Year: 2014, Fav: NEWISH-GMC-Yukon
# Id: 18514, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 26280, Make: Toyota, Model: Camry, Year: 2017, Fav: NEWISH-Toyota-Camry
# Id: 28972, Make: Ford, Model: Escape, Year: 2012, Fav: OLDISH-Ford-Escape
# Id: 28721, Make: Cadillac, Model: Escalade, Year: 2015, Fav: NEWISH-Cadillac-Escalade
# Id: 16650, Make: Honda, Model: Accord, Year: 2014, Fav: NEWISH-Honda-Accord
# Id: 20174, Make: BMW, Model: 330i, Year: 2018, Fav: NEWISH-BMW-330i
# Id: 17132, Make: Cadillac, Model: XT5, Year: 2012, Fav: OLDISH-Cadillac-XT5
# Id: 20185, Make: Volkswagen, Model: Jetta, Year: 2011, Fav: OLDISH-Volkswagen-Jetta
# Id: 19715, Make: Honda, Model: Odyssey, Year: 2010, Fav: OLDISH-Honda-Odyssey
# Id: 22801, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 27300, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 17473, Make: Chevrolet, Model: Traverse, Year: 2010, Fav: OLDISH-Chevrolet-Traverse
# Id: 27298, Make: Ford, Model: Fusion, Year: 2017, Fav: NEWISH-Ford-Fusion
# Id: 26796, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 28523, Make: Ford, Model: Edge, Year: 2014, Fav: NEWISH-Ford-Edge
# Id: 25625, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 28620, Make: Toyota, Model: Camry, Year: 2013, Fav: OLDISH-Toyota-Camry
# Id: 28581, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 27785, Make: Dodge, Model: Caravan, Year: 2011, Fav: OLDISH-Dodge-Caravan
# Id: 30082, Make: Nissan, Model: Leaf, Year: 2012, Fav: OLDISH-Nissan-Leaf
# Id: 32504, Make: Nissan, Model: Altima, Year: 2012, Fav: OLDISH-Nissan-Altima
# Id: 33149, Make: Dodge, Model: Durango, Year: 2009, Fav: OLDISH-Dodge-Durango
# Id: 23367, Make: Ford, Model: Expedition, Year: 2012, Fav: OLDISH-Ford-Expedition
# Id: 19394, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 24797, Make: Buick, Model: LaCrosse, Year: 2012, Fav: OLDISH-Buick-LaCrosse
# Id: 29351, Make: Ford, Model: Explorer, Year: 2012, Fav: OLDISH-Ford-Explorer
# Id: 33634, Make: Honda, Model: Civic, Year: 2013, Fav: OLDISH-Honda-Civic
# Id: 41302, Make: Chevrolet, Model: Silverado, Year: 2010, Fav: OLDISH-Chevrolet-Silverado
# Id: 10115, Make: GMC, Model: Acadia, Year: 2015, Fav: NEWISH-GMC-Acadia
# Id: 26664, Make: Dodge, Model: Durango, Year: 2014, Fav: NEWISH-Dodge-Durango
# Id: 16902, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 23029, Make: GMC, Model: Yukon, Year: 2008, Fav: OLDISH-GMC-Yukon
# Id: 24315, Make: Chrysler, Model: 200, Year: 2015, Fav: NEWISH-Chrysler-200
# Id: 24126, Make: Buick, Model: Enclave, Year: 2017, Fav: NEWISH-Buick-Enclave
# Id: 23634, Make: Volkswagen, Model: Jetta, Year: 2017, Fav: NEWISH-Volkswagen-Jetta
# Id: 18592, Make: Toyota, Model: Sienna, Year: 2016, Fav: NEWISH-Toyota-Sienna
# Id: 27595, Make: Cadillac, Model: Escalade, Year: 2008, Fav: OLDISH-Cadillac-Escalade
# Id: 24026, Make: Chevrolet, Model: Camaro, Year: 2010, Fav: OLDISH-Chevrolet-Camaro
# Id: 23268, Make: Chevrolet, Model: Suburban, Year: 2012, Fav: OLDISH-Chevrolet-Suburban
# Id: 37961, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 22564, Make: Chrysler, Model: 200, Year: 2010, Fav: OLDISH-Chrysler-200
# Id: 24787, Make: Ford, Model: Escape, Year: 2014, Fav: NEWISH-Ford-Escape
# Id: 27047, Make: Toyota, Model: Corrola, Year: 2015, Fav: NEWISH-Toyota-Corrola
# Id: 24730, Make: Ford, Model: F150, Year: 2010, Fav: OLDISH-Ford-F150
# Id: 25219, Make: Toyota, Model: Prius, Year: 2013, Fav: OLDISH-Toyota-Prius
# Id: 19096, Make: Dodge, Model: Ram, Year: 2012, Fav: OLDISH-Dodge-Ram
# Id: 31823, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 26612, Make: Hyundai, Model: Santa Fe, Year: 2011, Fav: OLDISH-Hyundai-Santa Fe
# Id: 28278, Make: Chevrolet, Model: Traverse, Year: 2018, Fav: NEWISH-Chevrolet-Traverse
# Id: 20280, Make: Nissan, Model: Altima, Year: 2015, Fav: NEWISH-Nissan-Altima
# Id: 12022, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 20265, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 26836, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 28795, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 29286, Make: Toyota, Model: Corrola, Year: 2010, Fav: OLDISH-Toyota-Corrola
# Id: 20256, Make: Ford, Model: Edge, Year: 2009, Fav: OLDISH-Ford-Edge
# Id: 23899, Make: Chevrolet, Model: Tahoe, Year: 2016, Fav: NEWISH-Chevrolet-Tahoe
# Id: 18210, Make: Jeep, Model: Grand Cherokee, Year: 2014, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 20606, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 30200, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 21564, Make: Volvo, Model: 240, Year: 2013, Fav: OLDISH-Volvo-240
# Id: 18759, Make: Chevrolet, Model: Camaro, Year: 2014, Fav: NEWISH-Chevrolet-Camaro
# Id: 23524, Make: Cadillac, Model: XT5, Year: 2015, Fav: NEWISH-Cadillac-XT5
# Id: 30515, Make: Ford, Model: F150, Year: 2014, Fav: NEWISH-Ford-F150
# Id: 18848, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 24364, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 24543, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 15726, Make: Buick, Model: Regal, Year: 2012, Fav: OLDISH-Buick-Regal
# Id: 29975, Make: BMW, Model: 430i, Year: 2015, Fav: NEWISH-BMW-430i
# Id: 24211, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 30781, Make: Volvo, Model: 240, Year: 2015, Fav: NEWISH-Volvo-240
# Id: 23768, Make: Ford, Model: Mustang, Year: 2014, Fav: NEWISH-Ford-Mustang
# Id: 23560, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 26112, Make: Chrysler, Model: Pacifica, Year: 2009, Fav: OLDISH-Chrysler-Pacifica
# Id: 28429, Make: Chevrolet, Model: Suburban, Year: 2014, Fav: NEWISH-Chevrolet-Suburban
# Id: 30388, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# **rank 0
#
# Ranking for user that prefers: OLDISH-Volvo-240
#
# Ranking for user: 15654
# Id: 21564, Make: Volvo, Model: 240, Year: 2013, Fav: OLDISH-Volvo-240
# Id: 20265, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 19096, Make: Dodge, Model: Ram, Year: 2012, Fav: OLDISH-Dodge-Ram
# Id: 23560, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 24364, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 22564, Make: Chrysler, Model: 200, Year: 2010, Fav: OLDISH-Chrysler-200
# Id: 31823, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 20606, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 28278, Make: Chevrolet, Model: Traverse, Year: 2018, Fav: NEWISH-Chevrolet-Traverse
# Id: 24126, Make: Buick, Model: Enclave, Year: 2017, Fav: NEWISH-Buick-Enclave
# Id: 28245, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 18759, Make: Chevrolet, Model: Camaro, Year: 2014, Fav: NEWISH-Chevrolet-Camaro
# Id: 26112, Make: Chrysler, Model: Pacifica, Year: 2009, Fav: OLDISH-Chrysler-Pacifica
# Id: 17132, Make: Cadillac, Model: XT5, Year: 2012, Fav: OLDISH-Cadillac-XT5
# Id: 33634, Make: Honda, Model: Civic, Year: 2013, Fav: OLDISH-Honda-Civic
# Id: 29112, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 29975, Make: BMW, Model: 430i, Year: 2015, Fav: NEWISH-BMW-430i
# Id: 30388, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 22801, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 27599, Make: Toyota, Model: Sienna, Year: 2013, Fav: OLDISH-Toyota-Sienna
# Id: 18848, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 25146, Make: Toyota, Model: Prius, Year: 2014, Fav: NEWISH-Toyota-Prius
# Id: 28721, Make: Cadillac, Model: Escalade, Year: 2015, Fav: NEWISH-Cadillac-Escalade
# Id: 32765, Make: Buick, Model: Enclave, Year: 2010, Fav: OLDISH-Buick-Enclave
# Id: 25913, Make: Chrysler, Model: 300, Year: 2018, Fav: NEWISH-Chrysler-300
# Id: 30200, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 21480, Make: Jeep, Model: Cherokee, Year: 2011, Fav: OLDISH-Jeep-Cherokee
# Id: 27785, Make: Dodge, Model: Caravan, Year: 2011, Fav: OLDISH-Dodge-Caravan
# Id: 24543, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 26280, Make: Toyota, Model: Camry, Year: 2017, Fav: NEWISH-Toyota-Camry
# Id: 12022, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 23899, Make: Chevrolet, Model: Tahoe, Year: 2016, Fav: NEWISH-Chevrolet-Tahoe
# Id: 16190, Make: Honda, Model: Civic, Year: 2014, Fav: NEWISH-Honda-Civic
# Id: 33149, Make: Dodge, Model: Durango, Year: 2009, Fav: OLDISH-Dodge-Durango
# Id: 18592, Make: Toyota, Model: Sienna, Year: 2016, Fav: NEWISH-Toyota-Sienna
# Id: 30082, Make: Nissan, Model: Leaf, Year: 2012, Fav: OLDISH-Nissan-Leaf
# Id: 19394, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 28854, Make: GMC, Model: Yukon, Year: 2014, Fav: NEWISH-GMC-Yukon
# Id: 28620, Make: Toyota, Model: Camry, Year: 2013, Fav: OLDISH-Toyota-Camry
# Id: 24797, Make: Buick, Model: LaCrosse, Year: 2012, Fav: OLDISH-Buick-LaCrosse
# Id: 29286, Make: Toyota, Model: Corrola, Year: 2010, Fav: OLDISH-Toyota-Corrola
# Id: 27595, Make: Cadillac, Model: Escalade, Year: 2008, Fav: OLDISH-Cadillac-Escalade
# Id: 23067, Make: Toyota, Model: Rav4, Year: 2013, Fav: OLDISH-Toyota-Rav4
# Id: 10115, Make: GMC, Model: Acadia, Year: 2015, Fav: NEWISH-GMC-Acadia
# Id: 26664, Make: Dodge, Model: Durango, Year: 2014, Fav: NEWISH-Dodge-Durango
# Id: 20174, Make: BMW, Model: 330i, Year: 2018, Fav: NEWISH-BMW-330i
# Id: 37961, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 16650, Make: Honda, Model: Accord, Year: 2014, Fav: NEWISH-Honda-Accord
# Id: 23524, Make: Cadillac, Model: XT5, Year: 2015, Fav: NEWISH-Cadillac-XT5
# Id: 20280, Make: Nissan, Model: Altima, Year: 2015, Fav: NEWISH-Nissan-Altima
# Id: 26796, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 24787, Make: Ford, Model: Escape, Year: 2014, Fav: NEWISH-Ford-Escape
# Id: 16902, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 17473, Make: Chevrolet, Model: Traverse, Year: 2010, Fav: OLDISH-Chevrolet-Traverse
# Id: 24730, Make: Ford, Model: F150, Year: 2010, Fav: OLDISH-Ford-F150
# Id: 18210, Make: Jeep, Model: Grand Cherokee, Year: 2014, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 22167, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 29351, Make: Ford, Model: Explorer, Year: 2012, Fav: OLDISH-Ford-Explorer
# Id: 26612, Make: Hyundai, Model: Santa Fe, Year: 2011, Fav: OLDISH-Hyundai-Santa Fe
# Id: 41302, Make: Chevrolet, Model: Silverado, Year: 2010, Fav: OLDISH-Chevrolet-Silverado
# Id: 19054, Make: Jeep, Model: Cherokee, Year: 2014, Fav: NEWISH-Jeep-Cherokee
# Id: 23367, Make: Ford, Model: Expedition, Year: 2012, Fav: OLDISH-Ford-Expedition
# Id: 21689, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 25219, Make: Toyota, Model: Prius, Year: 2013, Fav: OLDISH-Toyota-Prius
# Id: 15726, Make: Buick, Model: Regal, Year: 2012, Fav: OLDISH-Buick-Regal
# Id: 28972, Make: Ford, Model: Escape, Year: 2012, Fav: OLDISH-Ford-Escape
# Id: 20256, Make: Ford, Model: Edge, Year: 2009, Fav: OLDISH-Ford-Edge
# Id: 21758, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 38505, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 24315, Make: Chrysler, Model: 200, Year: 2015, Fav: NEWISH-Chrysler-200
# Id: 23634, Make: Volkswagen, Model: Jetta, Year: 2017, Fav: NEWISH-Volkswagen-Jetta
# Id: 24026, Make: Chevrolet, Model: Camaro, Year: 2010, Fav: OLDISH-Chevrolet-Camaro
# Id: 19715, Make: Honda, Model: Odyssey, Year: 2010, Fav: OLDISH-Honda-Odyssey
# Id: 22385, Make: Chrysler, Model: Pacifica, Year: 2014, Fav: NEWISH-Chrysler-Pacifica
# Id: 18514, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 23029, Make: GMC, Model: Yukon, Year: 2008, Fav: OLDISH-GMC-Yukon
# Id: 20185, Make: Volkswagen, Model: Jetta, Year: 2011, Fav: OLDISH-Volkswagen-Jetta
# Id: 29318, Make: Ford, Model: Expedition, Year: 2016, Fav: NEWISH-Ford-Expedition
# Id: 30781, Make: Volvo, Model: 240, Year: 2015, Fav: NEWISH-Volvo-240
# Id: 26526, Make: Buick, Model: LaCrosse, Year: 2016, Fav: NEWISH-Buick-LaCrosse
# Id: 24809, Make: Dodge, Model: Caravan, Year: 2016, Fav: NEWISH-Dodge-Caravan
# Id: 28795, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 25625, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 23768, Make: Ford, Model: Mustang, Year: 2014, Fav: NEWISH-Ford-Mustang
# Id: 30515, Make: Ford, Model: F150, Year: 2014, Fav: NEWISH-Ford-F150
# Id: 32504, Make: Nissan, Model: Altima, Year: 2012, Fav: OLDISH-Nissan-Altima
# Id: 28581, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 23184, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 29091, Make: Chevrolet, Model: Silverado, Year: 2018, Fav: NEWISH-Chevrolet-Silverado
# Id: 29315, Make: Volvo, Model: V60, Year: 2013, Fav: OLDISH-Volvo-V60
# Id: 27300, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 28523, Make: Ford, Model: Edge, Year: 2014, Fav: NEWISH-Ford-Edge
# Id: 26836, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 23268, Make: Chevrolet, Model: Suburban, Year: 2012, Fav: OLDISH-Chevrolet-Suburban
# Id: 26539, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 27157, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 27298, Make: Ford, Model: Fusion, Year: 2017, Fav: NEWISH-Ford-Fusion
# Id: 28429, Make: Chevrolet, Model: Suburban, Year: 2014, Fav: NEWISH-Chevrolet-Suburban
# Id: 24211, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 27047, Make: Toyota, Model: Corrola, Year: 2015, Fav: NEWISH-Toyota-Corrola
# **rank 0
#
# Ranking for user that prefers: OLDISH-Chrysler-300
#
# Ranking for user: 17130
# Id: 19394, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 25913, Make: Chrysler, Model: 300, Year: 2018, Fav: NEWISH-Chrysler-300
# Id: 21480, Make: Jeep, Model: Cherokee, Year: 2011, Fav: OLDISH-Jeep-Cherokee
# Id: 23634, Make: Volkswagen, Model: Jetta, Year: 2017, Fav: NEWISH-Volkswagen-Jetta
# Id: 19715, Make: Honda, Model: Odyssey, Year: 2010, Fav: OLDISH-Honda-Odyssey
# Id: 26526, Make: Buick, Model: LaCrosse, Year: 2016, Fav: NEWISH-Buick-LaCrosse
# Id: 24315, Make: Chrysler, Model: 200, Year: 2015, Fav: NEWISH-Chrysler-200
# Id: 26612, Make: Hyundai, Model: Santa Fe, Year: 2011, Fav: OLDISH-Hyundai-Santa Fe
# Id: 22801, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 27599, Make: Toyota, Model: Sienna, Year: 2013, Fav: OLDISH-Toyota-Sienna
# Id: 28278, Make: Chevrolet, Model: Traverse, Year: 2018, Fav: NEWISH-Chevrolet-Traverse
# Id: 24543, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 21689, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 29091, Make: Chevrolet, Model: Silverado, Year: 2018, Fav: NEWISH-Chevrolet-Silverado
# Id: 27157, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 30082, Make: Nissan, Model: Leaf, Year: 2012, Fav: OLDISH-Nissan-Leaf
# Id: 30200, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 32765, Make: Buick, Model: Enclave, Year: 2010, Fav: OLDISH-Buick-Enclave
# Id: 27785, Make: Dodge, Model: Caravan, Year: 2011, Fav: OLDISH-Dodge-Caravan
# Id: 17473, Make: Chevrolet, Model: Traverse, Year: 2010, Fav: OLDISH-Chevrolet-Traverse
# Id: 20185, Make: Volkswagen, Model: Jetta, Year: 2011, Fav: OLDISH-Volkswagen-Jetta
# Id: 19096, Make: Dodge, Model: Ram, Year: 2012, Fav: OLDISH-Dodge-Ram
# Id: 20265, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 24126, Make: Buick, Model: Enclave, Year: 2017, Fav: NEWISH-Buick-Enclave
# Id: 28245, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 23067, Make: Toyota, Model: Rav4, Year: 2013, Fav: OLDISH-Toyota-Rav4
# Id: 26280, Make: Toyota, Model: Camry, Year: 2017, Fav: NEWISH-Toyota-Camry
# Id: 16190, Make: Honda, Model: Civic, Year: 2014, Fav: NEWISH-Honda-Civic
# Id: 23899, Make: Chevrolet, Model: Tahoe, Year: 2016, Fav: NEWISH-Chevrolet-Tahoe
# Id: 33149, Make: Dodge, Model: Durango, Year: 2009, Fav: OLDISH-Dodge-Durango
# Id: 28721, Make: Cadillac, Model: Escalade, Year: 2015, Fav: NEWISH-Cadillac-Escalade
# Id: 18514, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 29315, Make: Volvo, Model: V60, Year: 2013, Fav: OLDISH-Volvo-V60
# Id: 22564, Make: Chrysler, Model: 200, Year: 2010, Fav: OLDISH-Chrysler-200
# Id: 25625, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 38505, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 28620, Make: Toyota, Model: Camry, Year: 2013, Fav: OLDISH-Toyota-Camry
# Id: 23524, Make: Cadillac, Model: XT5, Year: 2015, Fav: NEWISH-Cadillac-XT5
# Id: 29112, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 23367, Make: Ford, Model: Expedition, Year: 2012, Fav: OLDISH-Ford-Expedition
# Id: 25146, Make: Toyota, Model: Prius, Year: 2014, Fav: NEWISH-Toyota-Prius
# Id: 19054, Make: Jeep, Model: Cherokee, Year: 2014, Fav: NEWISH-Jeep-Cherokee
# Id: 10115, Make: GMC, Model: Acadia, Year: 2015, Fav: NEWISH-GMC-Acadia
# Id: 26664, Make: Dodge, Model: Durango, Year: 2014, Fav: NEWISH-Dodge-Durango
# Id: 21564, Make: Volvo, Model: 240, Year: 2013, Fav: OLDISH-Volvo-240
# Id: 32504, Make: Nissan, Model: Altima, Year: 2012, Fav: OLDISH-Nissan-Altima
# Id: 16902, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 22167, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 26796, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 23268, Make: Chevrolet, Model: Suburban, Year: 2012, Fav: OLDISH-Chevrolet-Suburban
# Id: 23560, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 20606, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 37961, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 41302, Make: Chevrolet, Model: Silverado, Year: 2010, Fav: OLDISH-Chevrolet-Silverado
# Id: 18848, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 29318, Make: Ford, Model: Expedition, Year: 2016, Fav: NEWISH-Ford-Expedition
# Id: 17132, Make: Cadillac, Model: XT5, Year: 2012, Fav: OLDISH-Cadillac-XT5
# Id: 33634, Make: Honda, Model: Civic, Year: 2013, Fav: OLDISH-Honda-Civic
# Id: 29975, Make: BMW, Model: 430i, Year: 2015, Fav: NEWISH-BMW-430i
# Id: 20280, Make: Nissan, Model: Altima, Year: 2015, Fav: NEWISH-Nissan-Altima
# Id: 20174, Make: BMW, Model: 330i, Year: 2018, Fav: NEWISH-BMW-330i
# Id: 18592, Make: Toyota, Model: Sienna, Year: 2016, Fav: NEWISH-Toyota-Sienna
# Id: 29286, Make: Toyota, Model: Corrola, Year: 2010, Fav: OLDISH-Toyota-Corrola
# Id: 27047, Make: Toyota, Model: Corrola, Year: 2015, Fav: NEWISH-Toyota-Corrola
# Id: 30515, Make: Ford, Model: F150, Year: 2014, Fav: NEWISH-Ford-F150
# Id: 21758, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 12022, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 25219, Make: Toyota, Model: Prius, Year: 2013, Fav: OLDISH-Toyota-Prius
# Id: 27300, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 23184, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 31823, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 24797, Make: Buick, Model: LaCrosse, Year: 2012, Fav: OLDISH-Buick-LaCrosse
# Id: 22385, Make: Chrysler, Model: Pacifica, Year: 2014, Fav: NEWISH-Chrysler-Pacifica
# Id: 27595, Make: Cadillac, Model: Escalade, Year: 2008, Fav: OLDISH-Cadillac-Escalade
# Id: 24787, Make: Ford, Model: Escape, Year: 2014, Fav: NEWISH-Ford-Escape
# Id: 28581, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 28523, Make: Ford, Model: Edge, Year: 2014, Fav: NEWISH-Ford-Edge
# Id: 26836, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 24364, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 24809, Make: Dodge, Model: Caravan, Year: 2016, Fav: NEWISH-Dodge-Caravan
# Id: 26112, Make: Chrysler, Model: Pacifica, Year: 2009, Fav: OLDISH-Chrysler-Pacifica
# Id: 28972, Make: Ford, Model: Escape, Year: 2012, Fav: OLDISH-Ford-Escape
# Id: 30781, Make: Volvo, Model: 240, Year: 2015, Fav: NEWISH-Volvo-240
# Id: 18759, Make: Chevrolet, Model: Camaro, Year: 2014, Fav: NEWISH-Chevrolet-Camaro
# Id: 24211, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 18210, Make: Jeep, Model: Grand Cherokee, Year: 2014, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 23029, Make: GMC, Model: Yukon, Year: 2008, Fav: OLDISH-GMC-Yukon
# Id: 28795, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 15726, Make: Buick, Model: Regal, Year: 2012, Fav: OLDISH-Buick-Regal
# Id: 28854, Make: GMC, Model: Yukon, Year: 2014, Fav: NEWISH-GMC-Yukon
# Id: 16650, Make: Honda, Model: Accord, Year: 2014, Fav: NEWISH-Honda-Accord
# Id: 24730, Make: Ford, Model: F150, Year: 2010, Fav: OLDISH-Ford-F150
# Id: 20256, Make: Ford, Model: Edge, Year: 2009, Fav: OLDISH-Ford-Edge
# Id: 26539, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 27298, Make: Ford, Model: Fusion, Year: 2017, Fav: NEWISH-Ford-Fusion
# Id: 23768, Make: Ford, Model: Mustang, Year: 2014, Fav: NEWISH-Ford-Mustang
# Id: 29351, Make: Ford, Model: Explorer, Year: 2012, Fav: OLDISH-Ford-Explorer
# Id: 28429, Make: Chevrolet, Model: Suburban, Year: 2014, Fav: NEWISH-Chevrolet-Suburban
# Id: 30388, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 24026, Make: Chevrolet, Model: Camaro, Year: 2010, Fav: OLDISH-Chevrolet-Camaro
# **rank 0
#
# Ranking for user that prefers: NEWISH-Ford-Fusion
#
# Ranking for user: 15490
# Id: 27298, Make: Ford, Model: Fusion, Year: 2017, Fav: NEWISH-Ford-Fusion
# Id: 23184, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 27047, Make: Toyota, Model: Corrola, Year: 2015, Fav: NEWISH-Toyota-Corrola
# Id: 27300, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 30781, Make: Volvo, Model: 240, Year: 2015, Fav: NEWISH-Volvo-240
# Id: 23029, Make: GMC, Model: Yukon, Year: 2008, Fav: OLDISH-GMC-Yukon
# Id: 26836, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 26539, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 24809, Make: Dodge, Model: Caravan, Year: 2016, Fav: NEWISH-Dodge-Caravan
# Id: 16650, Make: Honda, Model: Accord, Year: 2014, Fav: NEWISH-Honda-Accord
# Id: 25219, Make: Toyota, Model: Prius, Year: 2013, Fav: OLDISH-Toyota-Prius
# Id: 19054, Make: Jeep, Model: Cherokee, Year: 2014, Fav: NEWISH-Jeep-Cherokee
# Id: 21758, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 29318, Make: Ford, Model: Expedition, Year: 2016, Fav: NEWISH-Ford-Expedition
# Id: 20280, Make: Nissan, Model: Altima, Year: 2015, Fav: NEWISH-Nissan-Altima
# Id: 24211, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 26526, Make: Buick, Model: LaCrosse, Year: 2016, Fav: NEWISH-Buick-LaCrosse
# Id: 17473, Make: Chevrolet, Model: Traverse, Year: 2010, Fav: OLDISH-Chevrolet-Traverse
# Id: 30515, Make: Ford, Model: F150, Year: 2014, Fav: NEWISH-Ford-F150
# Id: 27595, Make: Cadillac, Model: Escalade, Year: 2008, Fav: OLDISH-Cadillac-Escalade
# Id: 21689, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 20174, Make: BMW, Model: 330i, Year: 2018, Fav: NEWISH-BMW-330i
# Id: 28523, Make: Ford, Model: Edge, Year: 2014, Fav: NEWISH-Ford-Edge
# Id: 24787, Make: Ford, Model: Escape, Year: 2014, Fav: NEWISH-Ford-Escape
# Id: 28581, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 19715, Make: Honda, Model: Odyssey, Year: 2010, Fav: OLDISH-Honda-Odyssey
# Id: 38505, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 23067, Make: Toyota, Model: Rav4, Year: 2013, Fav: OLDISH-Toyota-Rav4
# Id: 28972, Make: Ford, Model: Escape, Year: 2012, Fav: OLDISH-Ford-Escape
# Id: 25625, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 32504, Make: Nissan, Model: Altima, Year: 2012, Fav: OLDISH-Nissan-Altima
# Id: 24026, Make: Chevrolet, Model: Camaro, Year: 2010, Fav: OLDISH-Chevrolet-Camaro
# Id: 18514, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 28245, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 28795, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 25913, Make: Chrysler, Model: 300, Year: 2018, Fav: NEWISH-Chrysler-300
# Id: 24730, Make: Ford, Model: F150, Year: 2010, Fav: OLDISH-Ford-F150
# Id: 29975, Make: BMW, Model: 430i, Year: 2015, Fav: NEWISH-BMW-430i
# Id: 30082, Make: Nissan, Model: Leaf, Year: 2012, Fav: OLDISH-Nissan-Leaf
# Id: 28278, Make: Chevrolet, Model: Traverse, Year: 2018, Fav: NEWISH-Chevrolet-Traverse
# Id: 12022, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 32765, Make: Buick, Model: Enclave, Year: 2010, Fav: OLDISH-Buick-Enclave
# Id: 33149, Make: Dodge, Model: Durango, Year: 2009, Fav: OLDISH-Dodge-Durango
# Id: 16902, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 41302, Make: Chevrolet, Model: Silverado, Year: 2010, Fav: OLDISH-Chevrolet-Silverado
# Id: 26280, Make: Toyota, Model: Camry, Year: 2017, Fav: NEWISH-Toyota-Camry
# Id: 24797, Make: Buick, Model: LaCrosse, Year: 2012, Fav: OLDISH-Buick-LaCrosse
# Id: 26796, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 28620, Make: Toyota, Model: Camry, Year: 2013, Fav: OLDISH-Toyota-Camry
# Id: 18592, Make: Toyota, Model: Sienna, Year: 2016, Fav: NEWISH-Toyota-Sienna
# Id: 26664, Make: Dodge, Model: Durango, Year: 2014, Fav: NEWISH-Dodge-Durango
# Id: 10115, Make: GMC, Model: Acadia, Year: 2015, Fav: NEWISH-GMC-Acadia
# Id: 27157, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 23768, Make: Ford, Model: Mustang, Year: 2014, Fav: NEWISH-Ford-Mustang
# Id: 25146, Make: Toyota, Model: Prius, Year: 2014, Fav: NEWISH-Toyota-Prius
# Id: 20185, Make: Volkswagen, Model: Jetta, Year: 2011, Fav: OLDISH-Volkswagen-Jetta
# Id: 28429, Make: Chevrolet, Model: Suburban, Year: 2014, Fav: NEWISH-Chevrolet-Suburban
# Id: 37961, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 15726, Make: Buick, Model: Regal, Year: 2012, Fav: OLDISH-Buick-Regal
# Id: 29091, Make: Chevrolet, Model: Silverado, Year: 2018, Fav: NEWISH-Chevrolet-Silverado
# Id: 30388, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 20256, Make: Ford, Model: Edge, Year: 2009, Fav: OLDISH-Ford-Edge
# Id: 27785, Make: Dodge, Model: Caravan, Year: 2011, Fav: OLDISH-Dodge-Caravan
# Id: 27599, Make: Toyota, Model: Sienna, Year: 2013, Fav: OLDISH-Toyota-Sienna
# Id: 23367, Make: Ford, Model: Expedition, Year: 2012, Fav: OLDISH-Ford-Expedition
# Id: 29315, Make: Volvo, Model: V60, Year: 2013, Fav: OLDISH-Volvo-V60
# Id: 22385, Make: Chrysler, Model: Pacifica, Year: 2014, Fav: NEWISH-Chrysler-Pacifica
# Id: 18210, Make: Jeep, Model: Grand Cherokee, Year: 2014, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 33634, Make: Honda, Model: Civic, Year: 2013, Fav: OLDISH-Honda-Civic
# Id: 23899, Make: Chevrolet, Model: Tahoe, Year: 2016, Fav: NEWISH-Chevrolet-Tahoe
# Id: 22801, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 29351, Make: Ford, Model: Explorer, Year: 2012, Fav: OLDISH-Ford-Explorer
# Id: 18759, Make: Chevrolet, Model: Camaro, Year: 2014, Fav: NEWISH-Chevrolet-Camaro
# Id: 20265, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 24315, Make: Chrysler, Model: 200, Year: 2015, Fav: NEWISH-Chrysler-200
# Id: 16190, Make: Honda, Model: Civic, Year: 2014, Fav: NEWISH-Honda-Civic
# Id: 22167, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 29112, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 28721, Make: Cadillac, Model: Escalade, Year: 2015, Fav: NEWISH-Cadillac-Escalade
# Id: 23634, Make: Volkswagen, Model: Jetta, Year: 2017, Fav: NEWISH-Volkswagen-Jetta
# Id: 20606, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 28854, Make: GMC, Model: Yukon, Year: 2014, Fav: NEWISH-GMC-Yukon
# Id: 24543, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 23524, Make: Cadillac, Model: XT5, Year: 2015, Fav: NEWISH-Cadillac-XT5
# Id: 21480, Make: Jeep, Model: Cherokee, Year: 2011, Fav: OLDISH-Jeep-Cherokee
# Id: 18848, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 19394, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 24126, Make: Buick, Model: Enclave, Year: 2017, Fav: NEWISH-Buick-Enclave
# Id: 19096, Make: Dodge, Model: Ram, Year: 2012, Fav: OLDISH-Dodge-Ram
# Id: 31823, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 17132, Make: Cadillac, Model: XT5, Year: 2012, Fav: OLDISH-Cadillac-XT5
# Id: 29286, Make: Toyota, Model: Corrola, Year: 2010, Fav: OLDISH-Toyota-Corrola
# Id: 23268, Make: Chevrolet, Model: Suburban, Year: 2012, Fav: OLDISH-Chevrolet-Suburban
# Id: 30200, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 22564, Make: Chrysler, Model: 200, Year: 2010, Fav: OLDISH-Chrysler-200
# Id: 21564, Make: Volvo, Model: 240, Year: 2013, Fav: OLDISH-Volvo-240
# Id: 26612, Make: Hyundai, Model: Santa Fe, Year: 2011, Fav: OLDISH-Hyundai-Santa Fe
# Id: 24364, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 23560, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 26112, Make: Chrysler, Model: Pacifica, Year: 2009, Fav: OLDISH-Chrysler-Pacifica
# **rank 0
#
# Ranking for user that prefers: NEWISH-Jeep-Grand Cherokee
#
# Ranking for user: 14014
# Id: 18210, Make: Jeep, Model: Grand Cherokee, Year: 2014, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 27300, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 30781, Make: Volvo, Model: 240, Year: 2015, Fav: NEWISH-Volvo-240
# Id: 30388, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 26796, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 24126, Make: Buick, Model: Enclave, Year: 2017, Fav: NEWISH-Buick-Enclave
# Id: 18514, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 32504, Make: Nissan, Model: Altima, Year: 2012, Fav: OLDISH-Nissan-Altima
# Id: 33634, Make: Honda, Model: Civic, Year: 2013, Fav: OLDISH-Honda-Civic
# Id: 29318, Make: Ford, Model: Expedition, Year: 2016, Fav: NEWISH-Ford-Expedition
# Id: 12022, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 27595, Make: Cadillac, Model: Escalade, Year: 2008, Fav: OLDISH-Cadillac-Escalade
# Id: 18592, Make: Toyota, Model: Sienna, Year: 2016, Fav: NEWISH-Toyota-Sienna
# Id: 21689, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 20174, Make: BMW, Model: 330i, Year: 2018, Fav: NEWISH-BMW-330i
# Id: 20256, Make: Ford, Model: Edge, Year: 2009, Fav: OLDISH-Ford-Edge
# Id: 20185, Make: Volkswagen, Model: Jetta, Year: 2011, Fav: OLDISH-Volkswagen-Jetta
# Id: 16650, Make: Honda, Model: Accord, Year: 2014, Fav: NEWISH-Honda-Accord
# Id: 26280, Make: Toyota, Model: Camry, Year: 2017, Fav: NEWISH-Toyota-Camry
# Id: 30515, Make: Ford, Model: F150, Year: 2014, Fav: NEWISH-Ford-F150
# Id: 26539, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 33149, Make: Dodge, Model: Durango, Year: 2009, Fav: OLDISH-Dodge-Durango
# Id: 28854, Make: GMC, Model: Yukon, Year: 2014, Fav: NEWISH-GMC-Yukon
# Id: 23524, Make: Cadillac, Model: XT5, Year: 2015, Fav: NEWISH-Cadillac-XT5
# Id: 28620, Make: Toyota, Model: Camry, Year: 2013, Fav: OLDISH-Toyota-Camry
# Id: 23634, Make: Volkswagen, Model: Jetta, Year: 2017, Fav: NEWISH-Volkswagen-Jetta
# Id: 28278, Make: Chevrolet, Model: Traverse, Year: 2018, Fav: NEWISH-Chevrolet-Traverse
# Id: 37961, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 16902, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 22801, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 41302, Make: Chevrolet, Model: Silverado, Year: 2010, Fav: OLDISH-Chevrolet-Silverado
# Id: 22167, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 26836, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 20280, Make: Nissan, Model: Altima, Year: 2015, Fav: NEWISH-Nissan-Altima
# Id: 32765, Make: Buick, Model: Enclave, Year: 2010, Fav: OLDISH-Buick-Enclave
# Id: 23768, Make: Ford, Model: Mustang, Year: 2014, Fav: NEWISH-Ford-Mustang
# Id: 17473, Make: Chevrolet, Model: Traverse, Year: 2010, Fav: OLDISH-Chevrolet-Traverse
# Id: 21758, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 25146, Make: Toyota, Model: Prius, Year: 2014, Fav: NEWISH-Toyota-Prius
# Id: 18848, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 10115, Make: GMC, Model: Acadia, Year: 2015, Fav: NEWISH-GMC-Acadia
# Id: 26664, Make: Dodge, Model: Durango, Year: 2014, Fav: NEWISH-Dodge-Durango
# Id: 15726, Make: Buick, Model: Regal, Year: 2012, Fav: OLDISH-Buick-Regal
# Id: 29315, Make: Volvo, Model: V60, Year: 2013, Fav: OLDISH-Volvo-V60
# Id: 29286, Make: Toyota, Model: Corrola, Year: 2010, Fav: OLDISH-Toyota-Corrola
# Id: 23560, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 27047, Make: Toyota, Model: Corrola, Year: 2015, Fav: NEWISH-Toyota-Corrola
# Id: 24026, Make: Chevrolet, Model: Camaro, Year: 2010, Fav: OLDISH-Chevrolet-Camaro
# Id: 30082, Make: Nissan, Model: Leaf, Year: 2012, Fav: OLDISH-Nissan-Leaf
# Id: 21564, Make: Volvo, Model: 240, Year: 2013, Fav: OLDISH-Volvo-240
# Id: 27298, Make: Ford, Model: Fusion, Year: 2017, Fav: NEWISH-Ford-Fusion
# Id: 23067, Make: Toyota, Model: Rav4, Year: 2013, Fav: OLDISH-Toyota-Rav4
# Id: 38505, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 24364, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 16190, Make: Honda, Model: Civic, Year: 2014, Fav: NEWISH-Honda-Civic
# Id: 29112, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 24543, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 28972, Make: Ford, Model: Escape, Year: 2012, Fav: OLDISH-Ford-Escape
# Id: 27785, Make: Dodge, Model: Caravan, Year: 2011, Fav: OLDISH-Dodge-Caravan
# Id: 23029, Make: GMC, Model: Yukon, Year: 2008, Fav: OLDISH-GMC-Yukon
# Id: 29351, Make: Ford, Model: Explorer, Year: 2012, Fav: OLDISH-Ford-Explorer
# Id: 24787, Make: Ford, Model: Escape, Year: 2014, Fav: NEWISH-Ford-Escape
# Id: 28523, Make: Ford, Model: Edge, Year: 2014, Fav: NEWISH-Ford-Edge
# Id: 28429, Make: Chevrolet, Model: Suburban, Year: 2014, Fav: NEWISH-Chevrolet-Suburban
# Id: 19715, Make: Honda, Model: Odyssey, Year: 2010, Fav: OLDISH-Honda-Odyssey
# Id: 23367, Make: Ford, Model: Expedition, Year: 2012, Fav: OLDISH-Ford-Expedition
# Id: 26526, Make: Buick, Model: LaCrosse, Year: 2016, Fav: NEWISH-Buick-LaCrosse
# Id: 25219, Make: Toyota, Model: Prius, Year: 2013, Fav: OLDISH-Toyota-Prius
# Id: 18759, Make: Chevrolet, Model: Camaro, Year: 2014, Fav: NEWISH-Chevrolet-Camaro
# Id: 17132, Make: Cadillac, Model: XT5, Year: 2012, Fav: OLDISH-Cadillac-XT5
# Id: 23268, Make: Chevrolet, Model: Suburban, Year: 2012, Fav: OLDISH-Chevrolet-Suburban
# Id: 19054, Make: Jeep, Model: Cherokee, Year: 2014, Fav: NEWISH-Jeep-Cherokee
# Id: 25913, Make: Chrysler, Model: 300, Year: 2018, Fav: NEWISH-Chrysler-300
# Id: 24809, Make: Dodge, Model: Caravan, Year: 2016, Fav: NEWISH-Dodge-Caravan
# Id: 20265, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 29975, Make: BMW, Model: 430i, Year: 2015, Fav: NEWISH-BMW-430i
# Id: 31823, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 30200, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 24211, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 22385, Make: Chrysler, Model: Pacifica, Year: 2014, Fav: NEWISH-Chrysler-Pacifica
# Id: 25625, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 28721, Make: Cadillac, Model: Escalade, Year: 2015, Fav: NEWISH-Cadillac-Escalade
# Id: 23184, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 26112, Make: Chrysler, Model: Pacifica, Year: 2009, Fav: OLDISH-Chrysler-Pacifica
# Id: 28795, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 28245, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 26612, Make: Hyundai, Model: Santa Fe, Year: 2011, Fav: OLDISH-Hyundai-Santa Fe
# Id: 21480, Make: Jeep, Model: Cherokee, Year: 2011, Fav: OLDISH-Jeep-Cherokee
# Id: 24797, Make: Buick, Model: LaCrosse, Year: 2012, Fav: OLDISH-Buick-LaCrosse
# Id: 19394, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 27157, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 23899, Make: Chevrolet, Model: Tahoe, Year: 2016, Fav: NEWISH-Chevrolet-Tahoe
# Id: 24730, Make: Ford, Model: F150, Year: 2010, Fav: OLDISH-Ford-F150
# Id: 27599, Make: Toyota, Model: Sienna, Year: 2013, Fav: OLDISH-Toyota-Sienna
# Id: 20606, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 19096, Make: Dodge, Model: Ram, Year: 2012, Fav: OLDISH-Dodge-Ram
# Id: 29091, Make: Chevrolet, Model: Silverado, Year: 2018, Fav: NEWISH-Chevrolet-Silverado
# Id: 22564, Make: Chrysler, Model: 200, Year: 2010, Fav: OLDISH-Chrysler-200
# Id: 28581, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 24315, Make: Chrysler, Model: 200, Year: 2015, Fav: NEWISH-Chrysler-200
# **rank 0
#
# Ranking for user that prefers: NEWISH-Jeep-Cherokee
#
# Ranking for user: 17899
# Id: 19054, Make: Jeep, Model: Cherokee, Year: 2014, Fav: NEWISH-Jeep-Cherokee
# Id: 23067, Make: Toyota, Model: Rav4, Year: 2013, Fav: OLDISH-Toyota-Rav4
# Id: 24809, Make: Dodge, Model: Caravan, Year: 2016, Fav: NEWISH-Dodge-Caravan
# Id: 24797, Make: Buick, Model: LaCrosse, Year: 2012, Fav: OLDISH-Buick-LaCrosse
# Id: 32765, Make: Buick, Model: Enclave, Year: 2010, Fav: OLDISH-Buick-Enclave
# Id: 16650, Make: Honda, Model: Accord, Year: 2014, Fav: NEWISH-Honda-Accord
# Id: 28245, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 17473, Make: Chevrolet, Model: Traverse, Year: 2010, Fav: OLDISH-Chevrolet-Traverse
# Id: 24787, Make: Ford, Model: Escape, Year: 2014, Fav: NEWISH-Ford-Escape
# Id: 20280, Make: Nissan, Model: Altima, Year: 2015, Fav: NEWISH-Nissan-Altima
# ...
# Id: 23184, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 28795, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 28429, Make: Chevrolet, Model: Suburban, Year: 2014, Fav: NEWISH-Chevrolet-Suburban
# **rank 34
#
# Ranking for user that prefers: OLDISH-Cadillac-Escalade
#
# Ranking for user: 14563
# Id: 27595, Make: Cadillac, Model: Escalade, Year: 2008, Fav: OLDISH-Cadillac-Escalade
# Id: 21758, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 18210, Make: Jeep, Model: Grand Cherokee, Year: 2014, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 32504, Make: Nissan, Model: Altima, Year: 2012, Fav: OLDISH-Nissan-Altima
# Id: 28245, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 20185, Make: Volkswagen, Model: Jetta, Year: 2011, Fav: OLDISH-Volkswagen-Jetta
# Id: 33634, Make: Honda, Model: Civic, Year: 2013, Fav: OLDISH-Honda-Civic
# Id: 22167, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 25913, Make: Chrysler, Model: 300, Year: 2018, Fav: NEWISH-Chrysler-300
# Id: 30781, Make: Volvo, Model: 240, Year: 2015, Fav: NEWISH-Volvo-240
# Id: 25146, Make: Toyota, Model: Prius, Year: 2014, Fav: NEWISH-Toyota-Prius
# Id: 18514, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 22385, Make: Chrysler, Model: Pacifica, Year: 2014, Fav: NEWISH-Chrysler-Pacifica
# Id: 23029, Make: GMC, Model: Yukon, Year: 2008, Fav: OLDISH-GMC-Yukon
# Id: 26539, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 28854, Make: GMC, Model: Yukon, Year: 2014, Fav: NEWISH-GMC-Yukon
# Id: 28721, Make: Cadillac, Model: Escalade, Year: 2015, Fav: NEWISH-Cadillac-Escalade
# Id: 22801, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 27298, Make: Ford, Model: Fusion, Year: 2017, Fav: NEWISH-Ford-Fusion
# Id: 25625, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 38505, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 23067, Make: Toyota, Model: Rav4, Year: 2013, Fav: OLDISH-Toyota-Rav4
# Id: 27300, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 29315, Make: Volvo, Model: V60, Year: 2013, Fav: OLDISH-Volvo-V60
# Id: 31823, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 16650, Make: Honda, Model: Accord, Year: 2014, Fav: NEWISH-Honda-Accord
# Id: 24797, Make: Buick, Model: LaCrosse, Year: 2012, Fav: OLDISH-Buick-LaCrosse
# Id: 20256, Make: Ford, Model: Edge, Year: 2009, Fav: OLDISH-Ford-Edge
# Id: 21689, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 23184, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 12022, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 26836, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 30388, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 16190, Make: Honda, Model: Civic, Year: 2014, Fav: NEWISH-Honda-Civic
# Id: 18592, Make: Toyota, Model: Sienna, Year: 2016, Fav: NEWISH-Toyota-Sienna
# Id: 27047, Make: Toyota, Model: Corrola, Year: 2015, Fav: NEWISH-Toyota-Corrola
# Id: 24543, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 29318, Make: Ford, Model: Expedition, Year: 2016, Fav: NEWISH-Ford-Expedition
# Id: 37961, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 21564, Make: Volvo, Model: 240, Year: 2013, Fav: OLDISH-Volvo-240
# Id: 28972, Make: Ford, Model: Escape, Year: 2012, Fav: OLDISH-Ford-Escape
# Id: 21480, Make: Jeep, Model: Cherokee, Year: 2011, Fav: OLDISH-Jeep-Cherokee
# Id: 41302, Make: Chevrolet, Model: Silverado, Year: 2010, Fav: OLDISH-Chevrolet-Silverado
# Id: 16902, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 28620, Make: Toyota, Model: Camry, Year: 2013, Fav: OLDISH-Toyota-Camry
# Id: 28278, Make: Chevrolet, Model: Traverse, Year: 2018, Fav: NEWISH-Chevrolet-Traverse
# Id: 10115, Make: GMC, Model: Acadia, Year: 2015, Fav: NEWISH-GMC-Acadia
# Id: 26664, Make: Dodge, Model: Durango, Year: 2014, Fav: NEWISH-Dodge-Durango
# Id: 29286, Make: Toyota, Model: Corrola, Year: 2010, Fav: OLDISH-Toyota-Corrola
# Id: 25219, Make: Toyota, Model: Prius, Year: 2013, Fav: OLDISH-Toyota-Prius
# Id: 24126, Make: Buick, Model: Enclave, Year: 2017, Fav: NEWISH-Buick-Enclave
# Id: 24211, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 23524, Make: Cadillac, Model: XT5, Year: 2015, Fav: NEWISH-Cadillac-XT5
# Id: 27599, Make: Toyota, Model: Sienna, Year: 2013, Fav: OLDISH-Toyota-Sienna
# Id: 33149, Make: Dodge, Model: Durango, Year: 2009, Fav: OLDISH-Dodge-Durango
# Id: 27785, Make: Dodge, Model: Caravan, Year: 2011, Fav: OLDISH-Dodge-Caravan
# Id: 26796, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 19715, Make: Honda, Model: Odyssey, Year: 2010, Fav: OLDISH-Honda-Odyssey
# Id: 27157, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 20174, Make: BMW, Model: 330i, Year: 2018, Fav: NEWISH-BMW-330i
# Id: 29112, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 23634, Make: Volkswagen, Model: Jetta, Year: 2017, Fav: NEWISH-Volkswagen-Jetta
# Id: 19096, Make: Dodge, Model: Ram, Year: 2012, Fav: OLDISH-Dodge-Ram
# Id: 18848, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 26612, Make: Hyundai, Model: Santa Fe, Year: 2011, Fav: OLDISH-Hyundai-Santa Fe
# Id: 29351, Make: Ford, Model: Explorer, Year: 2012, Fav: OLDISH-Ford-Explorer
# Id: 32765, Make: Buick, Model: Enclave, Year: 2010, Fav: OLDISH-Buick-Enclave
# Id: 24026, Make: Chevrolet, Model: Camaro, Year: 2010, Fav: OLDISH-Chevrolet-Camaro
# Id: 30515, Make: Ford, Model: F150, Year: 2014, Fav: NEWISH-Ford-F150
# Id: 26280, Make: Toyota, Model: Camry, Year: 2017, Fav: NEWISH-Toyota-Camry
# Id: 19054, Make: Jeep, Model: Cherokee, Year: 2014, Fav: NEWISH-Jeep-Cherokee
# Id: 17473, Make: Chevrolet, Model: Traverse, Year: 2010, Fav: OLDISH-Chevrolet-Traverse
# Id: 20265, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 30200, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 24364, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 28523, Make: Ford, Model: Edge, Year: 2014, Fav: NEWISH-Ford-Edge
# Id: 26112, Make: Chrysler, Model: Pacifica, Year: 2009, Fav: OLDISH-Chrysler-Pacifica
# Id: 20280, Make: Nissan, Model: Altima, Year: 2015, Fav: NEWISH-Nissan-Altima
# Id: 24730, Make: Ford, Model: F150, Year: 2010, Fav: OLDISH-Ford-F150
# Id: 26526, Make: Buick, Model: LaCrosse, Year: 2016, Fav: NEWISH-Buick-LaCrosse
# Id: 29975, Make: BMW, Model: 430i, Year: 2015, Fav: NEWISH-BMW-430i
# Id: 28429, Make: Chevrolet, Model: Suburban, Year: 2014, Fav: NEWISH-Chevrolet-Suburban
# Id: 17132, Make: Cadillac, Model: XT5, Year: 2012, Fav: OLDISH-Cadillac-XT5
# Id: 24787, Make: Ford, Model: Escape, Year: 2014, Fav: NEWISH-Ford-Escape
# Id: 23899, Make: Chevrolet, Model: Tahoe, Year: 2016, Fav: NEWISH-Chevrolet-Tahoe
# Id: 23367, Make: Ford, Model: Expedition, Year: 2012, Fav: OLDISH-Ford-Expedition
# Id: 19394, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 28581, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 30082, Make: Nissan, Model: Leaf, Year: 2012, Fav: OLDISH-Nissan-Leaf
# Id: 24809, Make: Dodge, Model: Caravan, Year: 2016, Fav: NEWISH-Dodge-Caravan
# Id: 15726, Make: Buick, Model: Regal, Year: 2012, Fav: OLDISH-Buick-Regal
# Id: 23768, Make: Ford, Model: Mustang, Year: 2014, Fav: NEWISH-Ford-Mustang
# Id: 23560, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 20606, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 22564, Make: Chrysler, Model: 200, Year: 2010, Fav: OLDISH-Chrysler-200
# Id: 24315, Make: Chrysler, Model: 200, Year: 2015, Fav: NEWISH-Chrysler-200
# Id: 18759, Make: Chevrolet, Model: Camaro, Year: 2014, Fav: NEWISH-Chevrolet-Camaro
# Id: 28795, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 23268, Make: Chevrolet, Model: Suburban, Year: 2012, Fav: OLDISH-Chevrolet-Suburban
# Id: 29091, Make: Chevrolet, Model: Silverado, Year: 2018, Fav: NEWISH-Chevrolet-Silverado
# **rank 0
#
# Ranking for user that prefers: NEWISH-Volvo-V60
#
# Ranking for user: 25469
# Id: 22167, Make: Volvo, Model: V60, Year: 2014, Fav: NEWISH-Volvo-V60
# Id: 21758, Make: Nissan, Model: Leaf, Year: 2015, Fav: NEWISH-Nissan-Leaf
# Id: 28854, Make: GMC, Model: Yukon, Year: 2014, Fav: NEWISH-GMC-Yukon
# Id: 28972, Make: Ford, Model: Escape, Year: 2012, Fav: OLDISH-Ford-Escape
# Id: 16190, Make: Honda, Model: Civic, Year: 2014, Fav: NEWISH-Honda-Civic
# Id: 31823, Make: Hyundai, Model: Elantra, Year: 2014, Fav: NEWISH-Hyundai-Elantra
# Id: 28245, Make: Volkswagen, Model: Tiguan, Year: 2013, Fav: OLDISH-Volkswagen-Tiguan
# Id: 29315, Make: Volvo, Model: V60, Year: 2013, Fav: OLDISH-Volvo-V60
# Id: 22385, Make: Chrysler, Model: Pacifica, Year: 2014, Fav: NEWISH-Chrysler-Pacifica
# Id: 38505, Make: Volkswagen, Model: Golf, Year: 2014, Fav: NEWISH-Volkswagen-Golf
# Id: 17132, Make: Cadillac, Model: XT5, Year: 2012, Fav: OLDISH-Cadillac-XT5
# Id: 27599, Make: Toyota, Model: Sienna, Year: 2013, Fav: OLDISH-Toyota-Sienna
# Id: 24730, Make: Ford, Model: F150, Year: 2010, Fav: OLDISH-Ford-F150
# Id: 28721, Make: Cadillac, Model: Escalade, Year: 2015, Fav: NEWISH-Cadillac-Escalade
# Id: 25219, Make: Toyota, Model: Prius, Year: 2013, Fav: OLDISH-Toyota-Prius
# Id: 29112, Make: Honda, Model: Odyssey, Year: 2015, Fav: NEWISH-Honda-Odyssey
# Id: 18514, Make: Toyota, Model: Rav4, Year: 2014, Fav: NEWISH-Toyota-Rav4
# Id: 24809, Make: Dodge, Model: Caravan, Year: 2016, Fav: NEWISH-Dodge-Caravan
# Id: 29286, Make: Toyota, Model: Corrola, Year: 2010, Fav: OLDISH-Toyota-Corrola
# Id: 23029, Make: GMC, Model: Yukon, Year: 2008, Fav: OLDISH-GMC-Yukon
# Id: 24797, Make: Buick, Model: LaCrosse, Year: 2012, Fav: OLDISH-Buick-LaCrosse
# Id: 19054, Make: Jeep, Model: Cherokee, Year: 2014, Fav: NEWISH-Jeep-Cherokee
# Id: 16650, Make: Honda, Model: Accord, Year: 2014, Fav: NEWISH-Honda-Accord
# Id: 27595, Make: Cadillac, Model: Escalade, Year: 2008, Fav: OLDISH-Cadillac-Escalade
# Id: 21480, Make: Jeep, Model: Cherokee, Year: 2011, Fav: OLDISH-Jeep-Cherokee
# Id: 33634, Make: Honda, Model: Civic, Year: 2013, Fav: OLDISH-Honda-Civic
# Id: 32504, Make: Nissan, Model: Altima, Year: 2012, Fav: OLDISH-Nissan-Altima
# Id: 29091, Make: Chevrolet, Model: Silverado, Year: 2018, Fav: NEWISH-Chevrolet-Silverado
# Id: 23067, Make: Toyota, Model: Rav4, Year: 2013, Fav: OLDISH-Toyota-Rav4
# Id: 25146, Make: Toyota, Model: Prius, Year: 2014, Fav: NEWISH-Toyota-Prius
# Id: 24026, Make: Chevrolet, Model: Camaro, Year: 2010, Fav: OLDISH-Chevrolet-Camaro
# Id: 24364, Make: Hyundai, Model: Santa Fe, Year: 2015, Fav: NEWISH-Hyundai-Santa Fe
# Id: 24315, Make: Chrysler, Model: 200, Year: 2015, Fav: NEWISH-Chrysler-200
# Id: 29351, Make: Ford, Model: Explorer, Year: 2012, Fav: OLDISH-Ford-Explorer
# Id: 18210, Make: Jeep, Model: Grand Cherokee, Year: 2014, Fav: NEWISH-Jeep-Grand Cherokee
# Id: 20174, Make: BMW, Model: 330i, Year: 2018, Fav: NEWISH-BMW-330i
# Id: 41302, Make: Chevrolet, Model: Silverado, Year: 2010, Fav: OLDISH-Chevrolet-Silverado
# Id: 23184, Make: Hyundai, Model: Elantra, Year: 2013, Fav: OLDISH-Hyundai-Elantra
# Id: 27157, Make: GMC, Model: Acadia, Year: 2013, Fav: OLDISH-GMC-Acadia
# Id: 12022, Make: Volkswagen, Model: Tiguan, Year: 2016, Fav: NEWISH-Volkswagen-Tiguan
# Id: 26280, Make: Toyota, Model: Camry, Year: 2017, Fav: NEWISH-Toyota-Camry
# Id: 28581, Make: Chevrolet, Model: Tahoe, Year: 2013, Fav: OLDISH-Chevrolet-Tahoe
# Id: 25913, Make: Chrysler, Model: 300, Year: 2018, Fav: NEWISH-Chrysler-300
# Id: 10115, Make: GMC, Model: Acadia, Year: 2015, Fav: NEWISH-GMC-Acadia
# Id: 26664, Make: Dodge, Model: Durango, Year: 2014, Fav: NEWISH-Dodge-Durango
# Id: 20185, Make: Volkswagen, Model: Jetta, Year: 2011, Fav: OLDISH-Volkswagen-Jetta
# Id: 29318, Make: Ford, Model: Expedition, Year: 2016, Fav: NEWISH-Ford-Expedition
# Id: 37961, Make: Nissan, Model: Rogue, Year: 2014, Fav: NEWISH-Nissan-Rogue
# Id: 19096, Make: Dodge, Model: Ram, Year: 2012, Fav: OLDISH-Dodge-Ram
# Id: 18759, Make: Chevrolet, Model: Camaro, Year: 2014, Fav: NEWISH-Chevrolet-Camaro
# Id: 26112, Make: Chrysler, Model: Pacifica, Year: 2009, Fav: OLDISH-Chrysler-Pacifica
# Id: 19715, Make: Honda, Model: Odyssey, Year: 2010, Fav: OLDISH-Honda-Odyssey
# Id: 22801, Make: Jeep, Model: Grand Cherokee, Year: 2013, Fav: OLDISH-Jeep-Grand Cherokee
# Id: 16902, Make: Kia, Model: Sedona, Year: 2014, Fav: NEWISH-Kia-Sedona
# Id: 28620, Make: Toyota, Model: Camry, Year: 2013, Fav: OLDISH-Toyota-Camry
# Id: 20280, Make: Nissan, Model: Altima, Year: 2015, Fav: NEWISH-Nissan-Altima
# Id: 28523, Make: Ford, Model: Edge, Year: 2014, Fav: NEWISH-Ford-Edge
# Id: 27785, Make: Dodge, Model: Caravan, Year: 2011, Fav: OLDISH-Dodge-Caravan
# Id: 30200, Make: Buick, Model: Regal, Year: 2014, Fav: NEWISH-Buick-Regal
# Id: 20256, Make: Ford, Model: Edge, Year: 2009, Fav: OLDISH-Ford-Edge
# Id: 23367, Make: Ford, Model: Expedition, Year: 2012, Fav: OLDISH-Ford-Expedition
# Id: 32765, Make: Buick, Model: Enclave, Year: 2010, Fav: OLDISH-Buick-Enclave
# Id: 33149, Make: Dodge, Model: Durango, Year: 2009, Fav: OLDISH-Dodge-Durango
# Id: 28429, Make: Chevrolet, Model: Suburban, Year: 2014, Fav: NEWISH-Chevrolet-Suburban
# Id: 22564, Make: Chrysler, Model: 200, Year: 2010, Fav: OLDISH-Chrysler-200
# Id: 27300, Make: Kia, Model: Sedona, Year: 2013, Fav: OLDISH-Kia-Sedona
# Id: 17473, Make: Chevrolet, Model: Traverse, Year: 2010, Fav: OLDISH-Chevrolet-Traverse
# Id: 20265, Make: Ford, Model: Fusion, Year: 2013, Fav: OLDISH-Ford-Fusion
# Id: 30388, Make: Dodge, Model: Ram, Year: 2016, Fav: NEWISH-Dodge-Ram
# Id: 24126, Make: Buick, Model: Enclave, Year: 2017, Fav: NEWISH-Buick-Enclave
# Id: 23634, Make: Volkswagen, Model: Jetta, Year: 2017, Fav: NEWISH-Volkswagen-Jetta
# Id: 21564, Make: Volvo, Model: 240, Year: 2013, Fav: OLDISH-Volvo-240
# Id: 27047, Make: Toyota, Model: Corrola, Year: 2015, Fav: NEWISH-Toyota-Corrola
# Id: 26612, Make: Hyundai, Model: Santa Fe, Year: 2011, Fav: OLDISH-Hyundai-Santa Fe
# Id: 27298, Make: Ford, Model: Fusion, Year: 2017, Fav: NEWISH-Ford-Fusion
# Id: 20606, Make: Subaru, Model: Outback, Year: 2015, Fav: NEWISH-Subaru-Outback
# Id: 23524, Make: Cadillac, Model: XT5, Year: 2015, Fav: NEWISH-Cadillac-XT5
# Id: 24787, Make: Ford, Model: Escape, Year: 2014, Fav: NEWISH-Ford-Escape
# Id: 24543, Make: Honda, Model: Pilot, Year: 2013, Fav: OLDISH-Honda-Pilot
# Id: 26539, Make: Subaru, Model: Outback, Year: 2013, Fav: OLDISH-Subaru-Outback
# Id: 28795, Make: Ford, Model: Mustang, Year: 2011, Fav: OLDISH-Ford-Mustang
# Id: 25625, Make: Honda, Model: Pilot, Year: 2016, Fav: NEWISH-Honda-Pilot
# Id: 26796, Make: BMW, Model: 330i, Year: 2011, Fav: OLDISH-BMW-330i
# Id: 26526, Make: Buick, Model: LaCrosse, Year: 2016, Fav: NEWISH-Buick-LaCrosse
# Id: 18592, Make: Toyota, Model: Sienna, Year: 2016, Fav: NEWISH-Toyota-Sienna
# Id: 21689, Make: Honda, Model: Accord, Year: 2012, Fav: OLDISH-Honda-Accord
# Id: 19394, Make: Chrysler, Model: 300, Year: 2012, Fav: OLDISH-Chrysler-300
# Id: 23268, Make: Chevrolet, Model: Suburban, Year: 2012, Fav: OLDISH-Chevrolet-Suburban
# Id: 30082, Make: Nissan, Model: Leaf, Year: 2012, Fav: OLDISH-Nissan-Leaf
# Id: 23560, Make: Ford, Model: Explorer, Year: 2014, Fav: NEWISH-Ford-Explorer
# Id: 15726, Make: Buick, Model: Regal, Year: 2012, Fav: OLDISH-Buick-Regal
# Id: 26836, Make: Volkswagen, Model: Golf, Year: 2013, Fav: OLDISH-Volkswagen-Golf
# Id: 30781, Make: Volvo, Model: 240, Year: 2015, Fav: NEWISH-Volvo-240
# Id: 23899, Make: Chevrolet, Model: Tahoe, Year: 2016, Fav: NEWISH-Chevrolet-Tahoe
# Id: 24211, Make: Nissan, Model: Rogue, Year: 2013, Fav: OLDISH-Nissan-Rogue
# Id: 18848, Make: BMW, Model: 430i, Year: 2013, Fav: OLDISH-BMW-430i
# Id: 23768, Make: Ford, Model: Mustang, Year: 2014, Fav: NEWISH-Ford-Mustang
# Id: 28278, Make: Chevrolet, Model: Traverse, Year: 2018, Fav: NEWISH-Chevrolet-Traverse
# Id: 30515, Make: Ford, Model: F150, Year: 2014, Fav: NEWISH-Ford-F150
# Id: 29975, Make: BMW, Model: 430i, Year: 2015, Fav: NEWISH-BMW-430i
# **rank 0
#
# Rank average: 1.51

# %% [markdown]
# ## Exercise the hrnn campaign
# Here we try out the hrnn campaign. We ask Personalize for recommendations for a particular user. Our hope is that
# it would detect that this user likes old or new cars and would return a list accordingly.
# Best case is that the recommended list of cars entirely matches the user's preferred car
# cluster.

# %%
users_to_try = int_expanded_df.sample(5)
users_to_try[['USER_ID','FAV']].head(3)
# Out:
#         USER_ID                  FAV
# 528574     3070  OLDISH-Chrysler-200
# 245072    11097     OLDISH-Dodge-Ram
# 677878     7897      OLDISH-BMW-430i

# %%
show_user_interaction_history(int_expanded_df, users_to_try.iloc[0]['USER_ID'])
# Out:
# (20, 18)
#         USER_ID  ITEM_ID                 WHEN                  FAV  YEAR  \
# 528574     3070    22038  2019-07-10 14:00:55  OLDISH-Chrysler-200  2012
# 528573     3070    18703  2019-07-10 14:02:55  OLDISH-Chrysler-200  2011
# 528564     3070    18983  2019-07-10 14:06:55  OLDISH-Chrysler-200  2012
# 528567     3070    24068  2019-07-10 14:12:55  OLDISH-Chrysler-200  2010
# 528560     3070    31364  2019-07-10 14:20:55  OLDISH-Chrysler-200  2011
# 528570     3070    25834  2019-07-10 14:30:55  OLDISH-Chrysler-200  2012
# 528579     3070    11546  2019-07-10 14:42:55  OLDISH-Chrysler-200  2011
# 528576     3070    20779  2019-07-10 14:56:55  OLDISH-Chrysler-200  2012
# 528563     3070    25795  2019-07-10 15:12:55  OLDISH-Chrysler-200  2012
# 528562     3070    28626  2019-07-10 15:30:55  OLDISH-Chrysler-200  2011
# 528572     3070    25319  2019-07-14 10:23:25  OLDISH-Chrysler-200  2013
# 528569     3070    34080  2019-07-14 10:25:25  OLDISH-Chrysler-200  2013
# 528561     3070    16540  2019-07-14 10:29:25  OLDISH-Chrysler-200  2013
# 528575     3070    22038  2019-07-14 10:35:25  OLDISH-Chrysler-200  2012
# 528565     3070    31680  2019-07-14 10:43:25  OLDISH-Chrysler-200  2013
# 528566     3070    26426  2019-07-14 10:53:25  OLDISH-Chrysler-200  2013
# 528578     3070    13628  2019-07-14 11:05:25  OLDISH-Chrysler-200  2013
# 528577     3070    16908  2019-07-14 11:19:25  OLDISH-Chrysler-200  2012
# 528571     3070    23540  2019-07-14 11:35:25  OLDISH-Chrysler-200  2013
# 528568     3070    27255  2019-07-14 11:53:25  OLDISH-Chrysler-200  2012
#
#         PRICE  MILEAGE
# 528574  27869   110288
# 528573  17192   127144
# 528564  23548   110023
# 528567  17556   135164
# 528560  21037   122204
# 528570  22256   105244
# 528579  21494   120052
# 528576  25275   105894
# 528563  23489   109328
# 528562  19351   126405
# 528572  30604    92750
# 528569  28886    92286
# 528561  28089    92599
# 528575  27869   110288
# 528565  22941    99975
# 528566  25935    92931
# 528578  26987    96537
# 528577  23352   107925
# 528571  23978    95858
# 528568  26963   108482

# %%
if is_campaign_active(hrnn_arn):
    for i in range(5):
        user_id     = str(users_to_try.iloc[i]['USER_ID'])
        fav         = users_to_try.iloc[i]['FAV']
        fav_cluster = users_to_try.iloc[i]['FAV_CLUSTER']

        print('Getting recommendations for user: {}, who likes: {}'.format(user_id, fav))
        response = personalize_runtime.get_recommendations(campaignArn=hrnn_arn, 
                                                           userId=user_id, 
                                                           numResults=10)
        items = response['itemList']

        match = 0
        actual_num_results = len(items)

        for item in items:
            _curr_item_id  = int(item['itemId'])
            _curr_cluster  = int_expanded_df[int_expanded_df.ITEM_ID == _curr_item_id].iloc[0]['FAV_CLUSTER']
            if fav_cluster == _curr_cluster:
                match += 1
            print_item(_curr_item_id)
        print('Matched {:.0f}% ({}/{})'.format(100 * match/actual_num_results, match, actual_num_results))
        print('')
else:
    print('HRNN campaign not active: {}'.format(hrnn_arn))
# Out:
# Getting recommendations for user: 3070, who likes: OLDISH-Chrysler-200
# Id: 29140, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2012
# Id: 25002, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2013
# Id: 21045, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2012
# Id: 23948, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2010
# Id: 22926, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2012
# Id: 22616, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2013
# Id: 29709, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2010
# Id: 23457, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2010
# Id: 28747, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2011
# Id: 24914, Make: Chrysler, Model: 200, Fav: OLDISH-Chrysler-200, Year: 2012
# Matched 100% (10/10)
#
# Getting recommendations for user: 11097, who likes: OLDISH-Dodge-Ram
# Id: 28216, Make: Dodge, Model: Ram, Fav: OLDISH-Dodge-Ram, Year: 2012
# Id: 28318, Make: Dodge, Model: Ram, Fav: OLDISH-Dodge-Ram, Year: 2013
# Id: 23802, Make: Dodge, Model: Ram, Fav: OLDISH-Dodge-Ram, Year: 2012
# Id: 22592, Make: Dodge, Model: Ram, Fav: OLDISH-Dodge-Ram, Year: 2013
# Id: 28426, Make: Dodge, Model: Ram, Fav: OLDISH-Dodge-Ram, Year: 2010
# Id: 26334, Make: Dodge, Model: Ram, Fav: OLDISH-Dodge-Ram, Year: 2013
# Id: 25149, Make: Dodge, Model: Ram, Fav: OLDISH-Dodge-Ram, Year: 2013
# Id: 25521, Make: Dodge, Model: Ram, Fav: OLDISH-Dodge-Ram, Year: 2010
# Id: 22447, Make: Dodge, Model: Ram, Fav: OLDISH-Dodge-Ram, Year: 2012
# Id: 23101, Make: Dodge, Model: Ram, Fav: OLDISH-Dodge-Ram, Year: 2012
# Matched 100% (10/10)
#
# Getting recommendations for user: 7897, who likes: OLDISH-BMW-430i
# Id: 23337, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 24163, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2010
# Id: 26642, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2013
# Id: 23741, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 26136, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2011
# Id: 27457, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2013
# Id: 22910, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2013
# Id: 23611, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2013
# Id: 26950, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2012
# Id: 20011, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2011
# Matched 100% (10/10)
#
# Getting recommendations for user: 9039, who likes: NEWISH-GMC-Acadia
# Id: 27984, Make: GMC, Model: Acadia, Fav: NEWISH-GMC-Acadia, Year: 2014
# Id: 25675, Make: GMC, Model: Acadia, Fav: NEWISH-GMC-Acadia, Year: 2014
# Id: 24109, Make: GMC, Model: Acadia, Fav: NEWISH-GMC-Acadia, Year: 2019
# Id: 26555, Make: GMC, Model: Acadia, Fav: NEWISH-GMC-Acadia, Year: 2015
# Id: 28571, Make: GMC, Model: Acadia, Fav: NEWISH-GMC-Acadia, Year: 2016
# Id: 26087, Make: GMC, Model: Acadia, Fav: NEWISH-GMC-Acadia, Year: 2017
# Id: 25307, Make: GMC, Model: Acadia, Fav: NEWISH-GMC-Acadia, Year: 2015
# Id: 28505, Make: GMC, Model: Acadia, Fav: NEWISH-GMC-Acadia, Year: 2017
# Id: 24248, Make: GMC, Model: Acadia, Fav: NEWISH-GMC-Acadia, Year: 2014
# Id: 21516, Make: GMC, Model: Acadia, Fav: NEWISH-GMC-Acadia, Year: 2015
# Matched 100% (10/10)
#
# Getting recommendations for user: 19292, who likes: NEWISH-Chevrolet-Silverado
# Id: 24798, Make: Chevrolet, Model: Silverado, Fav: NEWISH-Chevrolet-Silverado, Year: 2017
# Id: 20731, Make: Chevrolet, Model: Silverado, Fav: NEWISH-Chevrolet-Silverado, Year: 2017
# Id: 28215, Make: Chevrolet, Model: Silverado, Fav: NEWISH-Chevrolet-Silverado, Year: 2017
# Id: 22469, Make: Chevrolet, Model: Silverado, Fav: NEWISH-Chevrolet-Silverado, Year: 2014
# Id: 19736, Make: Chevrolet, Model: Silverado, Fav: NEWISH-Chevrolet-Silverado, Year: 2014
# Id: 23289, Make: Chevrolet, Model: Silverado, Fav: NEWISH-Chevrolet-Silverado, Year: 2015
# Id: 26506, Make: Chevrolet, Model: Silverado, Fav: NEWISH-Chevrolet-Silverado, Year: 2017
# Id: 28063, Make: Chevrolet, Model: Silverado, Fav: NEWISH-Chevrolet-Silverado, Year: 2016
# Id: 27738, Make: Chevrolet, Model: Silverado, Fav: NEWISH-Chevrolet-Silverado, Year: 2015
# Id: 20923, Make: Chevrolet, Model: Silverado, Fav: NEWISH-Chevrolet-Silverado, Year: 2015
# Matched 100% (10/10)

# %% [markdown]
# ## Exercise the SIMS campaign
# Here we experiment with the SIMS campaign. We loop through a list of items that have at
# least some interactions historically.
# For each car, we would expect similar cars to be similar in age, make and model.
# We leverage car clusters and would like to see Personalize generate a list of similar cars
# that entirely come from the same car cluster.

# %%
items_to_try = int_expanded_df.sample(5)
items_to_try[['ITEM_ID','FAV']].head(5)
# Out:
#         ITEM_ID                        FAV
# 680854    24547          OLDISH-GMC-Acadia
# 694075    29030    NEWISH-Hyundai-Santa Fe
# 217670    24930           OLDISH-Ford-F150
# 135555    22067  NEWISH-Chevrolet-Suburban
# 634994    28493           NEWISH-Ford-Edge

# %%
if is_campaign_active(sims_arn):
    desired_num_results = 10
    for i in range(items_to_try.shape[0]):
        item_id     = str(items_to_try.iloc[i]['ITEM_ID'])
        fav         = items_to_try.iloc[i]['FAV']
        fav_cluster = items_to_try.iloc[i]['FAV_CLUSTER']

        print('Getting items similar to: {}, which is a: {}'.format(item_id, fav))
        response = personalize_runtime.get_recommendations(campaignArn=sims_arn, 
                                                           itemId=item_id, 
                                                           numResults=desired_num_results)
        items = response['itemList']
        
        match = 0
        actual_num_results = len(items)
        
        for item in items:
            _curr_item_id  = int(item['itemId'])
            _curr_cluster  = int_expanded_df[int_expanded_df.ITEM_ID == _curr_item_id].iloc[0]['FAV_CLUSTER']
            if fav_cluster == _curr_cluster:
                match += 1
            print_item(_curr_item_id)
        print('Matched {:.0f}% ({}/{})'.format(100 * match/actual_num_results, match, actual_num_results))
        print('')
else:
    print('SIMS campaign not active: {}'.format(sims_arn))
# Out:
# Getting items similar to: 24547, which is a: OLDISH-GMC-Acadia
# Id: 28608, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2013
# Id: 24170, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2013
# Id: 26221, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2013
# Id: 26130, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Id: 26257, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Id: 24438, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Id: 19456, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2013
# Id: 24218, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2010
# Id: 24672, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2013
# Id: 29514, Make: GMC, Model: Acadia, Fav: OLDISH-GMC-Acadia, Year: 2012
# Matched 100% (10/10)
#
# Getting items similar to: 29030, which is a: NEWISH-Hyundai-Santa Fe
# Id: 24364, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 23005, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2016
# Id: 24588, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2014
# Id: 21661, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 23281, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2017
# Id: 29305, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2014
# Id: 23810, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2014
# Id: 22976, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 28407, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2015
# Id: 25619, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2016
# Matched 100% (10/10)
#
# Getting items similar to: 24930, which is a: OLDISH-Ford-F150
# Id: 23377, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2013
# Id: 26107, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2012
# Id: 27108, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2011
# Id: 32499, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2012
# Id: 21569, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2012
# Id: 25664, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2013
# Id: 25088, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2012
# Id: 25898, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2013
# Id: 29666, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2011
# Id: 32400, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2011
# Matched 100% (10/10)
#
# Getting items similar to: 22067, which is a: NEWISH-Chevrolet-Suburban
# Id: 20989, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 20587, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 19710, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2016
# Id: 27415, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2016
# Id: 24952, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2017
# Id: 30321, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2016
# Id: 15215, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2015
# Id: 25955, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2014
# Id: 21338, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2014
# Id: 21307, Make: Chevrolet, Model: Suburban, Fav: NEWISH-Chevrolet-Suburban, Year: 2014
# Matched 100% (10/10)
#
# Getting items similar to: 28493, which is a: NEWISH-Ford-Edge
# Id: 20473, Make: Ford, Model: Edge, Fav: NEWISH-Ford-Edge, Year: 2014
# Id: 23665, Make: Ford, Model: Edge, Fav: NEWISH-Ford-Edge, Year: 2016
# Id: 26722, Make: Ford, Model: Edge, Fav: NEWISH-Ford-Edge, Year: 2014
# Id: 29586, Make: Ford, Model: Edge, Fav: NEWISH-Ford-Edge, Year: 2018
# Id: 25432, Make: Ford, Model: Edge, Fav: NEWISH-Ford-Edge, Year: 2016
# Id: 26033, Make: Ford, Model: Edge, Fav: NEWISH-Ford-Edge, Year: 2017
# Id: 21729, Make: Ford, Model: Edge, Fav: NEWISH-Ford-Edge, Year: 2014
# Id: 30089, Make: Ford, Model: Edge, Fav: NEWISH-Ford-Edge, Year: 2015
# Id: 31864, Make: Ford, Model: Edge, Fav: NEWISH-Ford-Edge, Year: 2014
# Id: 18453, Make: Ford, Model: Edge, Fav: NEWISH-Ford-Edge, Year: 2014
# Matched 100% (10/10)

# %% [markdown]
# ## Exercise the hrnn-metadata campaign
# Here we try out the hrnn-metadata campaign.
# We ask Personalize for recommendations for a particular user. Our hope is that
# it would detect that this user likes old or new cars and would return a list accordingly.

# %%
users_to_try = int_expanded_df.sample(10)
users_to_try[['USER_ID','FAV']].head(3)
# Out:
#         USER_ID                     FAV
# 241113    21855        OLDISH-Ford-F150
# 460002     9391    OLDISH-Ford-Explorer
# 66668     22270  NEWISH-Chevrolet-Tahoe

# %%
show_user_interaction_history(int_expanded_df, users_to_try.iloc[0]['USER_ID'])
# Out:
# (10, 18)
#         USER_ID  ITEM_ID                 WHEN               FAV  YEAR  PRICE  \
# 241118    21855    19123  2019-07-15 05:12:25  OLDISH-Ford-F150  2013  25437
# 241111    21855    33360  2019-07-15 05:14:25  OLDISH-Ford-F150  2012  23486
# 241114    21855    30046  2019-07-15 05:18:25  OLDISH-Ford-F150  2012  26776
# 241119    21855    26156  2019-07-15 05:24:25  OLDISH-Ford-F150  2011  19504
# 241116    21855    25088  2019-07-15 05:32:25  OLDISH-Ford-F150  2012  26156
# 241110    21855    27339  2019-07-15 05:42:25  OLDISH-Ford-F150  2013  24430
# 241115    21855    17932  2019-07-15 05:54:25  OLDISH-Ford-F150  2012  23657
# 241112    21855    31424  2019-07-15 06:08:25  OLDISH-Ford-F150  2008  16511
# 241113    21855    27125  2019-07-15 06:24:25  OLDISH-Ford-F150  2013  26761
# 241117    21855    21221  2019-07-15 06:42:25  OLDISH-Ford-F150  2013  25735
#
#         MILEAGE
# 241118    94331
# 241111   107885
# 241114   108834
# 241119   128913
# 241116   110343
# 241110    90904
# 241115   109671
# 241112   166766
# 241113    95914
# 241117    98633

# %%
if is_campaign_active(hrnn_metadata_arn):
    for i in range(10):
        user_id     = str(users_to_try.iloc[i]['USER_ID'])
        fav         = users_to_try.iloc[i]['FAV']
        fav_cluster = users_to_try.iloc[i]['FAV_CLUSTER']

        print('Getting recommendations for user: {}, who likes: {}'.format(user_id, fav))
        response = personalize_runtime.get_recommendations(campaignArn=hrnn_metadata_arn, 
                                                           userId=user_id, 
                                                           numResults=10)
        match = 0
        actual_num_results = len(items)

        items = response['itemList']
        for item in items:
            _curr_item_id  = int(item['itemId'])
            _curr_cluster  = int_expanded_df[int_expanded_df.ITEM_ID == _curr_item_id].iloc[0]['FAV_CLUSTER']
            if fav_cluster == _curr_cluster:
                match += 1
            print_item(_curr_item_id)
        print('Matched {:.0f}% ({}/{})'.format(100 * match/actual_num_results, match, actual_num_results))
        print('')
else:
    print('HRNN-metadata campaign not active: {}'.format(hrnn_metadata_arn))
# Out:
# Getting recommendations for user: 21855, who likes: OLDISH-Ford-F150
# Id: 25327, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2011
# Id: 25282, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2013
# Id: 22281, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2011
# Id: 26107, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2012
# Id: 16589, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2011
# Id: 21916, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2011
# Id: 33809, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2011
# Id: 30250, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2013
# Id: 23627, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2011
# Id: 23341, Make: Ford, Model: F150, Fav: OLDISH-Ford-F150, Year: 2013
# Matched 100% (10/10)
#
# Getting recommendations for user: 9391, who likes: OLDISH-Ford-Explorer
# Id: 25024, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 24582, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 27528, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 26535, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 26359, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 24716, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2012
# Id: 25671, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 26185, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 28688, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 23336, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2012
# Matched 100% (10/10)
#
# Getting recommendations for user: 22270, who likes: NEWISH-Chevrolet-Tahoe
# Id: 25614, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 21576, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 27421, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 26496, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 24138, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Id: 20529, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 23426, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 28759, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 29413, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 21487, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Matched 100% (10/10)
#
# Getting recommendations for user: 5316, who likes: OLDISH-Chevrolet-Silverado
# Id: 25173, Make: Chevrolet, Model: Silverado, Fav: OLDISH-Chevrolet-Silverado, Year: 2011
# Id: 16492, Make: Chevrolet, Model: Silverado, Fav: OLDISH-Chevrolet-Silverado, Year: 2012
# Id: 32422, Make: Chevrolet, Model: Silverado, Fav: OLDISH-Chevrolet-Silverado, Year: 2011
# Id: 25138, Make: Chevrolet, Model: Silverado, Fav: OLDISH-Chevrolet-Silverado, Year: 2011
# Id: 20752, Make: Chevrolet, Model: Silverado, Fav: OLDISH-Chevrolet-Silverado, Year: 2011
# Id: 24670, Make: Chevrolet, Model: Silverado, Fav: OLDISH-Chevrolet-Silverado, Year: 2011
# Id: 23037, Make: Chevrolet, Model: Silverado, Fav: OLDISH-Chevrolet-Silverado, Year: 2011
# Id: 24908, Make: Chevrolet, Model: Silverado, Fav: OLDISH-Chevrolet-Silverado, Year: 2011
# Id: 22081, Make: Chevrolet, Model: Silverado, Fav: OLDISH-Chevrolet-Silverado, Year: 2011
# Id: 23617, Make: Chevrolet, Model: Silverado, Fav: OLDISH-Chevrolet-Silverado, Year: 2012
# Matched 100% (10/10)
#
# Getting recommendations for user: 18125, who likes: NEWISH-Buick-Regal
# Id: 24566, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 26925, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 19828, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 20047, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 25076, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 26997, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 21317, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 25183, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 20526, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2015
# Id: 27402, Make: Buick, Model: Regal, Fav: NEWISH-Buick-Regal, Year: 2014
# Matched 100% (10/10)
#
# Getting recommendations for user: 12149, who likes: NEWISH-Volkswagen-Golf
# Id: 26849, Make: Volkswagen, Model: Golf, Fav: NEWISH-Volkswagen-Golf, Year: 2015
# Id: 29733, Make: Volkswagen, Model: Golf, Fav: NEWISH-Volkswagen-Golf, Year: 2015
# Id: 23065, Make: Volkswagen, Model: Golf, Fav: NEWISH-Volkswagen-Golf, Year: 2015
# Id: 25559, Make: Volkswagen, Model: Golf, Fav: NEWISH-Volkswagen-Golf, Year: 2014
# Id: 24075, Make: Volkswagen, Model: Golf, Fav: NEWISH-Volkswagen-Golf, Year: 2015
# Id: 25679, Make: Volkswagen, Model: Golf, Fav: NEWISH-Volkswagen-Golf, Year: 2014
# Id: 26547, Make: Volkswagen, Model: Golf, Fav: NEWISH-Volkswagen-Golf, Year: 2014
# Id: 27605, Make: Volkswagen, Model: Golf, Fav: NEWISH-Volkswagen-Golf, Year: 2014
# Id: 27969, Make: Volkswagen, Model: Golf, Fav: NEWISH-Volkswagen-Golf, Year: 2014
# Id: 24361, Make: Volkswagen, Model: Golf, Fav: NEWISH-Volkswagen-Golf, Year: 2014
# Matched 100% (10/10)
#
# Getting recommendations for user: 15519, who likes: OLDISH-Ford-Explorer
# Id: 25024, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 24582, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 27528, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 26535, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 26359, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 24716, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2012
# Id: 25671, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 26185, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Id: 23336, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2012
# Id: 28688, Make: Ford, Model: Explorer, Fav: OLDISH-Ford-Explorer, Year: 2011
# Matched 100% (10/10)
#
# Getting recommendations for user: 18954, who likes: OLDISH-Dodge-Caravan
# Id: 24182, Make: Dodge, Model: Caravan, Fav: OLDISH-Dodge-Caravan, Year: 2011
# Id: 27541, Make: Dodge, Model: Caravan, Fav: OLDISH-Dodge-Caravan, Year: 2011
# Id: 21000, Make: Dodge, Model: Caravan, Fav: OLDISH-Dodge-Caravan, Year: 2011
# Id: 27785, Make: Dodge, Model: Caravan, Fav: OLDISH-Dodge-Caravan, Year: 2011
# Id: 27156, Make: Dodge, Model: Caravan, Fav: OLDISH-Dodge-Caravan, Year: 2012
# Id: 27406, Make: Dodge, Model: Caravan, Fav: OLDISH-Dodge-Caravan, Year: 2013
# Id: 23321, Make: Dodge, Model: Caravan, Fav: OLDISH-Dodge-Caravan, Year: 2012
# Id: 25005, Make: Dodge, Model: Caravan, Fav: OLDISH-Dodge-Caravan, Year: 2011
# Id: 24690, Make: Dodge, Model: Caravan, Fav: OLDISH-Dodge-Caravan, Year: 2011
# Id: 31281, Make: Dodge, Model: Caravan, Fav: OLDISH-Dodge-Caravan, Year: 2011
# Matched 100% (10/10)
#
# Getting recommendations for user: 10658, who likes: NEWISH-Ford-Mustang
# Id: 23207, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 28126, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 19767, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 17893, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 21274, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 27535, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 21475, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 23173, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 25449, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2015
# Id: 22218, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2014
# Matched 100% (10/10)
#
# Getting recommendations for user: 10861, who likes: NEWISH-Dodge-Ram
# Id: 22425, Make: Dodge, Model: Ram, Fav: NEWISH-Dodge-Ram, Year: 2015
# Id: 24645, Make: Dodge, Model: Ram, Fav: NEWISH-Dodge-Ram, Year: 2015
# Id: 23684, Make: Dodge, Model: Ram, Fav: NEWISH-Dodge-Ram, Year: 2015
# Id: 28901, Make: Dodge, Model: Ram, Fav: NEWISH-Dodge-Ram, Year: 2015
# Id: 25819, Make: Dodge, Model: Ram, Fav: NEWISH-Dodge-Ram, Year: 2015
# Id: 26958, Make: Dodge, Model: Ram, Fav: NEWISH-Dodge-Ram, Year: 2015
# Id: 25956, Make: Dodge, Model: Ram, Fav: NEWISH-Dodge-Ram, Year: 2015
# Id: 28097, Make: Dodge, Model: Ram, Fav: NEWISH-Dodge-Ram, Year: 2014
# Id: 21408, Make: Dodge, Model: Ram, Fav: NEWISH-Dodge-Ram, Year: 2015
# Id: 20514, Make: Dodge, Model: Ram, Fav: NEWISH-Dodge-Ram, Year: 2015
# Matched 100% (10/10)

# %% [markdown]
# ## Exercise the popularity campaign
# Personalize provides a baseline recommender which leverages simple popularity of an item.
# Here we will
# compare its results with our own definition of "popular".
#
# Our popularity is driven simply by total count of
# interactions for that item. We expect significant overlap between our list and the one from Personalize.

# %% [markdown]
# #### First let's get the results from Personalize

# %%
personalized_pop = []
pop_items = []
NUM_MOST_POPULAR = 10

if is_campaign_active(pop_arn):
    popularity_response = personalize_runtime.get_recommendations(campaignArn=pop_arn, 
                                                                  userId='0', 
                                                                  numResults=NUM_MOST_POPULAR)
    pop_items = popularity_response['itemList']
    for item in pop_items:
        print_item(int(item['itemId']))    
else:
    print('Popularity campaign not active: {}'.format(pop_arn))

for p in pop_items:
    personalized_pop.append(str(p['itemId']))
# Out:
# Id: 25714, Make: Nissan, Model: Rogue, Fav: NEWISH-Nissan-Rogue, Year: 2015
# Id: 24588, Make: Hyundai, Model: Santa Fe, Fav: NEWISH-Hyundai-Santa Fe, Year: 2014
# Id: 23545, Make: BMW, Model: 430i, Fav: OLDISH-BMW-430i, Year: 2011
# Id: 24366, Make: Nissan, Model: Rogue, Fav: OLDISH-Nissan-Rogue, Year: 2013
# Id: 25012, Make: Nissan, Model: Rogue, Fav: NEWISH-Nissan-Rogue, Year: 2014
# Id: 23735, Make: Nissan, Model: Rogue, Fav: NEWISH-Nissan-Rogue, Year: 2014
# Id: 23649, Make: Chrysler, Model: Pacifica, Fav: OLDISH-Chrysler-Pacifica, Year: 2012
# Id: 23791, Make: Ford, Model: Mustang, Fav: NEWISH-Ford-Mustang, Year: 2016
# Id: 25812, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 25104, Make: Nissan, Model: Rogue, Fav: NEWISH-Nissan-Rogue, Year: 2016

# %% [markdown]
# #### Now let's get the actual popularity counts of the historical interactions

# %%
most_popular = pd.DataFrame(int_expanded_df['ITEM_ID'].value_counts().reset_index())
most_popular.drop(['ITEM_ID'], axis=1, inplace=True)
ten_most_popular = most_popular.head(10)

# %% [markdown]
# #### Now compare the two lists

# %%
if is_campaign_active(pop_arn):
    print('We asked Personalize for {} most popular.'.format(NUM_MOST_POPULAR))
    print('{}'.format(personalized_pop))
    print('We computed it ourselves also')
    print(ten_most_popular['index'])

    overlap_items     = ten_most_popular[ten_most_popular['index'].isin(personalized_pop)]
    overlap_count     = overlap_items.shape[0]
    not_overlap_items = ten_most_popular[~ten_most_popular['index'].isin(personalized_pop)]
    not_overlap_count = not_overlap_items.shape[0]
    
    print('\nOf the actual most popular, {} are selected by Personalize also.'.format(overlap_items))
    print('\nPersonalize did not think this list was truly top 10:'.format(not_overlap_count))
    print(not_overlap_items.head())
# Out:
# We asked Personalize for 10 most popular.
# ['25714', '24588', '23545', '24366', '25012', '23735', '23649', '23791', '25812', '25104']
# We computed it ourselves also
# 0    25714
# 1    26377
# 2    25104
# 3    24588
# 4    25589
# 5    23791
# 6    24366
# 7    25012
# 8    26299
# 9    23735
# Name: index, dtype: int64
#
# Of the actual most popular,    index
# 0  25714
# 2  25104
# 3  24588
# 5  23791
# 6  24366
# 7  25012
# 9  23735 are selected by Personalize also.
#
# Personalize did not think this list was truly top 10:
#    index
# 1  26377
# 4  25589
# 8  26299

# %% [markdown]
# ## Use real time events
# Here we use the event tracker mechanism of personalize to add some events on the fly after deployment of
# a campaign. We then show the impact on the recommendations, demonstrating that Personalize is able to
# react to changing user preferences on the fly.

# %%
def is_tracker_active(tracker_name):
    _is_active = False
    _event_tracker_arn = ''
    _tracking_id = ''

    resp = personalize.list_event_trackers()
    trackers = resp['eventTrackers']

    for t in trackers:
        if t['name'] == tracker_name:
            _is_active = True
            _event_tracker_arn = t['eventTrackerArn']
            d_resp = personalize.describe_event_tracker(eventTrackerArn = _event_tracker_arn)

            _tracking_id = d_resp['eventTracker']['trackingId']
    
    return _is_active, _event_tracker_arn, _tracking_id

# %%
(exists, tracker_arn, tracking_id) = is_tracker_active('CarClickTracker')
if not exists:
    response = personalize.create_event_tracker(
        name='CarClickTracker',
        datasetGroupArn=dg_arn
    )
    print(response['eventTrackerArn'])
    print(response['trackingId'])

    TRACKING_ID = response['trackingId']
else:
    TRACKING_ID = tracking_id

# %%
import uuid

session_dict = {}

# %%
def configure_session(user_id):
    # Configure Session
    try:
        _session_ID = session_dict[user_id]
    except:
        session_dict[user_id] = str(uuid.uuid1())
        _session_ID = session_dict[user_id]
    return _session_ID

# %%
def send_one_car_click(user_id, item_id, ts):
    """
    Simulates a click to send an event to Amazon Personalize's Event Tracker
    """
    session_ID = configure_session(user_id)
        
    # Configure Properties:
    event = {
        'itemId': str(item_id)
    }
    event_json = json.dumps(event)
        
    # Make Call
    personalize_events.put_events(
        trackingId = TRACKING_ID,
        userId     = str(user_id),
        sessionId  = session_ID,
        eventList  = [{
            'sentAt': ts,
            'eventType': 'EVENT_TYPE',
            'properties': event_json
            }]
    )

# %%
def send_car_clicks(user_id, items):
    _send_as_a_batch = True
    
    if _send_as_a_batch:
        # send items as if they each took a second, having them wrap up with the last one being now
        # so, first back up a number of seconds for the first item.
        _base_ts = time.time() - len(items)
        
        _session_ID = configure_session(user_id)
        
        _event_list  = []
        _max_batch_size = 10
        _i = 0
        for _item_id in items:
            _event_properties = {
                'itemId': str(_item_id)
            }
            _event_json = json.dumps(_event_properties)
            
            _event = {'sentAt': _base_ts + _i,
                      'eventType': 'EVENT_TYPE',
                      'properties': _event_json
                     }
            _event_list.append(_event)

            _i += 1
            if (_i > 1) and ((_i % _max_batch_size) == 0):
                # send along the next 10 events
#                print('Sending batch of {} events: {}\n'.format(len(_event_list), _event_list))
                personalize_events.put_events(
                    trackingId = TRACKING_ID,
                    userId     = str(user_id),
                    sessionId  = _session_ID,
                    eventList  = _event_list
                )
                # reset for the next batch
                _event_list = []


        # send last batch
        if (len(_event_list) > 0):
#            print('Sending batch of {} events: {}\n'.format(len(_event_list), _event_list))
            personalize_events.put_events(
                trackingId = TRACKING_ID,
                userId     = str(user_id),
                sessionId  = _session_ID,
                eventList  = _event_list
            )        

    else: # send one at a time
        i = 0
        for item in items:
            send_one_car_click(user_id, item, time.time())
            i += 1

# %%
def recommend_cars(user_id, campaign_arn):
    response = personalize_runtime.get_recommendations(campaignArn=campaign_arn, 
                                                       userId=str(user_id), 
                                                       numResults=10)
    items = response['itemList']
    for item in items:
        print_item(int(item['itemId']))
    print('')

# %%
sample_user = int_expanded_df.sample(1).iloc[0]['USER_ID']
sample_user_cluster = int_expanded_df[int_expanded_df.USER_ID == sample_user].iloc[0]['FAV_CLUSTER']
sample_user_fav = int_expanded_df[int_expanded_df.USER_ID == sample_user].iloc[0]['FAV']
print('Here is a sample user for exercising real time events:\n')
print('  user: {}, cluster: {}, fav: {}'.format(sample_user, sample_user_cluster, sample_user_fav))
# Out:
# Here is a sample user for exercising real time events:
#
#   user: 13875, cluster: 54, fav: NEWISH-Chevrolet-Tahoe

# %%
new_cluster = sample_user_cluster + 1
if (new_cluster == NUM_CLUSTERS):
    new_cluster = 0
new_fav = int_expanded_df[int_expanded_df.FAV_CLUSTER == new_cluster].iloc[0]['FAV']
print('Now, we pick a new preferred set of cars that we will use when sending events:\n')
print('  new cluster: {}, new fav: {}'.format(new_cluster, new_fav))
# Out:
# Now, we pick a new preferred set of cars that we will use when sending events:
#
#   new cluster: 55, new fav: OLDISH-Chevrolet-Tahoe

# %%
print('Before any real time events, Personalize should recommend {} cars...\n'.format(sample_user_fav))

if is_campaign_active(hrnn_arn):
    print('First using {}\n'.format(hrnn_arn))
    recommend_cars(sample_user, hrnn_arn)
else:
    print('HRNN campaign not active: {}'.format(hrnn_arn))

if is_campaign_active(hrnn_metadata_arn):
    print('Next using {}\n'.format(hrnn_metadata_arn))
    recommend_cars(sample_user, hrnn_arn)
else:
    print('HRNN-metadata campaign not active: {}'.format(hrnn_metadata_arn))
# Out:
# Before any real time events, Personalize should recommend NEWISH-Chevrolet-Tahoe cars...
#
# First using arn:aws:personalize:us-east-1:355151823911:campaign/car-hrnn
#
# Id: 26104, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 25071, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2018
# Id: 24128, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 27365, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Id: 27688, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 25932, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Id: 23245, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2017
# Id: 22727, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2018
# Id: 24688, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 21920, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2017
#
# Next using arn:aws:personalize:us-east-1:355151823911:campaign/car-hrnn-metadata
#
# Id: 26104, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 25071, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2018
# Id: 24128, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 27365, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Id: 27688, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 25932, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2014
# Id: 23245, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2017
# Id: 22727, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2018
# Id: 24688, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2015
# Id: 21920, Make: Chevrolet, Model: Tahoe, Fav: NEWISH-Chevrolet-Tahoe, Year: 2017

# %%
new_car_cluster = int_expanded_df[int_expanded_df.FAV_CLUSTER == new_cluster].sample(100)
new_car_cluster[['FAV','ITEM_ID','YEAR','PRICE']].head(3)
# Out:
#                            FAV  ITEM_ID  YEAR  PRICE
# 584385  OLDISH-Chevrolet-Tahoe    33778  2013  25780
# 320122  OLDISH-Chevrolet-Tahoe    23028  2013  23776
# 308636  OLDISH-Chevrolet-Tahoe    26517  2011  22385

# %%
new_items_clicked = new_car_cluster['ITEM_ID'].values
new_items_clicked
# Out:
# array([33778, 23028, 26517, 23307, 25094, 21760, 27565, 26709, 27571,
#        29478, 27887, 27777, 21448, 17218, 33579, 28211, 30818, 13254,
#        30099, 16843, 31985, 29599, 23179, 20503, 26820, 28963, 26517,
#        25694, 22528, 24527, 24400, 25060, 23454, 21630, 31528, 42523,
#        32619, 23307, 27434, 20721, 25694, 20617, 24527, 26429, 19558,
#        26429, 23179, 20998, 26709, 29169, 23307, 24150, 14772, 27105,
#        31997, 30508, 30122, 26340, 20792, 21423, 32746, 23552, 23860,
#        24527, 30277, 18110, 25437, 20948, 25094, 25437, 23330, 20948,
#        27434, 25730, 29046, 28581, 25056, 17492, 28542, 26339, 28963,
#        22906, 32665, 25338, 27624, 24561, 16707, 23860, 17723, 16353,
#        25812, 28336, 27565, 30818, 23179, 24121, 27579, 19374, 30818,
#        21913])

# %%
send_car_clicks(sample_user, new_items_clicked)

# %%
print('Here is the number of historical interactions for the sample user against each car cluster...')
int_expanded_df[int_expanded_df.USER_ID == sample_user]['FAV'].value_counts()
# Out:
# Here is the number of historical interactions for the sample user against each car cluster...
# NEWISH-Chevrolet-Tahoe    70
# Name: FAV, dtype: int64

# %%
print('Now this same user has started to like {} cars.'.format(new_fav))
print('Lets see if Personalize picks up on this real time change in intent...\n')

if is_campaign_active(hrnn_arn):
    print('First using {}\n'.format(hrnn_arn))
    recommend_cars(sample_user, hrnn_arn)
else:
    print('HRNN campaign not active: {}'.format(hrnn_arn))

if is_campaign_active(hrnn_metadata_arn):
    print('Next using {}\n'.format(hrnn_metadata_arn))
    recommend_cars(sample_user, hrnn_arn)
else:
    print('HRNN-metadata campaign not active: {}'.format(hrnn_metadata_arn))
# Out:
# Now this same user has started to like OLDISH-Chevrolet-Tahoe cars.
# Lets see if Personalize picks up on this real time change in intent...
#
# First using arn:aws:personalize:us-east-1:355151823911:campaign/car-hrnn
#
# Id: 23196, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2013
# Id: 26429, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2013
# Id: 21063, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 26517, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2011
# Id: 28616, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 23675, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2013
# Id: 24302, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 26340, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 23393, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2013
# Id: 24312, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2011
#
# Next using arn:aws:personalize:us-east-1:355151823911:campaign/car-hrnn-metadata
#
# Id: 23196, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2013
# Id: 26429, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2013
# Id: 21063, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 26517, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2011
# Id: 28616, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 23675, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2013
# Id: 24302, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 26340, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2012
# Id: 23393, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2013
# Id: 24312, Make: Chevrolet, Model: Tahoe, Fav: OLDISH-Chevrolet-Tahoe, Year: 2011
